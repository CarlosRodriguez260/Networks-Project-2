# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):
        
            # get a message from queue
            msg = self.Queue_Tx.get()
            
            text_out = self.Name + " Tx: message: " + str(msg)
            self.exp_out.print(text_out)
            
            # sending the message using socket
            msg_bytes = str.encode(msg)
            if (random.random() < 0.2):
                self.exp_out.print("packet loss")
            else:
                # sending the message using socket
                self.Socket.sendto(msg_bytes, self.AP_Tx)

    def loop_Rx(self):
        
        global thread_running
        global bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        # binding the socket with the IP and port
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):
        
            # get a message from socket, this thread is blocked here
            msg_addr = self.Socket.recvfrom(bufferSize)

            # to emulate a slow receiver
            time.sleep(0.5)
    
            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]
            
            text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            self.Queue_Rx.put(msg)
            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')
# 21:29:50> ALE_Alice: loop_Tx starting
# 21:29:50> ALE_Alice: loop_Rx starting
# 21:29:50> DLE_Alice: loop_Tx starting
# 21:29:50> DLE_Alice: loop_Rx starting
# 21:29:50> PLE_Alice: loop_Tx starting
# 21:29:50> PLE_Alice: loop_Rx starting
# 21:29:50> ALE_Bob: loop_Tx starting
# 21:29:50> ALE_Bob: loop_Rx starting
# 21:29:50> DLE_Bob: loop_Tx starting
# 21:29:50> DLE_Bob: loop_Rx starting
# 21:29:50> PLE_Bob: loop_Tx starting
# 21:29:50> PLE_Bob: loop_Rx starting
# 21:29:50> DLE_Alice: loop_FSM starting
# 21:29:50> DLE_Bob: loop_FSM starting
# 21:29:50> DLE_Alice: loop_Timer starting
# 21:29:50> DLE_Bob: loop_Timer starting
# 21:30:16> ALE_Alice Tx: message 1: Hello World0
# 21:30:16> ALE_Alice Tx: message 2: Hello World1
# 21:30:16> ALE_Alice Tx: message 3: Hello World2
# 21:30:16> ALE_Alice Tx: message 4: Hello World3
# 21:30:16> ALE_Alice Tx: message 5: Hello World4
# 21:30:16> ALE_Alice Tx: message 6: Hello World5
# 21:30:16> ALE_Alice Tx: message 7: Hello World6
# 21:30:16> ALE_Alice Tx: message 8: Hello World7
# 21:30:16> ALE_Alice Tx: message 9: Hello World8
# 21:30:16> ALE_Alice Tx: message 10: Hello World9
# 21:30:16> ALE_Alice Tx: message 11: Hello World10
# 21:30:16> ALE_Alice Tx: message 12: Hello World11
# 21:30:16> ALE_Alice Tx: message 13: Hello World12
# 21:30:16> ALE_Alice Tx: message 14: Hello World13
# 21:30:16> ALE_Alice Tx: message 15: Hello World14
# 21:30:16> ALE_Alice Tx: message 16: Hello World15
# 21:30:16> ALE_Alice Tx: message 17: Hello World16
# 21:30:16> ALE_Alice Tx: message 18: Hello World17
# 21:30:16> ALE_Alice Tx: message 19: Hello World18
# 21:30:16> ALE_Alice Tx: message 20: Hello World19
# 21:30:16> DLE_Alice Tx: message 1: Hello World0
# 21:30:16> DLE_Alice FSM: state: 0 event type: 0
# 21:30:16> DLE_Alice FSM: to send: Hello World0
# 21:30:16> PLE_Alice Tx: message: 00Hello World0
# 21:30:17> PLE_Bob Rx: from ('127.0.0.1', 30000): 00Hello World0
# 21:30:17> DLE_Bob Rx: message 1: 00Hello World0
# 21:30:17> DLE_Bob FSM: state: 0 event type: 1
# 21:30:17> DLE_Bob FSM: received: Hello World0
# 21:30:17> PLE_Bob Tx: message: 10
# 21:30:17> packet loss
# 21:30:17> ALE_Bob Rx: message 1: Hello World0
# 21:30:22> DLE_Alice FSM: state: 1 event type: 3
# 21:30:22> DLE_Alice FSM: to resend frame 0 Hello World0
# 21:30:22> PLE_Alice Tx: message: 00Hello World0
# 21:30:22> PLE_Bob Rx: from ('127.0.0.1', 30000): 00Hello World0
# 21:30:22> DLE_Bob Rx: message 2: 00Hello World0
# 21:30:22> DLE_Bob FSM: state: 0 event type: 1
# 21:30:22> DLE_Bob FSM: received: Hello World0
# 21:30:22> DLE_Bob FSM: received received frame 0 but expected 1
# 21:30:22> PLE_Bob Tx: message: 10
# 21:30:23> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 21:30:23> DLE_Alice Rx: message 1: 10
# 21:30:23> DLE_Alice FSM: state: 1 event type: 2
# 21:30:23> DLE_Alice Tx: message 2: Hello World1
# 21:30:23> DLE_Alice FSM: state: 0 event type: 0
# 21:30:23> DLE_Alice FSM: to send: Hello World1
# 21:30:23> PLE_Alice Tx: message: 01Hello World1
# 21:30:23> packet loss
# 21:30:27> ALE_Bob Tx: message 1: hello Universe0
# 21:30:27> ALE_Bob Tx: message 2: hello Universe1
# 21:30:27> ALE_Bob Tx: message 3: hello Universe2
# 21:30:27> ALE_Bob Tx: message 4: hello Universe3
# 21:30:27> ALE_Bob Tx: message 5: hello Universe4
# 21:30:27> ALE_Bob Tx: message 6: hello Universe5
# 21:30:27> ALE_Bob Tx: message 7: hello Universe6
# 21:30:27> ALE_Bob Tx: message 8: hello Universe7
# 21:30:27> ALE_Bob Tx: message 9: hello Universe8
# 21:30:27> ALE_Bob Tx: message 10: hello Universe9
# 21:30:27> ALE_Bob Tx: message 11: hello Universe10
# 21:30:27> ALE_Bob Tx: message 12: hello Universe11
# 21:30:27> ALE_Bob Tx: message 13: hello Universe12
# 21:30:27> ALE_Bob Tx: message 14: hello Universe13
# 21:30:27> ALE_Bob Tx: message 15: hello Universe14
# 21:30:27> ALE_Bob Tx: message 16: hello Universe15
# 21:30:27> ALE_Bob Tx: message 17: hello Universe16
# 21:30:27> ALE_Bob Tx: message 18: hello Universe17
# 21:30:27> ALE_Bob Tx: message 19: hello Universe18
# 21:30:27> ALE_Bob Tx: message 20: hello Universe19
# 21:30:27> DLE_Bob Tx: message 1: hello Universe0
# 21:30:27> DLE_Bob FSM: state: 0 event type: 0
# 21:30:27> DLE_Bob FSM: to send: hello Universe0
# 21:30:27> PLE_Bob Tx: message: 00hello Universe0
# 21:30:27> packet loss
# 21:30:28> DLE_Alice FSM: state: 1 event type: 3
# 21:30:28> DLE_Alice FSM: to resend frame 1 Hello World1
# 21:30:28> PLE_Alice Tx: message: 01Hello World1
# 21:30:29> PLE_Bob Rx: from ('127.0.0.1', 30000): 01Hello World1
# 21:30:29> DLE_Bob Rx: message 3: 01Hello World1
# 21:30:29> DLE_Bob FSM: state: 1 event type: 1
# 21:30:29> DLE_Bob FSM: received: Hello World1
# 21:30:29> PLE_Bob Tx: message: 11
# 21:30:29> ALE_Bob Rx: message 2: Hello World1
# 21:30:29> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 21:30:29> DLE_Alice Rx: message 2: 11
# 21:30:29> DLE_Alice FSM: state: 1 event type: 2
# 21:30:29> DLE_Alice Tx: message 3: Hello World2
# 21:30:29> DLE_Alice FSM: state: 0 event type: 0
# 21:30:29> DLE_Alice FSM: to send: Hello World2
# 21:30:29> PLE_Alice Tx: message: 02Hello World2
# 21:30:30> PLE_Bob Rx: from ('127.0.0.1', 30000): 02Hello World2
# 21:30:30> DLE_Bob Rx: message 4: 02Hello World2
# 21:30:30> DLE_Bob FSM: state: 1 event type: 1
# 21:30:30> DLE_Bob FSM: received: Hello World2
# 21:30:30> PLE_Bob Tx: message: 12
# 21:30:30> packet loss
# 21:30:30> ALE_Bob Rx: message 3: Hello World2
# 21:30:32> DLE_Bob FSM: state: 1 event type: 3
# 21:30:32> DLE_Bob FSM: to resend frame 0 hello Universe0
# 21:30:32> PLE_Bob Tx: message: 00hello Universe0
# 21:30:33> PLE_Alice Rx: from ('127.0.0.1', 31111): 00hello Universe0
# 21:30:33> DLE_Alice Rx: message 3: 00hello Universe0
# 21:30:33> DLE_Alice FSM: state: 1 event type: 1
# 21:30:33> DLE_Alice FSM: received: hello Universe0
# 21:30:33> PLE_Alice Tx: message: 10
# 21:30:33> ALE_Alice Rx: message 1: hello Universe0
# 21:30:33> PLE_Bob Rx: from ('127.0.0.1', 30000): 10
# 21:30:33> DLE_Bob Rx: message 5: 10
# 21:30:33> DLE_Bob FSM: state: 1 event type: 2
# 21:30:33> DLE_Bob Tx: message 2: hello Universe1
# 21:30:33> DLE_Bob FSM: state: 0 event type: 0
# 21:30:33> DLE_Bob FSM: to send: hello Universe1
# 21:30:33> PLE_Bob Tx: message: 01hello Universe1
# 21:30:34> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:30:34> DLE_Alice Rx: message 4: 01hello Universe1
# 21:30:34> DLE_Alice FSM: state: 1 event type: 1
# 21:30:34> DLE_Alice FSM: received: hello Universe1
# 21:30:34> PLE_Alice Tx: message: 11
# 21:30:34> packet loss
# 21:30:34> ALE_Alice Rx: message 2: hello Universe1
# 21:30:35> DLE_Alice FSM: state: 1 event type: 3
# 21:30:35> DLE_Alice FSM: to resend frame 2 Hello World2
# 21:30:35> PLE_Alice Tx: message: 02Hello World2
# 21:30:36> PLE_Bob Rx: from ('127.0.0.1', 30000): 02Hello World2
# 21:30:36> DLE_Bob Rx: message 6: 02Hello World2
# 21:30:36> DLE_Bob FSM: state: 1 event type: 1
# 21:30:36> DLE_Bob FSM: received: Hello World2
# 21:30:36> DLE_Bob FSM: received received frame 2 but expected 3
# 21:30:36> PLE_Bob Tx: message: 12
# 21:30:36> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 21:30:36> DLE_Alice Rx: message 5: 12
# 21:30:36> DLE_Alice FSM: state: 1 event type: 2
# 21:30:36> DLE_Alice Tx: message 4: Hello World3
# 21:30:36> DLE_Alice FSM: state: 0 event type: 0
# 21:30:36> DLE_Alice FSM: to send: Hello World3
# 21:30:36> PLE_Alice Tx: message: 03Hello World3
# 21:30:37> PLE_Bob Rx: from ('127.0.0.1', 30000): 03Hello World3
# 21:30:37> DLE_Bob Rx: message 7: 03Hello World3
# 21:30:37> DLE_Bob FSM: state: 1 event type: 1
# 21:30:37> DLE_Bob FSM: received: Hello World3
# 21:30:37> ALE_Bob Rx: message 4: Hello World3
# 21:30:37> PLE_Bob Tx: message: 13
# 21:30:37> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 21:30:37> DLE_Alice Rx: message 6: 13
# 21:30:37> DLE_Alice FSM: state: 1 event type: 2
# 21:30:37> DLE_Alice Tx: message 5: Hello World4
# 21:30:37> DLE_Alice FSM: state: 0 event type: 0
# 21:30:37> DLE_Alice FSM: to send: Hello World4
# 21:30:37> PLE_Alice Tx: message: 04Hello World4
# 21:30:38> PLE_Bob Rx: from ('127.0.0.1', 30000): 04Hello World4
# 21:30:38> DLE_Bob Rx: message 8: 04Hello World4
# 21:30:38> DLE_Bob FSM: state: 1 event type: 1
# 21:30:38> DLE_Bob FSM: received: Hello World4
# 21:30:38> ALE_Bob Rx: message 5: Hello World4
# 21:30:38> PLE_Bob Tx: message: 14
# 21:30:38> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 21:30:38> DLE_Alice Rx: message 7: 14
# 21:30:38> DLE_Alice FSM: state: 1 event type: 2
# 21:30:38> DLE_Alice Tx: message 6: Hello World5
# 21:30:38> DLE_Alice FSM: state: 0 event type: 0
# 21:30:38> DLE_Alice FSM: to send: Hello World5
# 21:30:38> PLE_Alice Tx: message: 05Hello World5
# 21:30:39> PLE_Bob Rx: from ('127.0.0.1', 30000): 05Hello World5
# 21:30:39> DLE_Bob Rx: message 9: 05Hello World5
# 21:30:39> DLE_Bob FSM: state: 1 event type: 1
# 21:30:39> DLE_Bob FSM: received: Hello World5
# 21:30:39> PLE_Bob Tx: message: 15
# 21:30:39> ALE_Bob Rx: message 6: Hello World5
# 21:30:39> DLE_Bob FSM: state: 1 event type: 3
# 21:30:39> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:30:39> PLE_Bob Tx: message: 01hello Universe1
# 21:30:39> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 21:30:39> DLE_Alice Rx: message 8: 15
# 21:30:39> DLE_Alice FSM: state: 1 event type: 2
# 21:30:39> DLE_Alice Tx: message 7: Hello World6
# 21:30:39> DLE_Alice FSM: state: 0 event type: 0
# 21:30:39> DLE_Alice FSM: to send: Hello World6
# 21:30:39> PLE_Alice Tx: message: 06Hello World6
# 21:30:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:30:40> DLE_Alice Rx: message 9: 01hello Universe1
# 21:30:40> DLE_Alice FSM: state: 1 event type: 1
# 21:30:40> DLE_Alice FSM: received: hello Universe1
# 21:30:40> DLE_Alice FSM: received received frame 1 but expected 2
# 21:30:40> PLE_Alice Tx: message: 11
# 21:30:40> packet loss
# 21:30:40> PLE_Bob Rx: from ('127.0.0.1', 30000): 06Hello World6
# 21:30:40> DLE_Bob Rx: message 10: 06Hello World6
# 21:30:40> DLE_Bob FSM: state: 1 event type: 1
# 21:30:40> DLE_Bob FSM: received: Hello World6
# 21:30:40> PLE_Bob Tx: message: 16
# 21:30:40> ALE_Bob Rx: message 7: Hello World6
# 21:30:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 21:30:40> DLE_Alice Rx: message 10: 16
# 21:30:40> DLE_Alice FSM: state: 1 event type: 2
# 21:30:40> DLE_Alice Tx: message 8: Hello World7
# 21:30:40> DLE_Alice FSM: state: 0 event type: 0
# 21:30:40> DLE_Alice FSM: to send: Hello World7
# 21:30:40> PLE_Alice Tx: message: 07Hello World7
# 21:30:41> PLE_Bob Rx: from ('127.0.0.1', 30000): 07Hello World7
# 21:30:41> DLE_Bob Rx: message 11: 07Hello World7
# 21:30:41> DLE_Bob FSM: state: 1 event type: 1
# 21:30:41> DLE_Bob FSM: received: Hello World7
# 21:30:41> PLE_Bob Tx: message: 17
# 21:30:41> ALE_Bob Rx: message 8: Hello World7
# 21:30:41> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 21:30:41> DLE_Alice Rx: message 11: 17
# 21:30:41> DLE_Alice FSM: state: 1 event type: 2
# 21:30:41> DLE_Alice Tx: message 9: Hello World8
# 21:30:41> DLE_Alice FSM: state: 0 event type: 0
# 21:30:41> DLE_Alice FSM: to send: Hello World8
# 21:30:41> PLE_Alice Tx: message: 08Hello World8
# 21:30:42> PLE_Bob Rx: from ('127.0.0.1', 30000): 08Hello World8
# 21:30:42> DLE_Bob Rx: message 12: 08Hello World8
# 21:30:42> DLE_Bob FSM: state: 1 event type: 1
# 21:30:42> DLE_Bob FSM: received: Hello World8
# 21:30:42> PLE_Bob Tx: message: 18
# 21:30:42> ALE_Bob Rx: message 9: Hello World8
# 21:30:42> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 21:30:42> DLE_Alice Rx: message 12: 18
# 21:30:42> DLE_Alice FSM: state: 1 event type: 2
# 21:30:42> DLE_Alice Tx: message 10: Hello World9
# 21:30:42> DLE_Alice FSM: state: 0 event type: 0
# 21:30:42> DLE_Alice FSM: to send: Hello World9
# 21:30:42> PLE_Alice Tx: message: 09Hello World9
# 21:30:43> PLE_Bob Rx: from ('127.0.0.1', 30000): 09Hello World9
# 21:30:43> DLE_Bob Rx: message 13: 09Hello World9
# 21:30:43> DLE_Bob FSM: state: 1 event type: 1
# 21:30:43> DLE_Bob FSM: received: Hello World9
# 21:30:43> PLE_Bob Tx: message: 19
# 21:30:43> ALE_Bob Rx: message 10: Hello World9
# 21:30:43> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 21:30:43> DLE_Alice Rx: message 13: 19
# 21:30:43> DLE_Alice FSM: state: 1 event type: 2
# 21:30:43> DLE_Alice Tx: message 11: Hello World10
# 21:30:43> DLE_Alice FSM: state: 0 event type: 0
# 21:30:43> DLE_Alice FSM: to send: Hello World10
# 21:30:43> PLE_Alice Tx: message: 00Hello World10
# 21:30:43> packet loss
# 21:30:44> DLE_Bob FSM: state: 1 event type: 3
# 21:30:44> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:30:44> PLE_Bob Tx: message: 01hello Universe1
# 21:30:45> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:30:45> DLE_Alice Rx: message 14: 01hello Universe1
# 21:30:45> DLE_Alice FSM: state: 1 event type: 1
# 21:30:45> DLE_Alice FSM: received: hello Universe1
# 21:30:45> DLE_Alice FSM: received received frame 1 but expected 2
# 21:30:45> PLE_Alice Tx: message: 11
# 21:30:45> packet loss
# 21:30:49> DLE_Alice FSM: state: 1 event type: 3
# 21:30:49> DLE_Alice FSM: to resend frame 0 Hello World10
# 21:30:49> PLE_Alice Tx: message: 00Hello World10
# 21:30:50> PLE_Bob Rx: from ('127.0.0.1', 30000): 00Hello World10
# 21:30:50> DLE_Bob Rx: message 14: 00Hello World10
# 21:30:50> DLE_Bob FSM: state: 1 event type: 1
# 21:30:50> DLE_Bob FSM: received: Hello World10
# 21:30:50> PLE_Bob Tx: message: 10
# 21:30:50> ALE_Bob Rx: message 11: Hello World10
# 21:30:50> DLE_Bob FSM: state: 1 event type: 3
# 21:30:50> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:30:50> PLE_Bob Tx: message: 01hello Universe1
# 21:30:50> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 21:30:50> DLE_Alice Rx: message 15: 10
# 21:30:50> DLE_Alice FSM: state: 1 event type: 2
# 21:30:50> DLE_Alice Tx: message 12: Hello World11
# 21:30:50> DLE_Alice FSM: state: 0 event type: 0
# 21:30:50> DLE_Alice FSM: to send: Hello World11
# 21:30:50> PLE_Alice Tx: message: 01Hello World11
# 21:30:50> packet loss
# 21:30:51> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:30:51> DLE_Alice Rx: message 16: 01hello Universe1
# 21:30:51> DLE_Alice FSM: state: 1 event type: 1
# 21:30:51> DLE_Alice FSM: received: hello Universe1
# 21:30:51> DLE_Alice FSM: received received frame 1 but expected 2
# 21:30:51> PLE_Alice Tx: message: 11
# 21:30:51> packet loss
# 21:30:55> DLE_Bob FSM: state: 1 event type: 3
# 21:30:55> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:30:55> PLE_Bob Tx: message: 01hello Universe1
# 21:30:56> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:30:56> DLE_Alice Rx: message 17: 01hello Universe1
# 21:30:56> DLE_Alice FSM: state: 1 event type: 1
# 21:30:56> DLE_Alice FSM: received: hello Universe1
# 21:30:56> DLE_Alice FSM: received received frame 1 but expected 2
# 21:30:56> PLE_Alice Tx: message: 11
# 21:30:56> packet loss
# 21:30:56> DLE_Alice FSM: state: 1 event type: 3
# 21:30:56> DLE_Alice FSM: to resend frame 1 Hello World11
# 21:30:56> PLE_Alice Tx: message: 01Hello World11
# 21:30:57> PLE_Bob Rx: from ('127.0.0.1', 30000): 01Hello World11
# 21:30:57> DLE_Bob Rx: message 15: 01Hello World11
# 21:30:57> DLE_Bob FSM: state: 1 event type: 1
# 21:30:57> DLE_Bob FSM: received: Hello World11
# 21:30:57> PLE_Bob Tx: message: 11
# 21:30:57> ALE_Bob Rx: message 12: Hello World11
# 21:30:57> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 21:30:57> DLE_Alice Rx: message 18: 11
# 21:30:57> DLE_Alice FSM: state: 1 event type: 2
# 21:30:57> DLE_Alice Tx: message 13: Hello World12
# 21:30:57> DLE_Alice FSM: state: 0 event type: 0
# 21:30:57> DLE_Alice FSM: to send: Hello World12
# 21:30:57> PLE_Alice Tx: message: 02Hello World12
# 21:30:57> packet loss
# 21:31:01> DLE_Bob FSM: state: 1 event type: 3
# 21:31:01> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:31:01> PLE_Bob Tx: message: 01hello Universe1
# 21:31:01> packet loss
# 21:31:03> DLE_Alice FSM: state: 1 event type: 3
# 21:31:03> DLE_Alice FSM: to resend frame 2 Hello World12
# 21:31:03> PLE_Alice Tx: message: 02Hello World12
# 21:31:04> PLE_Bob Rx: from ('127.0.0.1', 30000): 02Hello World12
# 21:31:04> DLE_Bob Rx: message 16: 02Hello World12
# 21:31:04> DLE_Bob FSM: state: 1 event type: 1
# 21:31:04> DLE_Bob FSM: received: Hello World12
# 21:31:04> PLE_Bob Tx: message: 12
# 21:31:04> ALE_Bob Rx: message 13: Hello World12
# 21:31:04> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 21:31:04> DLE_Alice Rx: message 19: 12
# 21:31:04> DLE_Alice FSM: state: 1 event type: 2
# 21:31:04> DLE_Alice Tx: message 14: Hello World13
# 21:31:04> DLE_Alice FSM: state: 0 event type: 0
# 21:31:04> DLE_Alice FSM: to send: Hello World13
# 21:31:04> PLE_Alice Tx: message: 03Hello World13
# 21:31:05> PLE_Bob Rx: from ('127.0.0.1', 30000): 03Hello World13
# 21:31:05> DLE_Bob Rx: message 17: 03Hello World13
# 21:31:05> DLE_Bob FSM: state: 1 event type: 1
# 21:31:05> DLE_Bob FSM: received: Hello World13
# 21:31:05> PLE_Bob Tx: message: 13
# 21:31:05> ALE_Bob Rx: message 14: Hello World13
# 21:31:05> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 21:31:05> DLE_Alice Rx: message 20: 13
# 21:31:05> DLE_Alice FSM: state: 1 event type: 2
# 21:31:05> DLE_Alice Tx: message 15: Hello World14
# 21:31:05> DLE_Alice FSM: state: 0 event type: 0
# 21:31:05> DLE_Alice FSM: to send: Hello World14
# 21:31:05> PLE_Alice Tx: message: 04Hello World14
# 21:31:06> PLE_Bob Rx: from ('127.0.0.1', 30000): 04Hello World14
# 21:31:06> DLE_Bob Rx: message 18: 04Hello World14
# 21:31:06> DLE_Bob FSM: state: 1 event type: 1
# 21:31:06> DLE_Bob FSM: received: Hello World14
# 21:31:06> PLE_Bob Tx: message: 14
# 21:31:06> packet loss
# 21:31:06> ALE_Bob Rx: message 15: Hello World14
# 21:31:07> DLE_Bob FSM: state: 1 event type: 3
# 21:31:07> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:31:07> PLE_Bob Tx: message: 01hello Universe1
# 21:31:07> packet loss
# 21:31:11> DLE_Alice FSM: state: 1 event type: 3
# 21:31:11> DLE_Alice FSM: to resend frame 4 Hello World14
# 21:31:11> PLE_Alice Tx: message: 04Hello World14
# 21:31:12> PLE_Bob Rx: from ('127.0.0.1', 30000): 04Hello World14
# 21:31:12> DLE_Bob Rx: message 19: 04Hello World14
# 21:31:12> DLE_Bob FSM: state: 1 event type: 1
# 21:31:12> DLE_Bob FSM: received: Hello World14
# 21:31:12> DLE_Bob FSM: received received frame 4 but expected 5
# 21:31:12> PLE_Bob Tx: message: 14
# 21:31:12> DLE_Bob FSM: state: 1 event type: 3
# 21:31:12> DLE_Bob FSM: to resend frame 1 hello Universe1
# 21:31:12> PLE_Bob Tx: message: 01hello Universe1
# 21:31:12> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 21:31:12> DLE_Alice Rx: message 21: 14
# 21:31:12> DLE_Alice FSM: state: 1 event type: 2
# 21:31:12> DLE_Alice Tx: message 16: Hello World15
# 21:31:12> DLE_Alice FSM: state: 0 event type: 0
# 21:31:12> DLE_Alice FSM: to send: Hello World15
# 21:31:12> PLE_Alice Tx: message: 05Hello World15
# 21:31:12> packet loss
# 21:31:13> PLE_Alice Rx: from ('127.0.0.1', 31111): 01hello Universe1
# 21:31:13> DLE_Alice Rx: message 22: 01hello Universe1
# 21:31:13> DLE_Alice FSM: state: 1 event type: 1
# 21:31:13> DLE_Alice FSM: received: hello Universe1
# 21:31:13> DLE_Alice FSM: received received frame 1 but expected 2
# 21:31:13> PLE_Alice Tx: message: 11
# 21:31:13> PLE_Bob Rx: from ('127.0.0.1', 30000): 11
# 21:31:13> DLE_Bob Rx: message 20: 11
# 21:31:13> DLE_Bob FSM: state: 1 event type: 2
# 21:31:13> DLE_Bob Tx: message 3: hello Universe2
# 21:31:13> DLE_Bob FSM: state: 0 event type: 0
# 21:31:13> DLE_Bob FSM: to send: hello Universe2
# 21:31:13> PLE_Bob Tx: message: 02hello Universe2
# 21:31:14> PLE_Alice Rx: from ('127.0.0.1', 31111): 02hello Universe2
# 21:31:14> DLE_Alice Rx: message 23: 02hello Universe2
# 21:31:14> DLE_Alice FSM: state: 1 event type: 1
# 21:31:14> DLE_Alice FSM: received: hello Universe2
# 21:31:14> ALE_Alice Rx: message 3: hello Universe2
# 21:31:14> PLE_Alice Tx: message: 12
# 21:31:14> PLE_Bob Rx: from ('127.0.0.1', 30000): 12
# 21:31:14> DLE_Bob Rx: message 21: 12
# 21:31:14> DLE_Bob FSM: state: 1 event type: 2
# 21:31:14> DLE_Bob Tx: message 4: hello Universe3
# 21:31:14> DLE_Bob FSM: state: 0 event type: 0
# 21:31:14> DLE_Bob FSM: to send: hello Universe3
# 21:31:14> PLE_Bob Tx: message: 03hello Universe3
# 21:31:15> PLE_Alice Rx: from ('127.0.0.1', 31111): 03hello Universe3
# 21:31:15> DLE_Alice Rx: message 24: 03hello Universe3
# 21:31:15> DLE_Alice FSM: state: 1 event type: 1
# 21:31:15> DLE_Alice FSM: received: hello Universe3
# 21:31:15> ALE_Alice Rx: message 4: hello Universe3
# 21:31:15> PLE_Alice Tx: message: 13
# 21:31:15> PLE_Bob Rx: from ('127.0.0.1', 30000): 13
# 21:31:15> DLE_Bob Rx: message 22: 13
# 21:31:15> DLE_Bob FSM: state: 1 event type: 2
# 21:31:15> DLE_Bob Tx: message 5: hello Universe4
# 21:31:15> DLE_Bob FSM: state: 0 event type: 0
# 21:31:15> DLE_Bob FSM: to send: hello Universe4
# 21:31:15> PLE_Bob Tx: message: 04hello Universe4
# 21:31:15> packet loss
# 21:31:18> DLE_Alice FSM: state: 1 event type: 3
# 21:31:18> DLE_Alice FSM: to resend frame 5 Hello World15
# 21:31:18> PLE_Alice Tx: message: 05Hello World15
# 21:31:19> PLE_Bob Rx: from ('127.0.0.1', 30000): 05Hello World15
# 21:31:19> DLE_Bob Rx: message 23: 05Hello World15
# 21:31:19> DLE_Bob FSM: state: 1 event type: 1
# 21:31:19> DLE_Bob FSM: received: Hello World15
# 21:31:19> ALE_Bob Rx: message 16: Hello World15
# 21:31:19> PLE_Bob Tx: message: 15
# 21:31:19> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 21:31:19> DLE_Alice Rx: message 25: 15
# 21:31:19> DLE_Alice FSM: state: 1 event type: 2
# 21:31:19> DLE_Alice Tx: message 17: Hello World16
# 21:31:19> DLE_Alice FSM: state: 0 event type: 0
# 21:31:19> DLE_Alice FSM: to send: Hello World16
# 21:31:19> PLE_Alice Tx: message: 06Hello World16
# 21:31:20> PLE_Bob Rx: from ('127.0.0.1', 30000): 06Hello World16
# 21:31:20> DLE_Bob Rx: message 24: 06Hello World16
# 21:31:20> DLE_Bob FSM: state: 1 event type: 1
# 21:31:20> DLE_Bob FSM: received: Hello World16
# 21:31:20> PLE_Bob Tx: message: 16
# 21:31:20> ALE_Bob Rx: message 17: Hello World16
# 21:31:20> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 21:31:20> DLE_Alice Rx: message 26: 16
# 21:31:20> DLE_Alice FSM: state: 1 event type: 2
# 21:31:20> DLE_Alice Tx: message 18: Hello World17
# 21:31:20> DLE_Alice FSM: state: 0 event type: 0
# 21:31:20> DLE_Alice FSM: to send: Hello World17
# 21:31:20> PLE_Alice Tx: message: 07Hello World17
# 21:31:20> packet loss
# 21:31:21> DLE_Bob FSM: state: 1 event type: 3
# 21:31:21> DLE_Bob FSM: to resend frame 4 hello Universe4
# 21:31:21> PLE_Bob Tx: message: 04hello Universe4
# 21:31:21> packet loss
# 21:31:26> DLE_Alice FSM: state: 1 event type: 3
# 21:31:26> DLE_Alice FSM: to resend frame 7 Hello World17
# 21:31:26> PLE_Alice Tx: message: 07Hello World17
# 21:31:27> DLE_Bob FSM: state: 1 event type: 3
# 21:31:27> DLE_Bob FSM: to resend frame 4 hello Universe4
# 21:31:27> PLE_Bob Tx: message: 04hello Universe4
# 21:31:27> PLE_Bob Rx: from ('127.0.0.1', 30000): 07Hello World17
# 21:31:27> DLE_Bob Rx: message 25: 07Hello World17
# 21:31:27> DLE_Bob FSM: state: 1 event type: 1
# 21:31:27> DLE_Bob FSM: received: Hello World17
# 21:31:27> ALE_Bob Rx: message 18: Hello World17
# 21:31:27> PLE_Bob Tx: message: 17
# 21:31:27> PLE_Alice Rx: from ('127.0.0.1', 31111): 04hello Universe4
# 21:31:27> DLE_Alice Rx: message 27: 04hello Universe4
# 21:31:27> DLE_Alice FSM: state: 1 event type: 1
# 21:31:27> DLE_Alice FSM: received: hello Universe4
# 21:31:27> PLE_Alice Tx: message: 14
# 21:31:27> ALE_Alice Rx: message 5: hello Universe4
# 21:31:28> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 21:31:28> DLE_Alice Rx: message 28: 17
# 21:31:28> DLE_Alice FSM: state: 1 event type: 2
# 21:31:28> DLE_Alice Tx: message 19: Hello World18
# 21:31:28> DLE_Alice FSM: state: 0 event type: 0
# 21:31:28> DLE_Alice FSM: to send: Hello World18
# 21:31:28> PLE_Alice Tx: message: 08Hello World18
# 21:31:28> PLE_Bob Rx: from ('127.0.0.1', 30000): 14
# 21:31:28> DLE_Bob Rx: message 26: 14
# 21:31:28> DLE_Bob FSM: state: 1 event type: 2
# 21:31:28> DLE_Bob Tx: message 6: hello Universe5
# 21:31:28> DLE_Bob FSM: state: 0 event type: 0
# 21:31:28> DLE_Bob FSM: to send: hello Universe5
# 21:31:28> PLE_Bob Tx: message: 05hello Universe5
# 21:31:28> packet loss
# 21:31:28> PLE_Bob Rx: from ('127.0.0.1', 30000): 08Hello World18
# 21:31:28> DLE_Bob Rx: message 27: 08Hello World18
# 21:31:28> DLE_Bob FSM: state: 1 event type: 1
# 21:31:28> DLE_Bob FSM: received: Hello World18
# 21:31:28> PLE_Bob Tx: message: 18
# 21:31:28> ALE_Bob Rx: message 19: Hello World18
# 21:31:29> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 21:31:29> DLE_Alice Rx: message 29: 18
# 21:31:29> DLE_Alice FSM: state: 1 event type: 2
# 21:31:29> DLE_Alice Tx: message 20: Hello World19
# 21:31:29> DLE_Alice FSM: state: 0 event type: 0
# 21:31:29> DLE_Alice FSM: to send: Hello World19
# 21:31:29> PLE_Alice Tx: message: 09Hello World19
# 21:31:29> PLE_Bob Rx: from ('127.0.0.1', 30000): 09Hello World19
# 21:31:29> DLE_Bob Rx: message 28: 09Hello World19
# 21:31:29> DLE_Bob FSM: state: 1 event type: 1
# 21:31:29> DLE_Bob FSM: received: Hello World19
# 21:31:29> ALE_Bob Rx: message 20: Hello World19
# 21:31:29> PLE_Bob Tx: message: 19
# 21:31:30> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 21:31:30> DLE_Alice Rx: message 30: 19
# 21:31:30> DLE_Alice FSM: state: 1 event type: 2

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()
