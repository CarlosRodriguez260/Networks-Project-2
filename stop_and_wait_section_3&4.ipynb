# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets, Layout, Output
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
# class PLE_TR:

#     def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
#         self.Name      = name
#         self.Socket    = Socket
#         self.AP_Tx     = AP_Tx
#         self.AP_Rx     = AP_Rx
#         self.Queue_Tx  = Queue()
#         self.Queue_Rx  = Queue()
#         self.exp_out   = exp_out
        
#     def loop_Tx(self):
        
#         global thread_running
#         self.exp_out.print(self.Name + ": loop_Tx starting")
    
#         while (thread_running == True):
        
#             # get a message from queue
#             msg = self.Queue_Tx.get()
            
#             text_out = self.Name + " Tx: message: " + str(msg)
#             self.exp_out.print(text_out)
            
#             # sending the message using socket
#             msg_bytes = str.encode(msg)
#             if (random.random() < 0.2):
#                 self.exp_out.print("packet loss")
#             else:
#                 # sending the message using socket
#                 self.Socket.sendto(msg_bytes, self.AP_Tx)

#     def loop_Rx(self):
        
#         global thread_running
#         global bufferSize
#         self.exp_out.print(self.Name + ": loop_Rx starting")
    
#         # binding the socket with the IP and port
#         self.Socket.bind(self.AP_Rx)
        
#         while (thread_running == True):
        
#             # get a message from socket, this thread is blocked here
#             msg_addr = self.Socket.recvfrom(bufferSize)

#             # to emulate a slow receiver
#             time.sleep(0.5)
    
#             msg  = msg_addr[0].decode('utf-8')
#             addr = msg_addr[1]
            
#             text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
#             self.exp_out.print(text_out)
            
#             self.Queue_Rx.put(msg)
            
#     def send(self, msg):
#         self.Queue_Tx.put(msg)
        
#     def receive(self):
#         return self.Queue_Rx.get()

class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")

        while (thread_running == True):
            # 1) Get a message from the queue (blocks until available)
            msg = self.Queue_Tx.get()
            self.exp_out.print(self.Name + " Tx: message: " + str(msg))

            # 2) Decide loss & duplication using a single random draw
            #    r in [0,1): 
            #      - r < 0.16   => drop (16%)
            #      - 0.15 <= r < 0.20 => send + duplicate (5%)
            #      - r >= 0.20  => normal single send (80%)
            r = random.random()
            msg_bytes = msg.encode()

            if r < 0.15:
                # Drop
                self.exp_out.print(self.Name + " PLE: packet loss (15%)")
                continue

            # Send once
            self.Socket.sendto(msg_bytes, self.AP_Tx)

            # Optional duplicate
            if r < 0.20:
                self.exp_out.print(self.Name + " PLE: duplicate transmission (5%)")
                self.Socket.sendto(msg_bytes, self.AP_Tx)


    def loop_Rx(self):
        global thread_running, bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")

        # Bind once before the receive loop
        self.Socket.bind(self.AP_Rx)

        while (thread_running == True):
            # Block waiting for a frame
            msg_addr = self.Socket.recvfrom(bufferSize)

            # Random delay 0.0 to 3.0 seconds
            delay = random.uniform(0.0, 3.0)
            time.sleep(delay)

            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]

            # Log the delay for evidence
            self.exp_out.print(self.Name + f" Rx: from {addr}: {msg} (rx_delay={delay:.2f}s)")

            # Hand to upper queue
            self.Queue_Rx.put(msg)

            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')
# 21:49:30> ALE_Alice: loop_Tx starting
# 21:49:30> ALE_Alice: loop_Rx starting
# 21:49:30> DLE_Alice: loop_Tx starting
# 21:49:30> DLE_Alice: loop_Rx starting
# 21:49:30> PLE_Alice: loop_Tx starting
# 21:49:30> PLE_Alice: loop_Rx starting
# 21:49:30> ALE_Bob: loop_Tx starting
# 21:49:30> ALE_Bob: loop_Rx starting
# 21:49:30> DLE_Bob: loop_Tx starting
# 21:49:30> DLE_Bob: loop_Rx starting
# 21:49:30> PLE_Bob: loop_Tx starting
# 21:49:30> PLE_Bob: loop_Rx starting
# 21:49:30> DLE_Alice: loop_FSM starting
# 21:49:30> DLE_Bob: loop_FSM starting
# 21:49:30> DLE_Alice: loop_Timer starting
# 21:49:30> DLE_Bob: loop_Timer starting

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()

# %%
### Measurement Layer Analysis ### ↓↓↓

# %%
# Measurement Layer Entity Class
class MLE_TR:
    def __init__(self, name, experiment, lower_TR, exp_out):
        self.Name = name
        self.Experiment = experiment
        self.Lower_TR = lower_TR
        self.exp_out = exp_out

        self.submit = widgets.Button(
                            description=f"Send 100 messages from {self.Name}.",
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                            layout=Layout(width='500px')
                        )
        self.submit.on_click(self.button_clicked)
        display(self.submit)

    def button_clicked(self, submit):
        # Initialize the CSV file to store experiment data
        # Deletes old data if it already exists
        with open(f"./experiment_outputs/experiment{self.Experiment}.csv", "w") as csv:
            csv.write("experimentId,messageId,currentTime\n")
        
        for i in range(100):
            # CSV Format: experimentId,messageId,currentTime
            msg = f"{self.Experiment},{i}"
            self.Lower_TR.send(msg)
    
    def loop_Rx(self):
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": MLE loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()

            # Append timestamp of when message was received (in ms)
            msg += f",{time.time_ns()/1_000_000}"
            text_out = self.Name + " MLE Rx: message " + str(c) + ": " + str(msg) 
            self.exp_out.print(text_out)

            # Everytime we successfully receive a message, store it in the CSV
            with open(f"./experiment_outputs/experiment{self.Experiment}.csv", "a") as csv:
                csv.write(str(msg)+"\n")

# %%
# Experiment 1: Two Nodes and Two Layers
# MLE_TR
# 
# PLE_TR

thread_running = False
bufferSize = 1024
exp_out = EXP_Output()

# Node 1 
AP_local_3  = ("127.0.0.1", 32222)
AP_remote_3 = ("127.0.0.1", 33000)

Socket_3 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_3 = PLE_TR("PLE_Node1", Socket_3, AP_remote_3, AP_local_3, exp_out)
MLE_1 = MLE_TR("MLE_Node1", 1, PLE_3, exp_out)

# Node 2 
AP_local_4  = ("127.0.0.1", 33000)
AP_remote_4 = ("127.0.0.1", 32222)

Socket_4 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_4 = PLE_TR("PLE_Node2", Socket_4, AP_remote_4, AP_local_4, exp_out)
MLE_2 = MLE_TR("MLE_Node2", 1, PLE_4, exp_out)
# Out:
# Button(description='Send 100 messages from MLE_Node1.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# Button(description='Send 100 messages from MLE_Node2.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# 21:49:31> PLE_Node1: loop_Tx starting
# 21:49:31> PLE_Node1: loop_Rx starting
# 21:49:31> MLE_Node1: MLE loop_Rx starting
# 21:49:31> PLE_Node2: loop_Tx starting
# 21:49:31> PLE_Node2: loop_Rx starting
# 21:49:31> MLE_Node2: MLE loop_Rx starting
# 21:50:25> PLE_Node1 Tx: message: 1,0
# 21:50:25> PLE_Node1 Tx: message: 1,1
# 21:50:25> PLE_Node1 Tx: message: 1,2
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,3
# 21:50:25> PLE_Node1 Tx: message: 1,4
# 21:50:25> PLE_Node1 Tx: message: 1,5
# 21:50:25> PLE_Node1 Tx: message: 1,6
# 21:50:25> PLE_Node1 Tx: message: 1,7
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,8
# 21:50:25> PLE_Node1 Tx: message: 1,9
# 21:50:25> PLE_Node1 Tx: message: 1,10
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,11
# 21:50:25> PLE_Node1 Tx: message: 1,12
# 21:50:25> PLE_Node1 Tx: message: 1,13
# 21:50:25> PLE_Node1 Tx: message: 1,14
# 21:50:25> PLE_Node1 PLE: duplicate transmission (5%)
# 21:50:25> PLE_Node1 Tx: message: 1,15
# 21:50:25> PLE_Node1 Tx: message: 1,16
# 21:50:25> PLE_Node1 Tx: message: 1,17
# 21:50:25> PLE_Node1 Tx: message: 1,18
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,19
# 21:50:25> PLE_Node1 Tx: message: 1,20
# 21:50:25> PLE_Node1 Tx: message: 1,21
# 21:50:25> PLE_Node1 Tx: message: 1,22
# 21:50:25> PLE_Node1 Tx: message: 1,23
# 21:50:25> PLE_Node1 Tx: message: 1,24
# 21:50:25> PLE_Node1 Tx: message: 1,25
# 21:50:25> PLE_Node1 Tx: message: 1,26
# 21:50:25> PLE_Node1 Tx: message: 1,27
# 21:50:25> PLE_Node1 Tx: message: 1,28
# 21:50:25> PLE_Node1 Tx: message: 1,29
# 21:50:25> PLE_Node1 PLE: duplicate transmission (5%)
# 21:50:25> PLE_Node1 Tx: message: 1,30
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,31
# 21:50:25> PLE_Node1 Tx: message: 1,32
# 21:50:25> PLE_Node1 Tx: message: 1,33
# 21:50:25> PLE_Node1 Tx: message: 1,34
# 21:50:25> PLE_Node1 Tx: message: 1,35
# 21:50:25> PLE_Node1 Tx: message: 1,36
# 21:50:25> PLE_Node1 Tx: message: 1,37
# 21:50:25> PLE_Node1 Tx: message: 1,38
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,39
# 21:50:25> PLE_Node1 Tx: message: 1,40
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,41
# 21:50:25> PLE_Node1 Tx: message: 1,42
# 21:50:25> PLE_Node1 Tx: message: 1,43
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,44
# 21:50:25> PLE_Node1 Tx: message: 1,45
# 21:50:25> PLE_Node1 PLE: duplicate transmission (5%)
# 21:50:25> PLE_Node1 Tx: message: 1,46
# 21:50:25> PLE_Node1 Tx: message: 1,47
# 21:50:25> PLE_Node1 Tx: message: 1,48
# 21:50:25> PLE_Node1 PLE: duplicate transmission (5%)
# 21:50:25> PLE_Node1 Tx: message: 1,49
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,50
# 21:50:25> PLE_Node1 Tx: message: 1,51
# 21:50:25> PLE_Node1 Tx: message: 1,52
# 21:50:25> PLE_Node1 Tx: message: 1,53
# 21:50:25> PLE_Node1 Tx: message: 1,54
# 21:50:25> PLE_Node1 Tx: message: 1,55
# 21:50:25> PLE_Node1 Tx: message: 1,56
# 21:50:25> PLE_Node1 Tx: message: 1,57
# 21:50:25> PLE_Node1 Tx: message: 1,58
# 21:50:25> PLE_Node1 Tx: message: 1,59
# 21:50:25> PLE_Node1 Tx: message: 1,60
# 21:50:25> PLE_Node1 Tx: message: 1,61
# 21:50:25> PLE_Node1 Tx: message: 1,62
# 21:50:25> PLE_Node1 Tx: message: 1,63
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,64
# 21:50:25> PLE_Node1 Tx: message: 1,65
# 21:50:25> PLE_Node1 Tx: message: 1,66
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,67
# 21:50:25> PLE_Node1 Tx: message: 1,68
# 21:50:25> PLE_Node1 Tx: message: 1,69
# 21:50:25> PLE_Node1 Tx: message: 1,70
# 21:50:25> PLE_Node1 Tx: message: 1,71
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,72
# 21:50:25> PLE_Node1 Tx: message: 1,73
# 21:50:25> PLE_Node1 Tx: message: 1,74
# 21:50:25> PLE_Node1 Tx: message: 1,75
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,76
# 21:50:25> PLE_Node1 Tx: message: 1,77
# 21:50:25> PLE_Node1 Tx: message: 1,78
# 21:50:25> PLE_Node1 Tx: message: 1,79
# 21:50:25> PLE_Node1 Tx: message: 1,80
# 21:50:25> PLE_Node1 Tx: message: 1,81
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,82
# 21:50:25> PLE_Node1 Tx: message: 1,83
# 21:50:25> PLE_Node1 Tx: message: 1,84
# 21:50:25> PLE_Node1 Tx: message: 1,85
# 21:50:25> PLE_Node1 Tx: message: 1,86
# 21:50:25> PLE_Node1 Tx: message: 1,87
# 21:50:25> PLE_Node1 Tx: message: 1,88
# 21:50:25> PLE_Node1 Tx: message: 1,89
# 21:50:25> PLE_Node1 Tx: message: 1,90
# 21:50:25> PLE_Node1 Tx: message: 1,91
# 21:50:25> PLE_Node1 Tx: message: 1,92
# 21:50:25> PLE_Node1 Tx: message: 1,93
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,94
# 21:50:25> PLE_Node1 Tx: message: 1,95
# 21:50:25> PLE_Node1 Tx: message: 1,96
# 21:50:25> PLE_Node1 Tx: message: 1,97
# 21:50:25> PLE_Node1 Tx: message: 1,98
# 21:50:25> PLE_Node1 PLE: packet loss (15%)
# 21:50:25> PLE_Node1 Tx: message: 1,99
# 21:50:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,0 (rx_delay=1.28s)
# 21:50:26> MLE_Node2 MLE Rx: message 1: 1,0,1760925026349.8042
# 21:50:29> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,1 (rx_delay=2.78s)
# 21:50:29> MLE_Node2 MLE Rx: message 2: 1,1,1760925029129.985
# 21:50:30> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,3 (rx_delay=1.26s)
# 21:50:30> MLE_Node2 MLE Rx: message 3: 1,3,1760925030389.725
# 21:50:32> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,4 (rx_delay=2.20s)
# 21:50:32> MLE_Node2 MLE Rx: message 4: 1,4,1760925032589.3364
# 21:50:34> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,5 (rx_delay=2.17s)
# 21:50:34> MLE_Node2 MLE Rx: message 5: 1,5,1760925034763.8428
# 21:50:36> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,6 (rx_delay=1.99s)
# 21:50:36> MLE_Node2 MLE Rx: message 6: 1,6,1760925036753.6619
# 21:50:39> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,8 (rx_delay=2.60s)
# 21:50:39> MLE_Node2 MLE Rx: message 7: 1,8,1760925039351.274
# 21:50:40> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,9 (rx_delay=1.54s)
# 21:50:40> MLE_Node2 MLE Rx: message 8: 1,9,1760925040888.8416
# 21:50:41> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,11 (rx_delay=0.49s)
# 21:50:41> MLE_Node2 MLE Rx: message 9: 1,11,1760925041383.151
# 21:50:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,12 (rx_delay=1.16s)
# 21:50:42> MLE_Node2 MLE Rx: message 10: 1,12,1760925042547.9028
# 21:50:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,13 (rx_delay=1.45s)
# 21:50:43> MLE_Node2 MLE Rx: message 11: 1,13,1760925043993.4397
# 21:50:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,14 (rx_delay=0.27s)
# 21:50:44> MLE_Node2 MLE Rx: message 12: 1,14,1760925044265.9885
# 21:50:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,14 (rx_delay=0.23s)
# 21:50:44> MLE_Node2 MLE Rx: message 13: 1,14,1760925044500.6902
# 21:50:45> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,15 (rx_delay=0.86s)
# 21:50:45> MLE_Node2 MLE Rx: message 14: 1,15,1760925045357.0154
# 21:50:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,16 (rx_delay=1.92s)
# 21:50:47> MLE_Node2 MLE Rx: message 15: 1,16,1760925047279.9116
# 21:50:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,17 (rx_delay=0.07s)
# 21:50:47> MLE_Node2 MLE Rx: message 16: 1,17,1760925047352.2437
# 21:50:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,19 (rx_delay=0.17s)
# 21:50:47> MLE_Node2 MLE Rx: message 17: 1,19,1760925047526.829
# 21:50:49> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,20 (rx_delay=2.15s)
# 21:50:49> MLE_Node2 MLE Rx: message 18: 1,20,1760925049677.7107
# 21:50:51> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,21 (rx_delay=2.17s)
# 21:50:51> MLE_Node2 MLE Rx: message 19: 1,21,1760925051849.1328
# 21:50:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,22 (rx_delay=1.13s)
# 21:50:52> MLE_Node2 MLE Rx: message 20: 1,22,1760925052983.4592
# 21:50:53> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,23 (rx_delay=0.97s)
# 21:50:53> MLE_Node2 MLE Rx: message 21: 1,23,1760925053955.972
# 21:50:54> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,24 (rx_delay=0.80s)
# 21:50:54> MLE_Node2 MLE Rx: message 22: 1,24,1760925054761.464
# 21:50:55> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,25 (rx_delay=0.52s)
# 21:50:55> MLE_Node2 MLE Rx: message 23: 1,25,1760925055285.6235
# 21:50:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,26 (rx_delay=1.71s)
# 21:50:56> MLE_Node2 MLE Rx: message 24: 1,26,1760925056993.435
# 21:50:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,27 (rx_delay=0.27s)
# 21:50:57> MLE_Node2 MLE Rx: message 25: 1,27,1760925057267.967
# 21:50:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,28 (rx_delay=0.27s)
# 21:50:57> MLE_Node2 MLE Rx: message 26: 1,28,1760925057534.6152
# 21:50:59> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,29 (rx_delay=2.41s)
# 21:50:59> MLE_Node2 MLE Rx: message 27: 1,29,1760925059945.857
# 21:51:00> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,29 (rx_delay=0.92s)
# 21:51:00> MLE_Node2 MLE Rx: message 28: 1,29,1760925060866.2827
# 21:51:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,31 (rx_delay=2.22s)
# 21:51:03> MLE_Node2 MLE Rx: message 29: 1,31,1760925063086.7798
# 21:51:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,32 (rx_delay=0.55s)
# 21:51:03> MLE_Node2 MLE Rx: message 30: 1,32,1760925063633.1091
# 21:51:06> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,33 (rx_delay=2.66s)
# 21:51:06> MLE_Node2 MLE Rx: message 31: 1,33,1760925066290.9512
# 21:51:08> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,34 (rx_delay=1.78s)
# 21:51:08> MLE_Node2 MLE Rx: message 32: 1,34,1760925068076.1877
# 21:51:10> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,35 (rx_delay=2.31s)
# 21:51:10> MLE_Node2 MLE Rx: message 33: 1,35,1760925070384.282
# 21:51:10> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,36 (rx_delay=0.04s)
# 21:51:10> MLE_Node2 MLE Rx: message 34: 1,36,1760925070422.7207
# 21:51:11> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,37 (rx_delay=0.58s)
# 21:51:11> MLE_Node2 MLE Rx: message 35: 1,37,1760925071008.33
# 21:51:12> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,39 (rx_delay=1.14s)
# 21:51:12> MLE_Node2 MLE Rx: message 36: 1,39,1760925072152.9346
# 21:51:12> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,41 (rx_delay=0.18s)
# 21:51:12> MLE_Node2 MLE Rx: message 37: 1,41,1760925072332.6245
# 21:51:14> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,42 (rx_delay=1.82s)
# 21:51:14> MLE_Node2 MLE Rx: message 38: 1,42,1760925074149.2683
# 21:51:14> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,44 (rx_delay=0.16s)
# 21:51:14> MLE_Node2 MLE Rx: message 39: 1,44,1760925074312.8738
# 21:51:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,45 (rx_delay=1.73s)
# 21:51:16> MLE_Node2 MLE Rx: message 40: 1,45,1760925076042.7627
# 21:51:17> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,45 (rx_delay=1.31s)
# 21:51:17> MLE_Node2 MLE Rx: message 41: 1,45,1760925077351.3242
# 21:51:18> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,46 (rx_delay=0.83s)
# 21:51:18> MLE_Node2 MLE Rx: message 42: 1,46,1760925078186.7168
# 21:51:19> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,47 (rx_delay=1.27s)
# 21:51:19> MLE_Node2 MLE Rx: message 43: 1,47,1760925079459.4758
# 21:51:20> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,48 (rx_delay=0.97s)
# 21:51:20> MLE_Node2 MLE Rx: message 44: 1,48,1760925080425.925
# 21:51:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,48 (rx_delay=2.98s)
# 21:51:23> MLE_Node2 MLE Rx: message 45: 1,48,1760925083401.839
# 21:51:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,50 (rx_delay=2.66s)
# 21:51:26> MLE_Node2 MLE Rx: message 46: 1,50,1760925086063.0725
# 21:51:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,51 (rx_delay=0.41s)
# 21:51:26> MLE_Node2 MLE Rx: message 47: 1,51,1760925086470.7898
# 21:51:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,52 (rx_delay=0.41s)
# 21:51:26> MLE_Node2 MLE Rx: message 48: 1,52,1760925086876.2942
# 21:51:28> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,53 (rx_delay=1.49s)
# 21:51:28> MLE_Node2 MLE Rx: message 49: 1,53,1760925088367.6575
# 21:51:29> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,54 (rx_delay=1.39s)
# 21:51:29> MLE_Node2 MLE Rx: message 50: 1,54,1760925089762.9912
# 21:51:30> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,55 (rx_delay=0.96s)
# 21:51:30> MLE_Node2 MLE Rx: message 51: 1,55,1760925090718.5857
# 21:51:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,56 (rx_delay=0.57s)
# 21:51:31> MLE_Node2 MLE Rx: message 52: 1,56,1760925091289.1023
# 21:51:34> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,57 (rx_delay=2.97s)
# 21:51:34> MLE_Node2 MLE Rx: message 53: 1,57,1760925094261.776
# 21:51:36> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,58 (rx_delay=2.29s)
# 21:51:36> MLE_Node2 MLE Rx: message 54: 1,58,1760925096554.216
# 21:51:36> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,59 (rx_delay=0.38s)
# 21:51:36> MLE_Node2 MLE Rx: message 55: 1,59,1760925096932.5056
# 21:51:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,60 (rx_delay=1.43s)
# 21:51:38> MLE_Node2 MLE Rx: message 56: 1,60,1760925098364.1265
# 21:51:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,61 (rx_delay=0.26s)
# 21:51:38> MLE_Node2 MLE Rx: message 57: 1,61,1760925098622.7102
# 21:51:39> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,62 (rx_delay=1.04s)
# 21:51:39> MLE_Node2 MLE Rx: message 58: 1,62,1760925099667.2524
# 21:51:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,64 (rx_delay=2.58s)
# 21:51:42> MLE_Node2 MLE Rx: message 59: 1,64,1760925102250.2307
# 21:51:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,65 (rx_delay=0.18s)
# 21:51:42> MLE_Node2 MLE Rx: message 60: 1,65,1760925102432.6487
# 21:51:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,67 (rx_delay=0.78s)
# 21:51:43> MLE_Node2 MLE Rx: message 61: 1,67,1760925103217.0176
# 21:51:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,68 (rx_delay=0.65s)
# 21:51:43> MLE_Node2 MLE Rx: message 62: 1,68,1760925103866.751
# 21:51:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,69 (rx_delay=0.95s)
# 21:51:44> MLE_Node2 MLE Rx: message 63: 1,69,1760925104819.1482
# 21:51:45> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,70 (rx_delay=0.80s)
# 21:51:45> MLE_Node2 MLE Rx: message 64: 1,70,1760925105617.3682
# 21:51:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,72 (rx_delay=0.41s)
# 21:51:46> MLE_Node2 MLE Rx: message 65: 1,72,1760925106024.7476
# 21:51:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,73 (rx_delay=0.04s)
# 21:51:46> MLE_Node2 MLE Rx: message 66: 1,73,1760925106063.7092
# 21:51:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,74 (rx_delay=1.68s)
# 21:51:47> MLE_Node2 MLE Rx: message 67: 1,74,1760925107746.4187
# 21:51:48> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,76 (rx_delay=0.43s)
# 21:51:48> MLE_Node2 MLE Rx: message 68: 1,76,1760925108172.4321
# 21:51:50> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,77 (rx_delay=1.99s)
# 21:51:50> MLE_Node2 MLE Rx: message 69: 1,77,1760925110157.9595
# 21:51:51> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,78 (rx_delay=1.42s)
# 21:51:51> MLE_Node2 MLE Rx: message 70: 1,78,1760925111578.2812
# 21:51:53> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,79 (rx_delay=2.28s)
# 21:51:53> MLE_Node2 MLE Rx: message 71: 1,79,1760925113857.678
# 21:51:55> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,80 (rx_delay=1.26s)
# 21:51:55> MLE_Node2 MLE Rx: message 72: 1,80,1760925115118.455
# 21:51:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,82 (rx_delay=1.51s)
# 21:51:56> MLE_Node2 MLE Rx: message 73: 1,82,1760925116634.1982
# 21:51:58> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,83 (rx_delay=1.63s)
# 21:51:58> MLE_Node2 MLE Rx: message 74: 1,83,1760925118266.9055
# 21:52:00> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,84 (rx_delay=2.51s)
# 21:52:00> MLE_Node2 MLE Rx: message 75: 1,84,1760925120781.0938
# 21:52:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,85 (rx_delay=2.28s)
# 21:52:03> MLE_Node2 MLE Rx: message 76: 1,85,1760925123059.8433
# 21:52:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,86 (rx_delay=0.17s)
# 21:52:03> MLE_Node2 MLE Rx: message 77: 1,86,1760925123231.325
# 21:52:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,87 (rx_delay=2.46s)
# 21:52:05> MLE_Node2 MLE Rx: message 78: 1,87,1760925125693.8699
# 21:52:08> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,88 (rx_delay=2.45s)
# 21:52:08> MLE_Node2 MLE Rx: message 79: 1,88,1760925128148.552
# 21:52:09> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,89 (rx_delay=0.97s)
# 21:52:09> MLE_Node2 MLE Rx: message 80: 1,89,1760925129117.1873
# 21:52:11> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,90 (rx_delay=2.53s)
# 21:52:11> MLE_Node2 MLE Rx: message 81: 1,90,1760925131652.3857
# 21:52:12> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,91 (rx_delay=1.01s)
# 21:52:12> MLE_Node2 MLE Rx: message 82: 1,91,1760925132659.5476
# 21:52:14> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,92 (rx_delay=1.72s)
# 21:52:14> MLE_Node2 MLE Rx: message 83: 1,92,1760925134375.452
# 21:52:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,94 (rx_delay=2.23s)
# 21:52:16> MLE_Node2 MLE Rx: message 84: 1,94,1760925136605.3435
# 21:52:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,95 (rx_delay=0.23s)
# 21:52:16> MLE_Node2 MLE Rx: message 85: 1,95,1760925136834.1145
# 21:52:18> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,96 (rx_delay=1.17s)
# 21:52:18> MLE_Node2 MLE Rx: message 86: 1,96,1760925138007.1682
# 21:52:19> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,97 (rx_delay=1.38s)
# 21:52:19> MLE_Node2 MLE Rx: message 87: 1,97,1760925139386.905
# 21:52:19> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,99 (rx_delay=0.25s)
# 21:52:19> MLE_Node2 MLE Rx: message 88: 1,99,1760925139639.2085

# %%
# Experiment 2: Two Nodes and Three Layers
# MLE_TR
# 
# DLE_TR
#
# PLE_TR

exp_out = EXP_Output()
# Node 1
AP_local_5 = ("127.0.0.1", 33333)
AP_remote_5 = ("127.0.0.1", 34000)

Socket_5 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_5 = PLE_TR("PLE_Node1", Socket_5, AP_remote_5, AP_local_5, exp_out)
DLE_3 = DLE_TR_FSM("DLE_Node1", PLE_5, exp_out)
MLE_3 = MLE_TR("MLE_Node1", 2, DLE_3, exp_out)

# Node 2
AP_local_6 = ("127.0.0.1", 34000)
AP_remote_6 = ("127.0.0.1", 33333)

Socket_6 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_6 = PLE_TR("PLE_Node2", Socket_6, AP_remote_6, AP_local_6, exp_out)
DLE_4 = DLE_TR_FSM("DLE_Node2", PLE_6, exp_out)
MLE_4 = MLE_TR("MLE_Node2", 2, DLE_4, exp_out)
# Out:
# Button(description='Send 100 messages from MLE_Node1.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# Button(description='Send 100 messages from MLE_Node2.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# 21:49:31> PLE_Node1: loop_Rx starting
# 21:49:31> PLE_Node1: loop_Tx starting
# 21:49:31> DLE_Node1: loop_Rx starting
# 21:49:31> DLE_Node1: loop_Tx starting
# 21:49:31> DLE_Node1: loop_FSM starting
# 21:49:31> DLE_Node1: loop_Timer starting
# 21:49:31> MLE_Node1: MLE loop_Rx starting
# 21:49:31> PLE_Node2: loop_Rx starting
# 21:49:31> PLE_Node2: loop_Tx starting
# 21:49:31> DLE_Node2: loop_Rx starting
# 21:49:31> DLE_Node2: loop_Tx starting
# 21:49:31> DLE_Node2: loop_FSM starting
# 21:49:31> DLE_Node2: loop_Timer starting
# 21:49:31> MLE_Node2: MLE loop_Rx starting
# 21:56:20> DLE_Node1 Tx: message 1: 2,0
# 21:56:20> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:20> DLE_Node1 FSM: to send: 2,0
# 21:56:20> PLE_Node1 Tx: message: 002,0
# 21:56:20> PLE_Node1 PLE: packet loss (15%)
# 21:56:26> DLE_Node1 FSM: state: 1 event type: 3
# 21:56:26> DLE_Node1 FSM: to resend frame 0 2,0
# 21:56:26> PLE_Node1 Tx: message: 002,0
# 21:56:26> PLE_Node1 PLE: duplicate transmission (5%)
# 21:56:26> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,0 (rx_delay=0.02s)
# 21:56:26> DLE_Node2 Rx: message 1: 002,0
# 21:56:26> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:26> DLE_Node2 FSM: received: 2,0
# 21:56:26> MLE_Node2 MLE Rx: message 1: 2,0,1760925386028.2053
# 21:56:26> PLE_Node2 Tx: message: 10
# 21:56:26> PLE_Node2 PLE: duplicate transmission (5%)
# 21:56:28> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,0 (rx_delay=1.99s)
# 21:56:28> DLE_Node2 Rx: message 2: 002,0
# 21:56:28> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:28> DLE_Node2 FSM: received: 2,0
# 21:56:28> DLE_Node2 FSM: received received frame 0 but expected 1
# 21:56:28> PLE_Node2 Tx: message: 10
# 21:56:28> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=2.11s)
# 21:56:28> DLE_Node1 Rx: message 1: 10
# 21:56:28> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:28> DLE_Node1 Tx: message 2: 2,1
# 21:56:28> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:28> DLE_Node1 FSM: to send: 2,1
# 21:56:28> PLE_Node1 Tx: message: 012,1
# 21:56:28> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=0.68s)
# 21:56:28> DLE_Node1 Rx: message 2: 10
# 21:56:28> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:28> ACK # 0 does not match local seq # 1
# 21:56:29> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,1 (rx_delay=1.63s)
# 21:56:29> DLE_Node2 Rx: message 3: 012,1
# 21:56:29> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:29> DLE_Node2 FSM: received: 2,1
# 21:56:29> MLE_Node2 MLE Rx: message 2: 2,1,1760925389776.3142
# 21:56:29> PLE_Node2 Tx: message: 11
# 21:56:30> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.92s)
# 21:56:30> DLE_Node1 Rx: message 3: 10
# 21:56:30> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:30> ACK # 0 does not match local seq # 1
# 21:56:31> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.13s)
# 21:56:31> DLE_Node1 Rx: message 4: 11
# 21:56:31> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:31> DLE_Node1 Tx: message 3: 2,2
# 21:56:31> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:31> DLE_Node1 FSM: to send: 2,2
# 21:56:31> PLE_Node1 Tx: message: 022,2
# 21:56:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,2 (rx_delay=1.95s)
# 21:56:33> DLE_Node2 Rx: message 4: 022,2
# 21:56:33> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:33> DLE_Node2 FSM: received: 2,2
# 21:56:33> MLE_Node2 MLE Rx: message 3: 2,2,1760925393830.0522
# 21:56:33> PLE_Node2 Tx: message: 12
# 21:56:34> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=0.48s)
# 21:56:34> DLE_Node1 Rx: message 5: 12
# 21:56:34> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:34> DLE_Node1 Tx: message 4: 2,3
# 21:56:34> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:34> DLE_Node1 FSM: to send: 2,3
# 21:56:34> PLE_Node1 Tx: message: 032,3
# 21:56:36> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,3 (rx_delay=2.56s)
# 21:56:36> DLE_Node2 Rx: message 5: 032,3
# 21:56:36> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:36> DLE_Node2 FSM: received: 2,3
# 21:56:36> PLE_Node2 Tx: message: 13
# 21:56:36> PLE_Node2 PLE: packet loss (15%)
# 21:56:36> MLE_Node2 MLE Rx: message 4: 2,3,1760925396877.1836
# 21:56:40> DLE_Node1 FSM: state: 1 event type: 3
# 21:56:40> DLE_Node1 FSM: to resend frame 3 2,3
# 21:56:40> PLE_Node1 Tx: message: 032,3
# 21:56:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,3 (rx_delay=0.70s)
# 21:56:40> DLE_Node2 Rx: message 6: 032,3
# 21:56:40> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:40> DLE_Node2 FSM: received: 2,3
# 21:56:40> DLE_Node2 FSM: received received frame 3 but expected 4
# 21:56:40> PLE_Node2 Tx: message: 13
# 21:56:41> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.62s)
# 21:56:41> DLE_Node1 Rx: message 6: 13
# 21:56:41> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:41> DLE_Node1 Tx: message 5: 2,4
# 21:56:41> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:41> DLE_Node1 FSM: to send: 2,4
# 21:56:41> PLE_Node1 Tx: message: 042,4
# 21:56:42> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,4 (rx_delay=1.17s)
# 21:56:42> DLE_Node2 Rx: message 7: 042,4
# 21:56:42> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:42> DLE_Node2 FSM: received: 2,4
# 21:56:42> MLE_Node2 MLE Rx: message 5: 2,4,1760925402522.029
# 21:56:42> PLE_Node2 Tx: message: 14
# 21:56:42> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.25s)
# 21:56:42> DLE_Node1 Rx: message 7: 14
# 21:56:42> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:42> DLE_Node1 Tx: message 6: 2,5
# 21:56:42> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:42> DLE_Node1 FSM: to send: 2,5
# 21:56:42> PLE_Node1 Tx: message: 052,5
# 21:56:45> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,5 (rx_delay=2.98s)
# 21:56:45> DLE_Node2 Rx: message 8: 052,5
# 21:56:45> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:45> DLE_Node2 FSM: received: 2,5
# 21:56:45> PLE_Node2 Tx: message: 15
# 21:56:45> MLE_Node2 MLE Rx: message 6: 2,5,1760925405748.9934
# 21:56:48> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=2.73s)
# 21:56:48> DLE_Node1 Rx: message 8: 15
# 21:56:48> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:48> DLE_Node1 Tx: message 7: 2,6
# 21:56:48> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:48> DLE_Node1 FSM: to send: 2,6
# 21:56:48> PLE_Node1 Tx: message: 062,6
# 21:56:48> DLE_Node1 FSM: state: 1 event type: 3
# 21:56:48> DLE_Node1 FSM: to resend frame 6 2,6
# 21:56:48> PLE_Node1 Tx: message: 062,6
# 21:56:48> PLE_Node1 PLE: duplicate transmission (5%)
# 21:56:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,6 (rx_delay=2.25s)
# 21:56:50> DLE_Node2 Rx: message 9: 062,6
# 21:56:50> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:50> DLE_Node2 FSM: received: 2,6
# 21:56:50> PLE_Node2 Tx: message: 16
# 21:56:50> MLE_Node2 MLE Rx: message 7: 2,6,1760925410729.7808
# 21:56:50> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=0.06s)
# 21:56:50> DLE_Node1 Rx: message 9: 16
# 21:56:50> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:50> DLE_Node1 Tx: message 8: 2,7
# 21:56:50> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:50> DLE_Node1 FSM: to send: 2,7
# 21:56:50> PLE_Node1 Tx: message: 072,7
# 21:56:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,6 (rx_delay=0.07s)
# 21:56:50> DLE_Node2 Rx: message 10: 062,6
# 21:56:50> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:50> DLE_Node2 FSM: received: 2,6
# 21:56:50> DLE_Node2 FSM: received received frame 6 but expected 7
# 21:56:50> PLE_Node2 Tx: message: 16
# 21:56:51> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,6 (rx_delay=0.75s)
# 21:56:51> DLE_Node2 Rx: message 11: 062,6
# 21:56:51> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:51> DLE_Node2 FSM: received: 2,6
# 21:56:51> DLE_Node2 FSM: received received frame 6 but expected 7
# 21:56:51> PLE_Node2 Tx: message: 16
# 21:56:51> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,7 (rx_delay=0.01s)
# 21:56:51> DLE_Node2 Rx: message 12: 072,7
# 21:56:51> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:51> DLE_Node2 FSM: received: 2,7
# 21:56:51> MLE_Node2 MLE Rx: message 8: 2,7,1760925411554.7017
# 21:56:51> PLE_Node2 Tx: message: 17
# 21:56:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.47s)
# 21:56:52> DLE_Node1 Rx: message 10: 16
# 21:56:52> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:52> ACK # 6 does not match local seq # 7
# 21:56:54> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.93s)
# 21:56:54> DLE_Node1 Rx: message 11: 16
# 21:56:54> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:54> ACK # 6 does not match local seq # 7
# 21:56:56> DLE_Node1 FSM: state: 1 event type: 3
# 21:56:56> DLE_Node1 FSM: to resend frame 7 2,7
# 21:56:56> PLE_Node1 Tx: message: 072,7
# 21:56:56> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.34s)
# 21:56:56> DLE_Node1 Rx: message 12: 17
# 21:56:56> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:56> DLE_Node1 Tx: message 9: 2,8
# 21:56:56> DLE_Node1 FSM: state: 0 event type: 0
# 21:56:56> DLE_Node1 FSM: to send: 2,8
# 21:56:56> PLE_Node1 Tx: message: 082,8
# 21:56:56> PLE_Node1 PLE: duplicate transmission (5%)
# 21:56:56> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,7 (rx_delay=0.42s)
# 21:56:56> DLE_Node2 Rx: message 13: 072,7
# 21:56:56> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:56> DLE_Node2 FSM: received: 2,7
# 21:56:56> DLE_Node2 FSM: received received frame 7 but expected 8
# 21:56:56> PLE_Node2 Tx: message: 17
# 21:56:57> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,8 (rx_delay=0.36s)
# 21:56:57> DLE_Node2 Rx: message 14: 082,8
# 21:56:57> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:57> DLE_Node2 FSM: received: 2,8
# 21:56:57> PLE_Node2 Tx: message: 18
# 21:56:57> MLE_Node2 MLE Rx: message 9: 2,8,1760925417308.9685
# 21:56:57> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.98s)
# 21:56:57> DLE_Node1 Rx: message 13: 17
# 21:56:57> DLE_Node1 FSM: state: 1 event type: 2
# 21:56:57> ACK # 7 does not match local seq # 8
# 21:56:57> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,8 (rx_delay=0.68s)
# 21:56:57> DLE_Node2 Rx: message 15: 082,8
# 21:56:57> DLE_Node2 FSM: state: 0 event type: 1
# 21:56:57> DLE_Node2 FSM: received: 2,8
# 21:56:57> DLE_Node2 FSM: received received frame 8 but expected 9
# 21:56:57> PLE_Node2 Tx: message: 18
# 21:57:00> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=2.68s)
# 21:57:00> DLE_Node1 Rx: message 14: 18
# 21:57:00> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:00> DLE_Node1 Tx: message 10: 2,9
# 21:57:00> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:00> DLE_Node1 FSM: to send: 2,9
# 21:57:00> PLE_Node1 Tx: message: 092,9
# 21:57:01> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=0.58s)
# 21:57:01> DLE_Node1 Rx: message 15: 18
# 21:57:01> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:01> ACK # 8 does not match local seq # 9
# 21:57:02> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,9 (rx_delay=2.26s)
# 21:57:02> DLE_Node2 Rx: message 16: 092,9
# 21:57:02> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:02> DLE_Node2 FSM: received: 2,9
# 21:57:02> MLE_Node2 MLE Rx: message 10: 2,9,1760925422864.6787
# 21:57:02> PLE_Node2 Tx: message: 19
# 21:57:03> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.70s)
# 21:57:03> DLE_Node1 Rx: message 16: 19
# 21:57:03> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:03> DLE_Node1 Tx: message 11: 2,10
# 21:57:03> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:03> DLE_Node1 FSM: to send: 2,10
# 21:57:03> PLE_Node1 Tx: message: 002,10
# 21:57:06> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,10 (rx_delay=2.98s)
# 21:57:06> DLE_Node2 Rx: message 17: 002,10
# 21:57:06> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:06> DLE_Node2 FSM: received: 2,10
# 21:57:06> MLE_Node2 MLE Rx: message 11: 2,10,1760925426547.656
# 21:57:06> PLE_Node2 Tx: message: 10
# 21:57:06> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=0.41s)
# 21:57:06> DLE_Node1 Rx: message 17: 10
# 21:57:06> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:06> DLE_Node1 Tx: message 12: 2,11
# 21:57:06> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:06> DLE_Node1 FSM: to send: 2,11
# 21:57:06> PLE_Node1 Tx: message: 012,11
# 21:57:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,11 (rx_delay=2.86s)
# 21:57:09> DLE_Node2 Rx: message 18: 012,11
# 21:57:09> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:09> DLE_Node2 FSM: received: 2,11
# 21:57:09> MLE_Node2 MLE Rx: message 12: 2,11,1760925429819.6196
# 21:57:09> PLE_Node2 Tx: message: 11
# 21:57:09> PLE_Node2 PLE: packet loss (15%)
# 21:57:12> DLE_Node1 FSM: state: 1 event type: 3
# 21:57:12> DLE_Node1 FSM: to resend frame 1 2,11
# 21:57:12> PLE_Node1 Tx: message: 012,11
# 21:57:13> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,11 (rx_delay=1.31s)
# 21:57:13> DLE_Node2 Rx: message 19: 012,11
# 21:57:13> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:13> DLE_Node2 FSM: received: 2,11
# 21:57:13> DLE_Node2 FSM: received received frame 1 but expected 2
# 21:57:13> PLE_Node2 Tx: message: 11
# 21:57:13> PLE_Node2 PLE: packet loss (15%)
# 21:57:18> DLE_Node1 FSM: state: 1 event type: 3
# 21:57:18> DLE_Node1 FSM: to resend frame 1 2,11
# 21:57:18> PLE_Node1 Tx: message: 012,11
# 21:57:19> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,11 (rx_delay=1.61s)
# 21:57:19> DLE_Node2 Rx: message 20: 012,11
# 21:57:19> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:19> DLE_Node2 FSM: received: 2,11
# 21:57:19> DLE_Node2 FSM: received received frame 1 but expected 2
# 21:57:19> PLE_Node2 Tx: message: 11
# 21:57:20> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.46s)
# 21:57:20> DLE_Node1 Rx: message 18: 11
# 21:57:20> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:20> DLE_Node1 Tx: message 13: 2,12
# 21:57:20> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:20> DLE_Node1 FSM: to send: 2,12
# 21:57:20> PLE_Node1 Tx: message: 022,12
# 21:57:22> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,12 (rx_delay=2.61s)
# 21:57:22> DLE_Node2 Rx: message 21: 022,12
# 21:57:22> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:22> DLE_Node2 FSM: received: 2,12
# 21:57:22> MLE_Node2 MLE Rx: message 13: 2,12,1760925442723.6694
# 21:57:22> PLE_Node2 Tx: message: 12
# 21:57:24> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=1.33s)
# 21:57:24> DLE_Node1 Rx: message 19: 12
# 21:57:24> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:24> DLE_Node1 Tx: message 14: 2,13
# 21:57:24> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:24> DLE_Node1 FSM: to send: 2,13
# 21:57:24> PLE_Node1 Tx: message: 032,13
# 21:57:25> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,13 (rx_delay=1.50s)
# 21:57:25> DLE_Node2 Rx: message 22: 032,13
# 21:57:25> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:25> DLE_Node2 FSM: received: 2,13
# 21:57:25> MLE_Node2 MLE Rx: message 14: 2,13,1760925445549.088
# 21:57:25> PLE_Node2 Tx: message: 13
# 21:57:25> PLE_Node2 PLE: packet loss (15%)
# 21:57:30> DLE_Node1 FSM: state: 1 event type: 3
# 21:57:30> DLE_Node1 FSM: to resend frame 3 2,13
# 21:57:30> PLE_Node1 Tx: message: 032,13
# 21:57:31> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,13 (rx_delay=1.86s)
# 21:57:31> DLE_Node2 Rx: message 23: 032,13
# 21:57:31> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:31> DLE_Node2 FSM: received: 2,13
# 21:57:31> DLE_Node2 FSM: received received frame 3 but expected 4
# 21:57:31> PLE_Node2 Tx: message: 13
# 21:57:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.27s)
# 21:57:33> DLE_Node1 Rx: message 20: 13
# 21:57:33> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:33> DLE_Node1 Tx: message 15: 2,14
# 21:57:33> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:33> DLE_Node1 FSM: to send: 2,14
# 21:57:33> PLE_Node1 Tx: message: 042,14
# 21:57:34> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,14 (rx_delay=1.68s)
# 21:57:34> DLE_Node2 Rx: message 24: 042,14
# 21:57:34> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:34> DLE_Node2 FSM: received: 2,14
# 21:57:34> MLE_Node2 MLE Rx: message 15: 2,14,1760925454857.8767
# 21:57:34> PLE_Node2 Tx: message: 14
# 21:57:34> PLE_Node2 PLE: packet loss (15%)
# 21:57:39> DLE_Node1 FSM: state: 1 event type: 3
# 21:57:39> DLE_Node1 FSM: to resend frame 4 2,14
# 21:57:39> PLE_Node1 Tx: message: 042,14
# 21:57:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,14 (rx_delay=1.85s)
# 21:57:40> DLE_Node2 Rx: message 25: 042,14
# 21:57:40> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:40> DLE_Node2 FSM: received: 2,14
# 21:57:40> DLE_Node2 FSM: received received frame 4 but expected 5
# 21:57:40> PLE_Node2 Tx: message: 14
# 21:57:40> PLE_Node2 PLE: duplicate transmission (5%)
# 21:57:41> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.98s)
# 21:57:41> DLE_Node1 Rx: message 21: 14
# 21:57:41> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:41> DLE_Node1 Tx: message 16: 2,15
# 21:57:41> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:41> DLE_Node1 FSM: to send: 2,15
# 21:57:41> PLE_Node1 Tx: message: 052,15
# 21:57:42> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.23s)
# 21:57:42> DLE_Node1 Rx: message 22: 14
# 21:57:42> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:42> ACK # 4 does not match local seq # 5
# 21:57:42> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,15 (rx_delay=1.09s)
# 21:57:42> DLE_Node2 Rx: message 26: 052,15
# 21:57:42> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:42> DLE_Node2 FSM: received: 2,15
# 21:57:42> MLE_Node2 MLE Rx: message 16: 2,15,1760925462972.7886
# 21:57:42> PLE_Node2 Tx: message: 15
# 21:57:45> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=2.10s)
# 21:57:45> DLE_Node1 Rx: message 23: 15
# 21:57:45> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:45> DLE_Node1 Tx: message 17: 2,16
# 21:57:45> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:45> DLE_Node1 FSM: to send: 2,16
# 21:57:45> PLE_Node1 Tx: message: 062,16
# 21:57:46> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,16 (rx_delay=1.78s)
# 21:57:46> DLE_Node2 Rx: message 27: 062,16
# 21:57:46> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:46> DLE_Node2 FSM: received: 2,16
# 21:57:46> MLE_Node2 MLE Rx: message 17: 2,16,1760925466850.1716
# 21:57:46> PLE_Node2 Tx: message: 16
# 21:57:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=2.55s)
# 21:57:49> DLE_Node1 Rx: message 24: 16
# 21:57:49> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:49> DLE_Node1 Tx: message 18: 2,17
# 21:57:49> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:49> DLE_Node1 FSM: to send: 2,17
# 21:57:49> PLE_Node1 Tx: message: 072,17
# 21:57:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,17 (rx_delay=1.05s)
# 21:57:50> DLE_Node2 Rx: message 28: 072,17
# 21:57:50> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:50> DLE_Node2 FSM: received: 2,17
# 21:57:50> MLE_Node2 MLE Rx: message 18: 2,17,1760925470446.6956
# 21:57:50> PLE_Node2 Tx: message: 17
# 21:57:53> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.64s)
# 21:57:53> DLE_Node1 Rx: message 25: 17
# 21:57:53> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:53> DLE_Node1 Tx: message 19: 2,18
# 21:57:53> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:53> DLE_Node1 FSM: to send: 2,18
# 21:57:53> PLE_Node1 Tx: message: 082,18
# 21:57:54> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,18 (rx_delay=1.34s)
# 21:57:54> DLE_Node2 Rx: message 29: 082,18
# 21:57:54> DLE_Node2 FSM: state: 0 event type: 1
# 21:57:54> DLE_Node2 FSM: received: 2,18
# 21:57:54> PLE_Node2 Tx: message: 18
# 21:57:54> MLE_Node2 MLE Rx: message 19: 2,18,1760925474436.515
# 21:57:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.04s)
# 21:57:55> DLE_Node1 Rx: message 26: 18
# 21:57:55> DLE_Node1 FSM: state: 1 event type: 2
# 21:57:55> DLE_Node1 Tx: message 20: 2,19
# 21:57:55> DLE_Node1 FSM: state: 0 event type: 0
# 21:57:55> DLE_Node1 FSM: to send: 2,19
# 21:57:55> PLE_Node1 Tx: message: 092,19
# 21:57:55> PLE_Node1 PLE: packet loss (15%)
# 21:58:01> DLE_Node1 FSM: state: 1 event type: 3
# 21:58:01> DLE_Node1 FSM: to resend frame 9 2,19
# 21:58:01> PLE_Node1 Tx: message: 092,19
# 21:58:03> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,19 (rx_delay=2.04s)
# 21:58:03> DLE_Node2 Rx: message 30: 092,19
# 21:58:03> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:03> DLE_Node2 FSM: received: 2,19
# 21:58:03> PLE_Node2 Tx: message: 19
# 21:58:03> MLE_Node2 MLE Rx: message 20: 2,19,1760925483111.988
# 21:58:04> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=1.44s)
# 21:58:04> DLE_Node1 Rx: message 27: 19
# 21:58:04> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:04> DLE_Node1 Tx: message 21: 2,20
# 21:58:04> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:04> DLE_Node1 FSM: to send: 2,20
# 21:58:04> PLE_Node1 Tx: message: 002,20
# 21:58:05> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,20 (rx_delay=1.35s)
# 21:58:05> DLE_Node2 Rx: message 31: 002,20
# 21:58:05> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:05> DLE_Node2 FSM: received: 2,20
# 21:58:05> PLE_Node2 Tx: message: 10
# 21:58:05> MLE_Node2 MLE Rx: message 21: 2,20,1760925485902.134
# 21:58:08> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=2.55s)
# 21:58:08> DLE_Node1 Rx: message 28: 10
# 21:58:08> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:08> DLE_Node1 Tx: message 22: 2,21
# 21:58:08> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:08> DLE_Node1 FSM: to send: 2,21
# 21:58:08> PLE_Node1 Tx: message: 012,21
# 21:58:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,21 (rx_delay=0.59s)
# 21:58:09> DLE_Node2 Rx: message 32: 012,21
# 21:58:09> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:09> DLE_Node2 FSM: received: 2,21
# 21:58:09> MLE_Node2 MLE Rx: message 22: 2,21,1760925489043.479
# 21:58:09> PLE_Node2 Tx: message: 11
# 21:58:09> PLE_Node2 PLE: packet loss (15%)
# 21:58:14> DLE_Node1 FSM: state: 1 event type: 3
# 21:58:14> DLE_Node1 FSM: to resend frame 1 2,21
# 21:58:14> PLE_Node1 Tx: message: 012,21
# 21:58:16> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,21 (rx_delay=2.34s)
# 21:58:16> DLE_Node2 Rx: message 33: 012,21
# 21:58:16> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:16> DLE_Node2 FSM: received: 2,21
# 21:58:16> DLE_Node2 FSM: received received frame 1 but expected 2
# 21:58:16> PLE_Node2 Tx: message: 11
# 21:58:16> PLE_Node2 PLE: packet loss (15%)
# 21:58:19> DLE_Node1 FSM: state: 1 event type: 3
# 21:58:19> DLE_Node1 FSM: to resend frame 1 2,21
# 21:58:19> PLE_Node1 Tx: message: 012,21
# 21:58:20> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,21 (rx_delay=1.23s)
# 21:58:20> DLE_Node2 Rx: message 34: 012,21
# 21:58:20> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:20> DLE_Node2 FSM: received: 2,21
# 21:58:20> DLE_Node2 FSM: received received frame 1 but expected 2
# 21:58:20> PLE_Node2 Tx: message: 11
# 21:58:21> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.86s)
# 21:58:21> DLE_Node1 Rx: message 29: 11
# 21:58:21> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:21> DLE_Node1 Tx: message 23: 2,22
# 21:58:21> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:21> DLE_Node1 FSM: to send: 2,22
# 21:58:21> PLE_Node1 Tx: message: 022,22
# 21:58:23> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,22 (rx_delay=1.95s)
# 21:58:23> DLE_Node2 Rx: message 35: 022,22
# 21:58:23> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:23> DLE_Node2 FSM: received: 2,22
# 21:58:23> MLE_Node2 MLE Rx: message 23: 2,22,1760925503627.0188
# 21:58:23> PLE_Node2 Tx: message: 12
# 21:58:26> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=2.96s)
# 21:58:26> DLE_Node1 Rx: message 30: 12
# 21:58:26> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:26> DLE_Node1 Tx: message 24: 2,23
# 21:58:26> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:26> DLE_Node1 FSM: to send: 2,23
# 21:58:26> PLE_Node1 Tx: message: 032,23
# 21:58:26> PLE_Node1 PLE: packet loss (15%)
# 21:58:32> DLE_Node1 FSM: state: 1 event type: 3
# 21:58:32> DLE_Node1 FSM: to resend frame 3 2,23
# 21:58:32> PLE_Node1 Tx: message: 032,23
# 21:58:32> PLE_Node1 PLE: packet loss (15%)
# 21:58:37> DLE_Node1 FSM: state: 1 event type: 3
# 21:58:37> DLE_Node1 FSM: to resend frame 3 2,23
# 21:58:37> PLE_Node1 Tx: message: 032,23
# 21:58:38> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,23 (rx_delay=1.14s)
# 21:58:38> DLE_Node2 Rx: message 36: 032,23
# 21:58:38> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:38> DLE_Node2 FSM: received: 2,23
# 21:58:38> MLE_Node2 MLE Rx: message 24: 2,23,1760925518739.4124
# 21:58:38> PLE_Node2 Tx: message: 13
# 21:58:38> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.02s)
# 21:58:38> DLE_Node1 Rx: message 31: 13
# 21:58:38> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:38> DLE_Node1 Tx: message 25: 2,24
# 21:58:38> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:38> DLE_Node1 FSM: to send: 2,24
# 21:58:38> PLE_Node1 Tx: message: 042,24
# 21:58:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,24 (rx_delay=2.07s)
# 21:58:40> DLE_Node2 Rx: message 37: 042,24
# 21:58:40> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:40> DLE_Node2 FSM: received: 2,24
# 21:58:40> MLE_Node2 MLE Rx: message 25: 2,24,1760925520822.1472
# 21:58:40> PLE_Node2 Tx: message: 14
# 21:58:43> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.37s)
# 21:58:43> DLE_Node1 Rx: message 32: 14
# 21:58:43> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:43> DLE_Node1 Tx: message 26: 2,25
# 21:58:43> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:43> DLE_Node1 FSM: to send: 2,25
# 21:58:43> PLE_Node1 Tx: message: 052,25
# 21:58:45> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,25 (rx_delay=1.88s)
# 21:58:45> DLE_Node2 Rx: message 38: 052,25
# 21:58:45> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:45> DLE_Node2 FSM: received: 2,25
# 21:58:45> PLE_Node2 Tx: message: 15
# 21:58:45> MLE_Node2 MLE Rx: message 26: 2,25,1760925525066.017
# 21:58:45> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=0.40s)
# 21:58:45> DLE_Node1 Rx: message 33: 15
# 21:58:45> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:45> DLE_Node1 Tx: message 27: 2,26
# 21:58:45> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:45> DLE_Node1 FSM: to send: 2,26
# 21:58:45> PLE_Node1 Tx: message: 062,26
# 21:58:48> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,26 (rx_delay=2.72s)
# 21:58:48> DLE_Node2 Rx: message 39: 062,26
# 21:58:48> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:48> DLE_Node2 FSM: received: 2,26
# 21:58:48> MLE_Node2 MLE Rx: message 27: 2,26,1760925528190.0857
# 21:58:48> PLE_Node2 Tx: message: 16
# 21:58:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.06s)
# 21:58:49> DLE_Node1 Rx: message 34: 16
# 21:58:49> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:49> DLE_Node1 Tx: message 28: 2,27
# 21:58:49> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:49> DLE_Node1 FSM: to send: 2,27
# 21:58:49> PLE_Node1 Tx: message: 072,27
# 21:58:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,27 (rx_delay=1.68s)
# 21:58:50> DLE_Node2 Rx: message 40: 072,27
# 21:58:50> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:50> DLE_Node2 FSM: received: 2,27
# 21:58:50> MLE_Node2 MLE Rx: message 28: 2,27,1760925530926.761
# 21:58:50> PLE_Node2 Tx: message: 17
# 21:58:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=1.12s)
# 21:58:52> DLE_Node1 Rx: message 35: 17
# 21:58:52> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:52> DLE_Node1 Tx: message 29: 2,28
# 21:58:52> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:52> DLE_Node1 FSM: to send: 2,28
# 21:58:52> PLE_Node1 Tx: message: 082,28
# 21:58:53> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,28 (rx_delay=1.94s)
# 21:58:53> DLE_Node2 Rx: message 41: 082,28
# 21:58:53> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:53> DLE_Node2 FSM: received: 2,28
# 21:58:53> MLE_Node2 MLE Rx: message 29: 2,28,1760925533984.3848
# 21:58:53> PLE_Node2 Tx: message: 18
# 21:58:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.55s)
# 21:58:55> DLE_Node1 Rx: message 36: 18
# 21:58:55> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:55> DLE_Node1 Tx: message 30: 2,29
# 21:58:55> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:55> DLE_Node1 FSM: to send: 2,29
# 21:58:55> PLE_Node1 Tx: message: 092,29
# 21:58:56> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,29 (rx_delay=1.30s)
# 21:58:56> DLE_Node2 Rx: message 42: 092,29
# 21:58:56> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:56> DLE_Node2 FSM: received: 2,29
# 21:58:56> MLE_Node2 MLE Rx: message 30: 2,29,1760925536841.8328
# 21:58:56> PLE_Node2 Tx: message: 19
# 21:58:56> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.09s)
# 21:58:56> DLE_Node1 Rx: message 37: 19
# 21:58:56> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:56> DLE_Node1 Tx: message 31: 2,30
# 21:58:56> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:56> DLE_Node1 FSM: to send: 2,30
# 21:58:56> PLE_Node1 Tx: message: 002,30
# 21:58:58> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,30 (rx_delay=1.83s)
# 21:58:58> DLE_Node2 Rx: message 43: 002,30
# 21:58:58> DLE_Node2 FSM: state: 0 event type: 1
# 21:58:58> DLE_Node2 FSM: received: 2,30
# 21:58:58> PLE_Node2 Tx: message: 10
# 21:58:58> MLE_Node2 MLE Rx: message 31: 2,30,1760925538765.5708
# 21:58:59> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=0.69s)
# 21:58:59> DLE_Node1 Rx: message 38: 10
# 21:58:59> DLE_Node1 FSM: state: 1 event type: 2
# 21:58:59> DLE_Node1 Tx: message 32: 2,31
# 21:58:59> DLE_Node1 FSM: state: 0 event type: 0
# 21:58:59> DLE_Node1 FSM: to send: 2,31
# 21:58:59> PLE_Node1 Tx: message: 012,31
# 21:58:59> PLE_Node1 PLE: packet loss (15%)
# 21:59:05> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:05> DLE_Node1 FSM: to resend frame 1 2,31
# 21:59:05> PLE_Node1 Tx: message: 012,31
# 21:59:06> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,31 (rx_delay=1.13s)
# 21:59:06> DLE_Node2 Rx: message 44: 012,31
# 21:59:06> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:06> DLE_Node2 FSM: received: 2,31
# 21:59:06> MLE_Node2 MLE Rx: message 32: 2,31,1760925546244.4922
# 21:59:06> PLE_Node2 Tx: message: 11
# 21:59:07> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.60s)
# 21:59:07> DLE_Node1 Rx: message 39: 11
# 21:59:07> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:07> DLE_Node1 Tx: message 33: 2,32
# 21:59:07> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:07> DLE_Node1 FSM: to send: 2,32
# 21:59:07> PLE_Node1 Tx: message: 022,32
# 21:59:08> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,32 (rx_delay=0.83s)
# 21:59:08> DLE_Node2 Rx: message 45: 022,32
# 21:59:08> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:08> DLE_Node2 FSM: received: 2,32
# 21:59:08> MLE_Node2 MLE Rx: message 33: 2,32,1760925548681.1677
# 21:59:08> PLE_Node2 Tx: message: 12
# 21:59:09> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=0.85s)
# 21:59:09> DLE_Node1 Rx: message 40: 12
# 21:59:09> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:09> DLE_Node1 Tx: message 34: 2,33
# 21:59:09> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:09> DLE_Node1 FSM: to send: 2,33
# 21:59:09> PLE_Node1 Tx: message: 032,33
# 21:59:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,33 (rx_delay=0.07s)
# 21:59:09> DLE_Node2 Rx: message 46: 032,33
# 21:59:09> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:09> DLE_Node2 FSM: received: 2,33
# 21:59:09> PLE_Node2 Tx: message: 13
# 21:59:09> MLE_Node2 MLE Rx: message 34: 2,33,1760925549609.0825
# 21:59:10> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.76s)
# 21:59:10> DLE_Node1 Rx: message 41: 13
# 21:59:10> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:10> DLE_Node1 Tx: message 35: 2,34
# 21:59:10> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:10> DLE_Node1 FSM: to send: 2,34
# 21:59:10> PLE_Node1 Tx: message: 042,34
# 21:59:10> PLE_Node1 PLE: packet loss (15%)
# 21:59:16> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:16> DLE_Node1 FSM: to resend frame 4 2,34
# 21:59:16> PLE_Node1 Tx: message: 042,34
# 21:59:17> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,34 (rx_delay=1.07s)
# 21:59:17> DLE_Node2 Rx: message 47: 042,34
# 21:59:17> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:17> DLE_Node2 FSM: received: 2,34
# 21:59:17> PLE_Node2 Tx: message: 14
# 21:59:17> MLE_Node2 MLE Rx: message 35: 2,34,1760925557187.9893
# 21:59:17> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.16s)
# 21:59:17> DLE_Node1 Rx: message 42: 14
# 21:59:17> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:17> DLE_Node1 Tx: message 36: 2,35
# 21:59:17> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:17> DLE_Node1 FSM: to send: 2,35
# 21:59:17> PLE_Node1 Tx: message: 052,35
# 21:59:17> PLE_Node1 PLE: packet loss (15%)
# 21:59:23> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:23> DLE_Node1 FSM: to resend frame 5 2,35
# 21:59:23> PLE_Node1 Tx: message: 052,35
# 21:59:23> PLE_Node1 PLE: packet loss (15%)
# 21:59:28> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:28> DLE_Node1 FSM: to resend frame 5 2,35
# 21:59:28> PLE_Node1 Tx: message: 052,35
# 21:59:29> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,35 (rx_delay=0.78s)
# 21:59:29> DLE_Node2 Rx: message 48: 052,35
# 21:59:29> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:29> DLE_Node2 FSM: received: 2,35
# 21:59:29> MLE_Node2 MLE Rx: message 36: 2,35,1760925569410.6348
# 21:59:29> PLE_Node2 Tx: message: 15
# 21:59:29> PLE_Node2 PLE: packet loss (15%)
# 21:59:34> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:34> DLE_Node1 FSM: to resend frame 5 2,35
# 21:59:34> PLE_Node1 Tx: message: 052,35
# 21:59:35> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,35 (rx_delay=1.37s)
# 21:59:35> DLE_Node2 Rx: message 49: 052,35
# 21:59:35> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:35> DLE_Node2 FSM: received: 2,35
# 21:59:35> DLE_Node2 FSM: received received frame 5 but expected 6
# 21:59:35> PLE_Node2 Tx: message: 15
# 21:59:36> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.45s)
# 21:59:36> DLE_Node1 Rx: message 43: 15
# 21:59:36> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:36> DLE_Node1 Tx: message 37: 2,36
# 21:59:36> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:36> DLE_Node1 FSM: to send: 2,36
# 21:59:36> PLE_Node1 Tx: message: 062,36
# 21:59:39> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,36 (rx_delay=2.92s)
# 21:59:39> DLE_Node2 Rx: message 50: 062,36
# 21:59:39> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:39> DLE_Node2 FSM: received: 2,36
# 21:59:39> MLE_Node2 MLE Rx: message 37: 2,36,1760925579876.5752
# 21:59:39> PLE_Node2 Tx: message: 16
# 21:59:40> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=0.41s)
# 21:59:40> DLE_Node1 Rx: message 44: 16
# 21:59:40> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:40> DLE_Node1 Tx: message 38: 2,37
# 21:59:40> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:40> DLE_Node1 FSM: to send: 2,37
# 21:59:40> PLE_Node1 Tx: message: 072,37
# 21:59:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,37 (rx_delay=0.43s)
# 21:59:40> DLE_Node2 Rx: message 51: 072,37
# 21:59:40> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:40> DLE_Node2 FSM: received: 2,37
# 21:59:40> MLE_Node2 MLE Rx: message 38: 2,37,1760925580721.45
# 21:59:40> PLE_Node2 Tx: message: 17
# 21:59:41> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.91s)
# 21:59:41> DLE_Node1 Rx: message 45: 17
# 21:59:41> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:41> DLE_Node1 Tx: message 39: 2,38
# 21:59:41> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:41> DLE_Node1 FSM: to send: 2,38
# 21:59:41> PLE_Node1 Tx: message: 082,38
# 21:59:43> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,38 (rx_delay=1.61s)
# 21:59:43> DLE_Node2 Rx: message 52: 082,38
# 21:59:43> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:43> DLE_Node2 FSM: received: 2,38
# 21:59:43> PLE_Node2 Tx: message: 18
# 21:59:43> MLE_Node2 MLE Rx: message 39: 2,38,1760925583244.802
# 21:59:45> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=2.36s)
# 21:59:45> DLE_Node1 Rx: message 46: 18
# 21:59:45> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:45> DLE_Node1 Tx: message 40: 2,39
# 21:59:45> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:45> DLE_Node1 FSM: to send: 2,39
# 21:59:45> PLE_Node1 Tx: message: 092,39
# 21:59:45> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,39 (rx_delay=0.23s)
# 21:59:45> DLE_Node2 Rx: message 53: 092,39
# 21:59:45> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:45> DLE_Node2 FSM: received: 2,39
# 21:59:45> PLE_Node2 Tx: message: 19
# 21:59:45> MLE_Node2 MLE Rx: message 40: 2,39,1760925585838.0432
# 21:59:46> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=1.02s)
# 21:59:46> DLE_Node1 Rx: message 47: 19
# 21:59:46> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:46> DLE_Node1 Tx: message 41: 2,40
# 21:59:46> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:46> DLE_Node1 FSM: to send: 2,40
# 21:59:46> PLE_Node1 Tx: message: 002,40
# 21:59:49> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,40 (rx_delay=2.34s)
# 21:59:49> DLE_Node2 Rx: message 54: 002,40
# 21:59:49> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:49> DLE_Node2 FSM: received: 2,40
# 21:59:49> MLE_Node2 MLE Rx: message 41: 2,40,1760925589197.0032
# 21:59:49> PLE_Node2 Tx: message: 10
# 21:59:50> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.16s)
# 21:59:50> DLE_Node1 Rx: message 48: 10
# 21:59:50> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:50> DLE_Node1 Tx: message 42: 2,41
# 21:59:50> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:50> DLE_Node1 FSM: to send: 2,41
# 21:59:50> PLE_Node1 Tx: message: 012,41
# 21:59:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,41 (rx_delay=1.72s)
# 21:59:52> DLE_Node2 Rx: message 55: 012,41
# 21:59:52> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:52> DLE_Node2 FSM: received: 2,41
# 21:59:52> MLE_Node2 MLE Rx: message 42: 2,41,1760925592084.049
# 21:59:52> PLE_Node2 Tx: message: 11
# 21:59:52> PLE_Node2 PLE: packet loss (15%)
# 21:59:56> DLE_Node1 FSM: state: 1 event type: 3
# 21:59:56> DLE_Node1 FSM: to resend frame 1 2,41
# 21:59:56> PLE_Node1 Tx: message: 012,41
# 21:59:57> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,41 (rx_delay=1.27s)
# 21:59:57> DLE_Node2 Rx: message 56: 012,41
# 21:59:57> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:57> DLE_Node2 FSM: received: 2,41
# 21:59:57> DLE_Node2 FSM: received received frame 1 but expected 2
# 21:59:57> PLE_Node2 Tx: message: 11
# 21:59:58> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.05s)
# 21:59:58> DLE_Node1 Rx: message 49: 11
# 21:59:58> DLE_Node1 FSM: state: 1 event type: 2
# 21:59:58> DLE_Node1 Tx: message 43: 2,42
# 21:59:58> DLE_Node1 FSM: state: 0 event type: 0
# 21:59:58> DLE_Node1 FSM: to send: 2,42
# 21:59:58> PLE_Node1 Tx: message: 022,42
# 21:59:59> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,42 (rx_delay=1.09s)
# 21:59:59> DLE_Node2 Rx: message 57: 022,42
# 21:59:59> DLE_Node2 FSM: state: 0 event type: 1
# 21:59:59> DLE_Node2 FSM: received: 2,42
# 21:59:59> MLE_Node2 MLE Rx: message 43: 2,42,1760925599553.2217
# 21:59:59> PLE_Node2 Tx: message: 12
# 22:00:01> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=2.40s)
# 22:00:01> DLE_Node1 Rx: message 50: 12
# 22:00:01> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:01> DLE_Node1 Tx: message 44: 2,43
# 22:00:01> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:01> DLE_Node1 FSM: to send: 2,43
# 22:00:01> PLE_Node1 Tx: message: 032,43
# 22:00:04> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,43 (rx_delay=2.26s)
# 22:00:04> DLE_Node2 Rx: message 58: 032,43
# 22:00:04> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:04> DLE_Node2 FSM: received: 2,43
# 22:00:04> PLE_Node2 Tx: message: 13
# 22:00:04> PLE_Node2 PLE: packet loss (15%)
# 22:00:04> MLE_Node2 MLE Rx: message 44: 2,43,1760925604209.9507
# 22:00:07> DLE_Node1 FSM: state: 1 event type: 3
# 22:00:07> DLE_Node1 FSM: to resend frame 3 2,43
# 22:00:07> PLE_Node1 Tx: message: 032,43
# 22:00:07> PLE_Node1 PLE: packet loss (15%)
# 22:00:13> DLE_Node1 FSM: state: 1 event type: 3
# 22:00:13> DLE_Node1 FSM: to resend frame 3 2,43
# 22:00:13> PLE_Node1 Tx: message: 032,43
# 22:00:15> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,43 (rx_delay=2.34s)
# 22:00:15> DLE_Node2 Rx: message 59: 032,43
# 22:00:15> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:15> DLE_Node2 FSM: received: 2,43
# 22:00:15> DLE_Node2 FSM: received received frame 3 but expected 4
# 22:00:15> PLE_Node2 Tx: message: 13
# 22:00:16> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.83s)
# 22:00:16> DLE_Node1 Rx: message 51: 13
# 22:00:16> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:16> DLE_Node1 Tx: message 45: 2,44
# 22:00:16> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:16> DLE_Node1 FSM: to send: 2,44
# 22:00:16> PLE_Node1 Tx: message: 042,44
# 22:00:16> PLE_Node1 PLE: packet loss (15%)
# 22:00:22> DLE_Node1 FSM: state: 1 event type: 3
# 22:00:22> DLE_Node1 FSM: to resend frame 4 2,44
# 22:00:22> PLE_Node1 Tx: message: 042,44
# 22:00:22> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,44 (rx_delay=0.60s)
# 22:00:22> DLE_Node2 Rx: message 60: 042,44
# 22:00:22> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:22> DLE_Node2 FSM: received: 2,44
# 22:00:22> MLE_Node2 MLE Rx: message 45: 2,44,1760925622762.0283
# 22:00:22> PLE_Node2 Tx: message: 14
# 22:00:22> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.13s)
# 22:00:22> DLE_Node1 Rx: message 52: 14
# 22:00:22> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:22> DLE_Node1 Tx: message 46: 2,45
# 22:00:22> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:22> DLE_Node1 FSM: to send: 2,45
# 22:00:22> PLE_Node1 Tx: message: 052,45
# 22:00:25> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,45 (rx_delay=2.69s)
# 22:00:25> DLE_Node2 Rx: message 61: 052,45
# 22:00:25> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:25> DLE_Node2 FSM: received: 2,45
# 22:00:25> PLE_Node2 Tx: message: 15
# 22:00:25> PLE_Node2 PLE: duplicate transmission (5%)
# 22:00:25> MLE_Node2 MLE Rx: message 46: 2,45,1760925625585.9326
# 22:00:28> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=2.99s)
# 22:00:28> DLE_Node1 Rx: message 53: 15
# 22:00:28> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:28> DLE_Node1 Tx: message 47: 2,46
# 22:00:28> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:28> DLE_Node1 FSM: to send: 2,46
# 22:00:28> PLE_Node1 Tx: message: 062,46
# 22:00:28> DLE_Node1 FSM: state: 1 event type: 3
# 22:00:28> DLE_Node1 FSM: to resend frame 6 2,46
# 22:00:28> PLE_Node1 Tx: message: 062,46
# 22:00:29> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,46 (rx_delay=1.28s)
# 22:00:29> DLE_Node2 Rx: message 62: 062,46
# 22:00:29> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:29> DLE_Node2 FSM: received: 2,46
# 22:00:29> PLE_Node2 Tx: message: 16
# 22:00:29> MLE_Node2 MLE Rx: message 47: 2,46,1760925629850.655
# 22:00:30> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.75s)
# 22:00:30> DLE_Node1 Rx: message 54: 15
# 22:00:30> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:30> ACK # 5 does not match local seq # 6
# 22:00:30> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,46 (rx_delay=0.76s)
# 22:00:30> DLE_Node2 Rx: message 63: 062,46
# 22:00:30> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:30> DLE_Node2 FSM: received: 2,46
# 22:00:30> DLE_Node2 FSM: received received frame 6 but expected 7
# 22:00:30> PLE_Node2 Tx: message: 16
# 22:00:30> PLE_Node2 PLE: packet loss (15%)
# 22:00:32> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.76s)
# 22:00:32> DLE_Node1 Rx: message 55: 16
# 22:00:32> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:32> DLE_Node1 Tx: message 48: 2,47
# 22:00:32> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:32> DLE_Node1 FSM: to send: 2,47
# 22:00:32> PLE_Node1 Tx: message: 072,47
# 22:00:32> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,47 (rx_delay=0.69s)
# 22:00:32> DLE_Node2 Rx: message 64: 072,47
# 22:00:32> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:32> DLE_Node2 FSM: received: 2,47
# 22:00:32> MLE_Node2 MLE Rx: message 48: 2,47,1760925632774.7856
# 22:00:32> PLE_Node2 Tx: message: 17
# 22:00:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.81s)
# 22:00:33> DLE_Node1 Rx: message 56: 17
# 22:00:33> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:33> DLE_Node1 Tx: message 49: 2,48
# 22:00:33> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:33> DLE_Node1 FSM: to send: 2,48
# 22:00:33> PLE_Node1 Tx: message: 082,48
# 22:00:36> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,48 (rx_delay=2.97s)
# 22:00:36> DLE_Node2 Rx: message 65: 082,48
# 22:00:36> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:36> DLE_Node2 FSM: received: 2,48
# 22:00:36> MLE_Node2 MLE Rx: message 49: 2,48,1760925636563.7893
# 22:00:36> PLE_Node2 Tx: message: 18
# 22:00:37> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.13s)
# 22:00:37> DLE_Node1 Rx: message 57: 18
# 22:00:37> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:37> DLE_Node1 Tx: message 50: 2,49
# 22:00:37> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:37> DLE_Node1 FSM: to send: 2,49
# 22:00:37> PLE_Node1 Tx: message: 092,49
# 22:00:38> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,49 (rx_delay=1.14s)
# 22:00:38> DLE_Node2 Rx: message 66: 092,49
# 22:00:38> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:38> DLE_Node2 FSM: received: 2,49
# 22:00:38> MLE_Node2 MLE Rx: message 50: 2,49,1760925638836.912
# 22:00:38> PLE_Node2 Tx: message: 19
# 22:00:39> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.43s)
# 22:00:39> DLE_Node1 Rx: message 58: 19
# 22:00:39> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:39> DLE_Node1 Tx: message 51: 2,50
# 22:00:39> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:39> DLE_Node1 FSM: to send: 2,50
# 22:00:39> PLE_Node1 Tx: message: 002,50
# 22:00:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,50 (rx_delay=1.20s)
# 22:00:40> DLE_Node2 Rx: message 67: 002,50
# 22:00:40> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:40> DLE_Node2 FSM: received: 2,50
# 22:00:40> MLE_Node2 MLE Rx: message 51: 2,50,1760925640462.0815
# 22:00:40> PLE_Node2 Tx: message: 10
# 22:00:42> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=2.20s)
# 22:00:42> DLE_Node1 Rx: message 59: 10
# 22:00:42> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:42> DLE_Node1 Tx: message 52: 2,51
# 22:00:42> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:42> DLE_Node1 FSM: to send: 2,51
# 22:00:42> PLE_Node1 Tx: message: 012,51
# 22:00:43> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,51 (rx_delay=0.98s)
# 22:00:43> DLE_Node2 Rx: message 68: 012,51
# 22:00:43> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:43> DLE_Node2 FSM: received: 2,51
# 22:00:43> MLE_Node2 MLE Rx: message 52: 2,51,1760925643641.1726
# 22:00:43> PLE_Node2 Tx: message: 11
# 22:00:45> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.56s)
# 22:00:45> DLE_Node1 Rx: message 60: 11
# 22:00:45> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:45> DLE_Node1 Tx: message 53: 2,52
# 22:00:45> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:45> DLE_Node1 FSM: to send: 2,52
# 22:00:45> PLE_Node1 Tx: message: 022,52
# 22:00:47> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,52 (rx_delay=2.39s)
# 22:00:47> DLE_Node2 Rx: message 69: 022,52
# 22:00:47> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:47> DLE_Node2 FSM: received: 2,52
# 22:00:47> PLE_Node2 Tx: message: 12
# 22:00:47> PLE_Node2 PLE: packet loss (15%)
# 22:00:47> MLE_Node2 MLE Rx: message 53: 2,52,1760925647591.1975
# 22:00:51> DLE_Node1 FSM: state: 1 event type: 3
# 22:00:51> DLE_Node1 FSM: to resend frame 2 2,52
# 22:00:51> PLE_Node1 Tx: message: 022,52
# 22:00:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,52 (rx_delay=1.68s)
# 22:00:52> DLE_Node2 Rx: message 70: 022,52
# 22:00:52> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:52> DLE_Node2 FSM: received: 2,52
# 22:00:52> DLE_Node2 FSM: received received frame 2 but expected 3
# 22:00:52> PLE_Node2 Tx: message: 12
# 22:00:54> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=1.80s)
# 22:00:54> DLE_Node1 Rx: message 61: 12
# 22:00:54> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:54> DLE_Node1 Tx: message 54: 2,53
# 22:00:54> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:54> DLE_Node1 FSM: to send: 2,53
# 22:00:54> PLE_Node1 Tx: message: 032,53
# 22:00:56> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,53 (rx_delay=1.92s)
# 22:00:56> DLE_Node2 Rx: message 71: 032,53
# 22:00:56> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:56> DLE_Node2 FSM: received: 2,53
# 22:00:56> MLE_Node2 MLE Rx: message 54: 2,53,1760925656590.3662
# 22:00:56> PLE_Node2 Tx: message: 13
# 22:00:58> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=2.28s)
# 22:00:58> DLE_Node1 Rx: message 62: 13
# 22:00:58> DLE_Node1 FSM: state: 1 event type: 2
# 22:00:58> DLE_Node1 Tx: message 55: 2,54
# 22:00:58> DLE_Node1 FSM: state: 0 event type: 0
# 22:00:58> DLE_Node1 FSM: to send: 2,54
# 22:00:58> PLE_Node1 Tx: message: 042,54
# 22:00:59> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,54 (rx_delay=0.92s)
# 22:00:59> DLE_Node2 Rx: message 72: 042,54
# 22:00:59> DLE_Node2 FSM: state: 0 event type: 1
# 22:00:59> DLE_Node2 FSM: received: 2,54
# 22:00:59> PLE_Node2 Tx: message: 14
# 22:00:59> MLE_Node2 MLE Rx: message 55: 2,54,1760925659796.9197
# 22:01:00> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.37s)
# 22:01:00> DLE_Node1 Rx: message 63: 14
# 22:01:00> DLE_Node1 FSM: state: 1 event type: 2
# 22:01:00> DLE_Node1 Tx: message 56: 2,55
# 22:01:00> DLE_Node1 FSM: state: 0 event type: 0
# 22:01:00> DLE_Node1 FSM: to send: 2,55
# 22:01:00> PLE_Node1 Tx: message: 052,55
# 22:01:01> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,55 (rx_delay=1.56s)
# 22:01:01> DLE_Node2 Rx: message 73: 052,55
# 22:01:01> DLE_Node2 FSM: state: 0 event type: 1
# 22:01:01> DLE_Node2 FSM: received: 2,55
# 22:01:01> MLE_Node2 MLE Rx: message 56: 2,55,1760925661725.97
# 22:01:01> PLE_Node2 Tx: message: 15
# 22:01:03> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.32s)
# 22:01:03> DLE_Node1 Rx: message 64: 15
# 22:01:03> DLE_Node1 FSM: state: 1 event type: 2
# 22:01:03> DLE_Node1 Tx: message 57: 2,56
# 22:01:03> DLE_Node1 FSM: state: 0 event type: 0
# 22:01:03> DLE_Node1 FSM: to send: 2,56
# 22:01:03> PLE_Node1 Tx: message: 062,56
# 22:01:06> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,56 (rx_delay=2.99s)
# 22:01:06> DLE_Node2 Rx: message 74: 062,56
# 22:01:06> DLE_Node2 FSM: state: 0 event type: 1
# 22:01:06> DLE_Node2 FSM: received: 2,56
# 22:01:06> MLE_Node2 MLE Rx: message 57: 2,56,1760925666036.8997
# 22:01:06> PLE_Node2 Tx: message: 16
# 22:01:07> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.94s)
# ...
# 22:03:10> DLE_Node1 Tx: message 84: 2,83
# 22:03:10> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:10> DLE_Node1 FSM: to send: 2,83
# 22:03:10> PLE_Node1 Tx: message: 032,83
# 22:03:10> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,83 (rx_delay=0.27s)
# 22:03:10> DLE_Node2 Rx: message 114: 032,83
# 22:03:10> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:10> DLE_Node2 FSM: received: 2,83
# 22:03:10> MLE_Node2 MLE Rx: message 84: 2,83,1760925790850.558
# 22:03:10> PLE_Node2 Tx: message: 13
# 22:03:13> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=2.30s)
# 22:03:13> DLE_Node1 Rx: message 100: 13
# 22:03:13> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:13> DLE_Node1 Tx: message 85: 2,84
# 22:03:13> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:13> DLE_Node1 FSM: to send: 2,84
# 22:03:13> PLE_Node1 Tx: message: 042,84
# 22:03:15> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,84 (rx_delay=2.00s)
# 22:03:15> DLE_Node2 Rx: message 115: 042,84
# 22:03:15> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:15> DLE_Node2 FSM: received: 2,84
# 22:03:15> MLE_Node2 MLE Rx: message 85: 2,84,1760925795159.0142
# 22:03:15> PLE_Node2 Tx: message: 14
# 22:03:15> PLE_Node2 PLE: packet loss (15%)
# 22:03:18> DLE_Node1 FSM: state: 1 event type: 3
# 22:03:18> DLE_Node1 FSM: to resend frame 4 2,84
# 22:03:18> PLE_Node1 Tx: message: 042,84
# 22:03:18> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,84 (rx_delay=0.05s)
# 22:03:18> DLE_Node2 Rx: message 116: 042,84
# 22:03:18> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:18> DLE_Node2 FSM: received: 2,84
# 22:03:18> DLE_Node2 FSM: received received frame 4 but expected 5
# 22:03:18> PLE_Node2 Tx: message: 14
# 22:03:18> PLE_Node2 PLE: packet loss (15%)
# 22:03:24> DLE_Node1 FSM: state: 1 event type: 3
# 22:03:24> DLE_Node1 FSM: to resend frame 4 2,84
# 22:03:24> PLE_Node1 Tx: message: 042,84
# 22:03:24> PLE_Node1 PLE: packet loss (15%)
# 22:03:29> DLE_Node1 FSM: state: 1 event type: 3
# 22:03:29> DLE_Node1 FSM: to resend frame 4 2,84
# 22:03:29> PLE_Node1 Tx: message: 042,84
# 22:03:31> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,84 (rx_delay=1.61s)
# 22:03:31> DLE_Node2 Rx: message 117: 042,84
# 22:03:31> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:31> DLE_Node2 FSM: received: 2,84
# 22:03:31> DLE_Node2 FSM: received received frame 4 but expected 5
# 22:03:31> PLE_Node2 Tx: message: 14
# 22:03:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.01s)
# 22:03:33> DLE_Node1 Rx: message 101: 14
# 22:03:33> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:33> DLE_Node1 Tx: message 86: 2,85
# 22:03:33> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:33> DLE_Node1 FSM: to send: 2,85
# 22:03:33> PLE_Node1 Tx: message: 052,85
# 22:03:33> PLE_Node1 PLE: duplicate transmission (5%)
# 22:03:35> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,85 (rx_delay=2.18s)
# 22:03:35> DLE_Node2 Rx: message 118: 052,85
# 22:03:35> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:35> DLE_Node2 FSM: received: 2,85
# 22:03:35> MLE_Node2 MLE Rx: message 86: 2,85,1760925815601.6729
# 22:03:35> PLE_Node2 Tx: message: 15
# 22:03:36> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,85 (rx_delay=0.42s)
# 22:03:36> DLE_Node2 Rx: message 119: 052,85
# 22:03:36> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:36> DLE_Node2 FSM: received: 2,85
# 22:03:36> DLE_Node2 FSM: received received frame 5 but expected 6
# 22:03:36> PLE_Node2 Tx: message: 15
# 22:03:36> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=0.53s)
# 22:03:36> DLE_Node1 Rx: message 102: 15
# 22:03:36> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:36> DLE_Node1 Tx: message 87: 2,86
# 22:03:36> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:36> DLE_Node1 FSM: to send: 2,86
# 22:03:36> PLE_Node1 Tx: message: 062,86
# 22:03:37> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.82s)
# 22:03:37> DLE_Node1 Rx: message 103: 15
# 22:03:37> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:37> ACK # 5 does not match local seq # 6
# 22:03:38> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,86 (rx_delay=2.11s)
# 22:03:38> DLE_Node2 Rx: message 120: 062,86
# 22:03:38> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:38> DLE_Node2 FSM: received: 2,86
# 22:03:38> MLE_Node2 MLE Rx: message 87: 2,86,1760925818243.6836
# 22:03:38> PLE_Node2 Tx: message: 16
# 22:03:41> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=3.00s)
# 22:03:41> DLE_Node1 Rx: message 104: 16
# 22:03:41> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:41> DLE_Node1 Tx: message 88: 2,87
# 22:03:41> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:41> DLE_Node1 FSM: to send: 2,87
# 22:03:41> PLE_Node1 Tx: message: 072,87
# 22:03:43> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,87 (rx_delay=1.97s)
# 22:03:43> DLE_Node2 Rx: message 121: 072,87
# 22:03:43> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:43> DLE_Node2 FSM: received: 2,87
# 22:03:43> MLE_Node2 MLE Rx: message 88: 2,87,1760925823210.0793
# 22:03:43> PLE_Node2 Tx: message: 17
# 22:03:43> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.73s)
# 22:03:43> DLE_Node1 Rx: message 105: 17
# 22:03:43> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:43> DLE_Node1 Tx: message 89: 2,88
# 22:03:43> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:43> DLE_Node1 FSM: to send: 2,88
# 22:03:43> PLE_Node1 Tx: message: 082,88
# 22:03:45> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,88 (rx_delay=1.88s)
# 22:03:45> DLE_Node2 Rx: message 122: 082,88
# 22:03:45> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:45> DLE_Node2 FSM: received: 2,88
# 22:03:45> PLE_Node2 Tx: message: 18
# 22:03:45> MLE_Node2 MLE Rx: message 89: 2,88,1760925825820.3086
# 22:03:47> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.89s)
# 22:03:47> DLE_Node1 Rx: message 106: 18
# 22:03:47> DLE_Node1 FSM: state: 1 event type: 2
# 22:03:47> DLE_Node1 Tx: message 90: 2,89
# 22:03:47> DLE_Node1 FSM: state: 0 event type: 0
# 22:03:47> DLE_Node1 FSM: to send: 2,89
# 22:03:47> PLE_Node1 Tx: message: 092,89
# 22:03:47> PLE_Node1 PLE: packet loss (15%)
# 22:03:53> DLE_Node1 FSM: state: 1 event type: 3
# 22:03:53> DLE_Node1 FSM: to resend frame 9 2,89
# 22:03:53> PLE_Node1 Tx: message: 092,89
# 22:03:55> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,89 (rx_delay=2.24s)
# 22:03:55> DLE_Node2 Rx: message 123: 092,89
# 22:03:55> DLE_Node2 FSM: state: 0 event type: 1
# 22:03:55> DLE_Node2 FSM: received: 2,89
# 22:03:55> PLE_Node2 Tx: message: 19
# 22:03:55> PLE_Node2 PLE: packet loss (15%)
# 22:03:55> MLE_Node2 MLE Rx: message 90: 2,89,1760925835540.3074
# 22:03:58> DLE_Node1 FSM: state: 1 event type: 3
# 22:03:58> DLE_Node1 FSM: to resend frame 9 2,89
# 22:03:58> PLE_Node1 Tx: message: 092,89
# 22:04:01> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,89 (rx_delay=2.52s)
# 22:04:01> DLE_Node2 Rx: message 124: 092,89
# 22:04:01> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:01> DLE_Node2 FSM: received: 2,89
# 22:04:01> DLE_Node2 FSM: received received frame 9 but expected 0
# 22:04:01> PLE_Node2 Tx: message: 19
# 22:04:03> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=2.39s)
# 22:04:03> DLE_Node1 Rx: message 107: 19
# 22:04:03> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:03> DLE_Node1 Tx: message 91: 2,90
# 22:04:03> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:03> DLE_Node1 FSM: to send: 2,90
# 22:04:03> PLE_Node1 Tx: message: 002,90
# 22:04:03> PLE_Node1 PLE: packet loss (15%)
# 22:04:09> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:09> DLE_Node1 FSM: to resend frame 0 2,90
# 22:04:09> PLE_Node1 Tx: message: 002,90
# 22:04:09> PLE_Node1 PLE: packet loss (15%)
# 22:04:14> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:14> DLE_Node1 FSM: to resend frame 0 2,90
# 22:04:14> PLE_Node1 Tx: message: 002,90
# 22:04:16> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,90 (rx_delay=1.99s)
# 22:04:16> DLE_Node2 Rx: message 125: 002,90
# 22:04:16> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:16> DLE_Node2 FSM: received: 2,90
# 22:04:16> PLE_Node2 Tx: message: 10
# 22:04:16> MLE_Node2 MLE Rx: message 91: 2,90,1760925856810.5051
# 22:04:18> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.47s)
# 22:04:18> DLE_Node1 Rx: message 108: 10
# 22:04:18> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:18> DLE_Node1 Tx: message 92: 2,91
# 22:04:18> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:18> DLE_Node1 FSM: to send: 2,91
# 22:04:18> PLE_Node1 Tx: message: 012,91
# 22:04:20> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,91 (rx_delay=2.44s)
# 22:04:20> DLE_Node2 Rx: message 126: 012,91
# 22:04:20> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:20> DLE_Node2 FSM: received: 2,91
# 22:04:20> PLE_Node2 Tx: message: 11
# 22:04:20> PLE_Node2 PLE: packet loss (15%)
# 22:04:20> MLE_Node2 MLE Rx: message 92: 2,91,1760925860722.1697
# 22:04:23> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:23> DLE_Node1 FSM: to resend frame 1 2,91
# 22:04:23> PLE_Node1 Tx: message: 012,91
# 22:04:23> PLE_Node1 PLE: packet loss (15%)
# 22:04:29> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:29> DLE_Node1 FSM: to resend frame 1 2,91
# 22:04:29> PLE_Node1 Tx: message: 012,91
# 22:04:30> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,91 (rx_delay=1.37s)
# 22:04:30> DLE_Node2 Rx: message 127: 012,91
# 22:04:30> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:30> DLE_Node2 FSM: received: 2,91
# 22:04:30> DLE_Node2 FSM: received received frame 1 but expected 2
# 22:04:30> PLE_Node2 Tx: message: 11
# 22:04:31> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.52s)
# 22:04:31> DLE_Node1 Rx: message 109: 11
# 22:04:31> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:31> DLE_Node1 Tx: message 93: 2,92
# 22:04:31> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:31> DLE_Node1 FSM: to send: 2,92
# 22:04:31> PLE_Node1 Tx: message: 022,92
# 22:04:31> PLE_Node1 PLE: duplicate transmission (5%)
# 22:04:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,92 (rx_delay=2.08s)
# 22:04:33> DLE_Node2 Rx: message 128: 022,92
# 22:04:33> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:33> DLE_Node2 FSM: received: 2,92
# 22:04:33> MLE_Node2 MLE Rx: message 93: 2,92,1760925873298.7827
# 22:04:33> PLE_Node2 Tx: message: 12
# 22:04:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,92 (rx_delay=0.28s)
# 22:04:33> DLE_Node2 Rx: message 129: 022,92
# 22:04:33> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:33> DLE_Node2 FSM: received: 2,92
# 22:04:33> DLE_Node2 FSM: received received frame 2 but expected 3
# 22:04:33> PLE_Node2 Tx: message: 12
# 22:04:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=0.64s)
# 22:04:33> DLE_Node1 Rx: message 110: 12
# 22:04:33> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:33> DLE_Node1 Tx: message 94: 2,93
# 22:04:33> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:33> DLE_Node1 FSM: to send: 2,93
# 22:04:33> PLE_Node1 Tx: message: 032,93
# 22:04:34> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,93 (rx_delay=1.02s)
# 22:04:34> DLE_Node2 Rx: message 130: 032,93
# 22:04:34> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:34> DLE_Node2 FSM: received: 2,93
# 22:04:34> PLE_Node2 Tx: message: 13
# 22:04:34> MLE_Node2 MLE Rx: message 94: 2,93,1760925874964.1716
# 22:04:35> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=1.49s)
# 22:04:35> DLE_Node1 Rx: message 111: 12
# 22:04:35> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:35> ACK # 2 does not match local seq # 3
# 22:04:37> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.94s)
# 22:04:37> DLE_Node1 Rx: message 112: 13
# 22:04:37> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:37> DLE_Node1 Tx: message 95: 2,94
# 22:04:37> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:37> DLE_Node1 FSM: to send: 2,94
# 22:04:37> PLE_Node1 Tx: message: 042,94
# 22:04:37> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,94 (rx_delay=0.55s)
# 22:04:37> DLE_Node2 Rx: message 131: 042,94
# 22:04:37> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:37> DLE_Node2 FSM: received: 2,94
# 22:04:37> MLE_Node2 MLE Rx: message 95: 2,94,1760925877926.3015
# 22:04:37> PLE_Node2 Tx: message: 14
# 22:04:39> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=1.99s)
# 22:04:39> DLE_Node1 Rx: message 113: 14
# 22:04:39> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:39> DLE_Node1 Tx: message 96: 2,95
# 22:04:39> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:39> DLE_Node1 FSM: to send: 2,95
# 22:04:39> PLE_Node1 Tx: message: 052,95
# 22:04:39> PLE_Node1 PLE: packet loss (15%)
# 22:04:45> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:45> DLE_Node1 FSM: to resend frame 5 2,95
# 22:04:45> PLE_Node1 Tx: message: 052,95
# 22:04:47> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,95 (rx_delay=1.76s)
# 22:04:47> DLE_Node2 Rx: message 132: 052,95
# 22:04:47> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:47> DLE_Node2 FSM: received: 2,95
# 22:04:47> PLE_Node2 Tx: message: 15
# 22:04:47> MLE_Node2 MLE Rx: message 96: 2,95,1760925887606.6943
# 22:04:47> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=0.32s)
# 22:04:47> DLE_Node1 Rx: message 114: 15
# 22:04:47> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:47> DLE_Node1 Tx: message 97: 2,96
# 22:04:47> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:47> DLE_Node1 FSM: to send: 2,96
# 22:04:47> PLE_Node1 Tx: message: 062,96
# 22:04:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,96 (rx_delay=2.71s)
# 22:04:50> DLE_Node2 Rx: message 133: 062,96
# 22:04:50> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:50> DLE_Node2 FSM: received: 2,96
# 22:04:50> MLE_Node2 MLE Rx: message 97: 2,96,1760925890644.4866
# 22:04:50> PLE_Node2 Tx: message: 16
# 22:04:51> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=0.68s)
# 22:04:51> DLE_Node1 Rx: message 115: 16
# 22:04:51> DLE_Node1 FSM: state: 1 event type: 2
# 22:04:51> DLE_Node1 Tx: message 98: 2,97
# 22:04:51> DLE_Node1 FSM: state: 0 event type: 0
# 22:04:51> DLE_Node1 FSM: to send: 2,97
# 22:04:51> PLE_Node1 Tx: message: 072,97
# 22:04:54> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,97 (rx_delay=2.69s)
# 22:04:54> DLE_Node2 Rx: message 134: 072,97
# 22:04:54> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:54> DLE_Node2 FSM: received: 2,97
# 22:04:54> PLE_Node2 Tx: message: 17
# 22:04:54> PLE_Node2 PLE: packet loss (15%)
# 22:04:54> MLE_Node2 MLE Rx: message 98: 2,97,1760925894017.1826
# 22:04:56> DLE_Node1 FSM: state: 1 event type: 3
# 22:04:56> DLE_Node1 FSM: to resend frame 7 2,97
# 22:04:56> PLE_Node1 Tx: message: 072,97
# 22:04:58> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,97 (rx_delay=1.49s)
# 22:04:58> DLE_Node2 Rx: message 135: 072,97
# 22:04:58> DLE_Node2 FSM: state: 0 event type: 1
# 22:04:58> DLE_Node2 FSM: received: 2,97
# 22:04:58> DLE_Node2 FSM: received received frame 7 but expected 8
# 22:04:58> PLE_Node2 Tx: message: 17
# 22:05:00> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.17s)
# 22:05:00> DLE_Node1 Rx: message 116: 17
# 22:05:00> DLE_Node1 FSM: state: 1 event type: 2
# 22:05:00> DLE_Node1 Tx: message 99: 2,98
# 22:05:00> DLE_Node1 FSM: state: 0 event type: 0
# 22:05:00> DLE_Node1 FSM: to send: 2,98
# 22:05:00> PLE_Node1 Tx: message: 082,98
# 22:05:01> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,98 (rx_delay=1.20s)
# 22:05:01> DLE_Node2 Rx: message 136: 082,98
# 22:05:01> DLE_Node2 FSM: state: 0 event type: 1
# 22:05:01> DLE_Node2 FSM: received: 2,98
# 22:05:01> MLE_Node2 MLE Rx: message 99: 2,98,1760925901711.5312
# 22:05:01> PLE_Node2 Tx: message: 18
# 22:05:04> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=2.69s)
# 22:05:04> DLE_Node1 Rx: message 117: 18
# 22:05:04> DLE_Node1 FSM: state: 1 event type: 2
# 22:05:04> DLE_Node1 Tx: message 100: 2,99
# 22:05:04> DLE_Node1 FSM: state: 0 event type: 0
# 22:05:04> DLE_Node1 FSM: to send: 2,99
# 22:05:04> PLE_Node1 Tx: message: 092,99
# 22:05:04> PLE_Node1 PLE: duplicate transmission (5%)
# 22:05:05> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,99 (rx_delay=1.24s)
# 22:05:05> DLE_Node2 Rx: message 137: 092,99
# 22:05:05> DLE_Node2 FSM: state: 0 event type: 1
# 22:05:05> DLE_Node2 FSM: received: 2,99
# 22:05:05> PLE_Node2 Tx: message: 19
# 22:05:05> MLE_Node2 MLE Rx: message 100: 2,99,1760925905642.0618
# 22:05:06> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.74s)
# 22:05:06> DLE_Node1 Rx: message 118: 19
# 22:05:06> DLE_Node1 FSM: state: 1 event type: 2
# 22:05:08> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,99 (rx_delay=2.62s)
# 22:05:08> DLE_Node2 Rx: message 138: 092,99
# 22:05:08> DLE_Node2 FSM: state: 0 event type: 1
# 22:05:08> DLE_Node2 FSM: received: 2,99
# 22:05:08> DLE_Node2 FSM: received received frame 9 but expected 0
# 22:05:08> PLE_Node2 Tx: message: 19
# 22:05:10> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=2.41s)
# 22:05:10> DLE_Node1 Rx: message 119: 19
# 22:05:10> DLE_Node1 FSM: state: 0 event type: 2
# 22:05:10> DLE_Node1 FSM: error! 9

# %%
# Run the loop functions on threads
x1_1 = Thread(target = PLE_3.loop_Tx, args = ()) 
x1_2 = Thread(target = PLE_3.loop_Rx, args = ()) 
x1_3 = Thread(target = MLE_1.loop_Rx, args=())
x2_1 = Thread(target = PLE_4.loop_Tx, args = ()) 
x2_2 = Thread(target = PLE_4.loop_Rx, args = ()) 
x2_3 = Thread(target = MLE_2.loop_Rx, args=())

x3_1 = Thread(target = PLE_5.loop_Rx, args = ())
x3_2 = Thread(target = PLE_5.loop_Tx, args = ())
x3_3 = Thread(target = DLE_3.loop_Rx, args = ())
x3_4 = Thread(target = DLE_3.loop_Tx, args = ())
x3_5 = Thread(target = DLE_3.loop_FSM, args = ())
x3_6 = Thread(target = DLE_3.loop_timer, args = ())
x3_7 = Thread(target = MLE_3.loop_Rx, args = ())
x4_1 = Thread(target = PLE_6.loop_Rx, args = ())
x4_2 = Thread(target = PLE_6.loop_Tx, args = ())
x4_3 = Thread(target = DLE_4.loop_Rx, args = ())
x4_4 = Thread(target = DLE_4.loop_Tx, args = ())
x4_5 = Thread(target = DLE_4.loop_FSM, args = ())
x4_6 = Thread(target = DLE_4.loop_timer, args = ())
x4_7 = Thread(target = MLE_4.loop_Rx, args = ())

thread_running = True

x1_1.start()
x1_2.start()
x1_3.start()
x2_1.start()
x2_2.start()
x2_3.start()
x3_1.start()
x3_2.start()
x3_3.start()
x3_4.start()
x3_5.start()
x3_6.start()
x3_7.start()
x4_1.start()
x4_2.start()
x4_3.start()
x4_4.start()
x4_5.start()
x4_6.start()
x4_7.start()

# %%
### Experiment Insights Calculators ### ↓↓↓
# Note: This requires each experiment to be ran atleast once.

# %%
out = Output()

def exp_1_insights(exp1):
    with out:
        with open("./experiment_outputs/experiment1.csv", "r") as csv:
            message_count = 0
            messages_duped = 0
            message_ids = []
            message_times = []
            for line in csv:
                expId,msgId,currentTime = line.split(",")
                if expId == "experimentId":
                    continue
                else:
                    message_count += 1
                    message_ids.append(int(msgId))
                    message_times.append(float(currentTime))
            
            message_ids_set = set(message_ids)
            messages_duped = len(message_ids) - len(message_ids_set)

            times_substracted = 0
            for i in range(0,message_count-2):
                times_substracted += message_times[i+1] - message_times[i]
            
            avg_time_delay = times_substracted / message_count

            print("*Experiment 1*\n")
            print(f"Messages Received: {message_count} out of 100 \nMessages Lost: {100-message_count}\nMessages Duped: {messages_duped}\nAverage Time Delay: {avg_time_delay} ms\n")

def exp_2_insights(exp2):
    with out:
        with open("./experiment_outputs/experiment2.csv", "r") as csv:
            message_count = 0
            messages_duped = 0
            message_ids = []
            message_times = []
            for line in csv:
                expId,msgId,currentTime = line.split(",")
                if expId == "experimentId":
                    continue
                else:
                    message_count += 1
                    message_ids.append(int(msgId))
                    message_times.append(float(currentTime))
            
            message_ids_set = set(message_ids)
            messages_duped = len(message_ids) - len(message_ids_set)

            times_substracted = 0
            for i in range(0,message_count-2):
                times_substracted += message_times[i+1] - message_times[i]
            avg_time_delay = times_substracted / message_count

            print("*Experiment 2*\n")
            print(f"Messages Received: {message_count} out of 100 \nMessages Lost: {100-message_count}\nMessages Duped: {messages_duped}\nAverage Time Delay: {avg_time_delay} ms\n")

exp1 = widgets.Button(description="Insights from experiment 1.",
                    disabled=False,
                    button_style='', 
                    tooltip='Click me for experiment 1 insights.',
                    layout=Layout(width='500px'))
exp1.on_click(exp_1_insights)
display(exp1)
exp2 = widgets.Button(description="Insights from experiment 2.",
                    disabled=False,
                    button_style='', 
                    tooltip='Click me for experiment 2 insights.',
                    layout=Layout(width='500px'))
exp2.on_click(exp_2_insights)
display(exp2)

display(out)
# Out:
# Button(description='Insights from experiment 1.', layout=Layout(width='500px'), style=ButtonStyle(), tooltip='…
# Button(description='Insights from experiment 2.', layout=Layout(width='500px'), style=ButtonStyle(), tooltip='…
# Output()
