# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets, Layout
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
# class PLE_TR:

#     def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
#         self.Name      = name
#         self.Socket    = Socket
#         self.AP_Tx     = AP_Tx
#         self.AP_Rx     = AP_Rx
#         self.Queue_Tx  = Queue()
#         self.Queue_Rx  = Queue()
#         self.exp_out   = exp_out
        
#     def loop_Tx(self):
        
#         global thread_running
#         self.exp_out.print(self.Name + ": loop_Tx starting")
    
#         while (thread_running == True):
        
#             # get a message from queue
#             msg = self.Queue_Tx.get()
            
#             text_out = self.Name + " Tx: message: " + str(msg)
#             self.exp_out.print(text_out)
            
#             # sending the message using socket
#             msg_bytes = str.encode(msg)
#             if (random.random() < 0.2):
#                 self.exp_out.print("packet loss")
#             else:
#                 # sending the message using socket
#                 self.Socket.sendto(msg_bytes, self.AP_Tx)

#     def loop_Rx(self):
        
#         global thread_running
#         global bufferSize
#         self.exp_out.print(self.Name + ": loop_Rx starting")
    
#         # binding the socket with the IP and port
#         self.Socket.bind(self.AP_Rx)
        
#         while (thread_running == True):
        
#             # get a message from socket, this thread is blocked here
#             msg_addr = self.Socket.recvfrom(bufferSize)

#             # to emulate a slow receiver
#             time.sleep(0.5)
    
#             msg  = msg_addr[0].decode('utf-8')
#             addr = msg_addr[1]
            
#             text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
#             self.exp_out.print(text_out)
            
#             self.Queue_Rx.put(msg)
            
#     def send(self, msg):
#         self.Queue_Tx.put(msg)
        
#     def receive(self):
#         return self.Queue_Rx.get()

class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")

        while (thread_running == True):
            # 1) Get a message from the queue (blocks until available)
            msg = self.Queue_Tx.get()
            self.exp_out.print(self.Name + " Tx: message: " + str(msg))

            # 2) Decide loss & duplication using a single random draw
            #    r in [0,1): 
            #      - r < 0.16   => drop (16%)
            #      - 0.15 <= r < 0.20 => send + duplicate (5%)
            #      - r >= 0.20  => normal single send (80%)
            r = random.random()
            msg_bytes = msg.encode()

            if r < 0.15:
                # Drop
                self.exp_out.print(self.Name + " PLE: packet loss (15%)")
                continue

            # Send once
            self.Socket.sendto(msg_bytes, self.AP_Tx)

            # Optional duplicate
            if r < 0.20:
                self.exp_out.print(self.Name + " PLE: duplicate transmission (5%)")
                self.Socket.sendto(msg_bytes, self.AP_Tx)


    def loop_Rx(self):
        global thread_running, bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")

        # Bind once before the receive loop
        self.Socket.bind(self.AP_Rx)

        while (thread_running == True):
            # Block waiting for a frame
            msg_addr = self.Socket.recvfrom(bufferSize)

            # Random delay 0.0 to 3.0 seconds
            delay = random.uniform(0.0, 3.0)
            time.sleep(delay)

            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]

            # Log the delay for evidence
            self.exp_out.print(self.Name + f" Rx: from {addr}: {msg} (rx_delay={delay:.2f}s)")

            # Hand to upper queue
            self.Queue_Rx.put(msg)

            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')
# 12:28:36> ALE_Alice: loop_Tx starting
# 12:28:36> ALE_Alice: loop_Rx starting
# 12:28:36> DLE_Alice: loop_Tx starting
# 12:28:36> DLE_Alice: loop_Rx starting
# 12:28:36> PLE_Alice: loop_Tx starting
# 12:28:36> PLE_Alice: loop_Rx starting
# 12:28:36> ALE_Bob: loop_Tx starting
# 12:28:36> ALE_Bob: loop_Rx starting
# 12:28:36> DLE_Bob: loop_Tx starting
# 12:28:36> DLE_Bob: loop_Rx starting
# 12:28:36> PLE_Bob: loop_Tx starting
# 12:28:36> PLE_Bob: loop_Rx starting
# 12:28:36> DLE_Alice: loop_FSM starting
# 12:28:36> DLE_Bob: loop_FSM starting
# 12:28:36> DLE_Alice: loop_Timer starting
# 12:28:36> DLE_Bob: loop_Timer starting

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()

# %%
### Measurement Layer Analysis ### ↓↓↓

# %%
# Measurement Layer Entity Class
class MLE_TR:
    def __init__(self, name, experiment, lower_TR, exp_out):
        self.Name = name
        self.Experiment = experiment
        self.Lower_TR = lower_TR
        self.exp_out = exp_out

        self.submit = widgets.Button(
                            description=f"Send 100 messages from {self.Name}.",
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                            layout=Layout(width='500px')
                        )
        self.submit.on_click(self.button_clicked)
        display(self.submit)

    def button_clicked(self, submit):
        # Initialize the CSV file to store experiment data
        # Deletes old data if it already exists
        with open(f"./experiment_outputs/experiment{self.Experiment}.csv", "w") as csv:
            csv.write("experimentId,messageId,currentTime\n")
        
        for i in range(100):
            # CSV Format: experimentId,messageId,currentTime
            msg = f"{self.Experiment},{i},{time.time_ns()/1e6}"
            self.Lower_TR.send(msg)
    
    def loop_Rx(self):
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": MLE loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " MLE Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # Everytime we successfully receive a message, store it in the CSV
            with open(f"./experiment_outputs/experiment{self.Experiment}.csv", "a") as csv:
                csv.write(str(msg)+"\n")

# %%
# Experiment 1: Two Nodes and Two Layers
# MLE_TR
# 
# PLE_TR

thread_running = False
bufferSize = 1024
exp_out = EXP_Output()

# Node 1 
AP_local_3  = ("127.0.0.1", 32222)
AP_remote_3 = ("127.0.0.1", 33000)

Socket_3 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_3 = PLE_TR("PLE_Node1", Socket_3, AP_remote_3, AP_local_3, exp_out)
MLE_1 = MLE_TR("MLE_Node1", 1, PLE_3, exp_out)

# Node 2 
AP_local_4  = ("127.0.0.1", 33000)
AP_remote_4 = ("127.0.0.1", 32222)

Socket_4 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_4 = PLE_TR("PLE_Node2", Socket_4, AP_remote_4, AP_local_4, exp_out)
MLE_2 = MLE_TR("MLE_Node2", 1, PLE_4, exp_out)
# Out:
# Button(description='Send 100 messages from MLE_Node1.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# Button(description='Send 100 messages from MLE_Node2.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# 12:28:36> PLE_Node1: loop_Tx starting
# 12:28:36> PLE_Node1: loop_Rx starting
# 12:28:36> MLE_Node1: MLE loop_Rx starting
# 12:28:36> PLE_Node2: loop_Tx starting
# 12:28:36> PLE_Node2: loop_Rx starting
# 12:28:36> MLE_Node2: MLE loop_Rx starting
# 12:28:39> PLE_Node1 Tx: message: 1,0,1760804919386.0908
# 12:28:39> PLE_Node1 Tx: message: 1,1,1760804919386.108
# 12:28:39> PLE_Node1 Tx: message: 1,2,1760804919386.111
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,3,1760804919386.113
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,4,1760804919386.1143
# 12:28:39> PLE_Node1 Tx: message: 1,5,1760804919386.1157
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,6,1760804919386.1174
# 12:28:39> PLE_Node1 Tx: message: 1,7,1760804919386.1187
# 12:28:39> PLE_Node1 Tx: message: 1,8,1760804919386.12
# 12:28:39> PLE_Node1 Tx: message: 1,9,1760804919386.1218
# 12:28:39> PLE_Node1 Tx: message: 1,10,1760804919386.1235
# 12:28:39> PLE_Node1 Tx: message: 1,11,1760804919386.1248
# 12:28:39> PLE_Node1 PLE: duplicate transmission (5%)
# 12:28:39> PLE_Node1 Tx: message: 1,12,1760804919386.126
# 12:28:39> PLE_Node1 Tx: message: 1,13,1760804919386.1277
# 12:28:39> PLE_Node1 Tx: message: 1,14,1760804919386.1292
# 12:28:39> PLE_Node1 Tx: message: 1,15,1760804919386.1306
# 12:28:39> PLE_Node1 Tx: message: 1,16,1760804919386.132
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,17,1760804919386.1335
# 12:28:39> PLE_Node1 Tx: message: 1,18,1760804919386.1348
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,19,1760804919386.1362
# 12:28:39> PLE_Node1 Tx: message: 1,20,1760804919386.1377
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,21,1760804919386.139
# 12:28:39> PLE_Node1 Tx: message: 1,22,1760804919386.1406
# 12:28:39> PLE_Node1 Tx: message: 1,23,1760804919386.1426
# 12:28:39> PLE_Node1 Tx: message: 1,24,1760804919386.1438
# 12:28:39> PLE_Node1 Tx: message: 1,25,1760804919386.1453
# 12:28:39> PLE_Node1 Tx: message: 1,26,1760804919386.1465
# 12:28:39> PLE_Node1 Tx: message: 1,27,1760804919386.1482
# 12:28:39> PLE_Node1 Tx: message: 1,28,1760804919386.1494
# 12:28:39> PLE_Node1 Tx: message: 1,29,1760804919386.151
# 12:28:39> PLE_Node1 Tx: message: 1,30,1760804919386.1523
# 12:28:39> PLE_Node1 Tx: message: 1,31,1760804919386.1538
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,32,1760804919386.1553
# 12:28:39> PLE_Node1 Tx: message: 1,33,1760804919386.1575
# 12:28:39> PLE_Node1 Tx: message: 1,34,1760804919386.1592
# 12:28:39> PLE_Node1 Tx: message: 1,35,1760804919386.1604
# 12:28:39> PLE_Node1 Tx: message: 1,36,1760804919386.162
# 12:28:39> PLE_Node1 Tx: message: 1,37,1760804919386.1638
# 12:28:39> PLE_Node1 Tx: message: 1,38,1760804919386.165
# 12:28:39> PLE_Node1 Tx: message: 1,39,1760804919386.1665
# 12:28:39> PLE_Node1 Tx: message: 1,40,1760804919386.168
# 12:28:39> PLE_Node1 Tx: message: 1,41,1760804919386.1694
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,42,1760804919386.171
# 12:28:39> PLE_Node1 Tx: message: 1,43,1760804919386.172
# 12:28:39> PLE_Node1 Tx: message: 1,44,1760804919386.1736
# 12:28:39> PLE_Node1 Tx: message: 1,45,1760804919386.175
# 12:28:39> PLE_Node1 Tx: message: 1,46,1760804919386.1765
# 12:28:39> PLE_Node1 Tx: message: 1,47,1760804919386.178
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,48,1760804919386.1797
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,49,1760804919386.1812
# 12:28:39> PLE_Node1 Tx: message: 1,50,1760804919386.1826
# 12:28:39> PLE_Node1 Tx: message: 1,51,1760804919386.184
# 12:28:39> PLE_Node1 Tx: message: 1,52,1760804919386.1855
# 12:28:39> PLE_Node1 Tx: message: 1,53,1760804919386.187
# 12:28:39> PLE_Node1 Tx: message: 1,54,1760804919386.1882
# 12:28:39> PLE_Node1 Tx: message: 1,55,1760804919386.19
# 12:28:39> PLE_Node1 Tx: message: 1,56,1760804919386.1914
# 12:28:39> PLE_Node1 Tx: message: 1,57,1760804919386.1929
# 12:28:39> PLE_Node1 Tx: message: 1,58,1760804919386.194
# 12:28:39> PLE_Node1 Tx: message: 1,59,1760804919386.1958
# 12:28:39> PLE_Node1 Tx: message: 1,60,1760804919386.197
# 12:28:39> PLE_Node1 Tx: message: 1,61,1760804919386.1985
# 12:28:39> PLE_Node1 Tx: message: 1,62,1760804919386.1997
# 12:28:39> PLE_Node1 Tx: message: 1,63,1760804919386.2012
# 12:28:39> PLE_Node1 Tx: message: 1,64,1760804919386.2026
# 12:28:39> PLE_Node1 Tx: message: 1,65,1760804919386.2043
# 12:28:39> PLE_Node1 Tx: message: 1,66,1760804919386.2058
# 12:28:39> PLE_Node1 Tx: message: 1,67,1760804919386.207
# 12:28:39> PLE_Node1 Tx: message: 1,68,1760804919386.2085
# 12:28:39> PLE_Node1 Tx: message: 1,69,1760804919386.2097
# 12:28:39> PLE_Node1 Tx: message: 1,70,1760804919386.2112
# 12:28:39> PLE_Node1 Tx: message: 1,71,1760804919386.2126
# 12:28:39> PLE_Node1 PLE: duplicate transmission (5%)
# 12:28:39> PLE_Node1 Tx: message: 1,72,1760804919386.2139
# 12:28:39> PLE_Node1 Tx: message: 1,73,1760804919386.215
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,74,1760804919386.2166
# 12:28:39> PLE_Node1 Tx: message: 1,75,1760804919386.218
# 12:28:39> PLE_Node1 Tx: message: 1,76,1760804919386.2192
# 12:28:39> PLE_Node1 Tx: message: 1,77,1760804919386.2207
# 12:28:39> PLE_Node1 Tx: message: 1,78,1760804919386.2222
# 12:28:39> PLE_Node1 Tx: message: 1,79,1760804919386.2236
# 12:28:39> PLE_Node1 Tx: message: 1,80,1760804919386.2249
# 12:28:39> PLE_Node1 Tx: message: 1,81,1760804919386.226
# 12:28:39> PLE_Node1 Tx: message: 1,82,1760804919386.2278
# 12:28:39> PLE_Node1 Tx: message: 1,83,1760804919386.229
# 12:28:39> PLE_Node1 Tx: message: 1,84,1760804919386.2302
# 12:28:39> PLE_Node1 Tx: message: 1,85,1760804919386.2314
# 12:28:39> PLE_Node1 PLE: duplicate transmission (5%)
# 12:28:39> PLE_Node1 Tx: message: 1,86,1760804919386.2332
# 12:28:39> PLE_Node1 Tx: message: 1,87,1760804919386.2344
# 12:28:39> PLE_Node1 PLE: duplicate transmission (5%)
# 12:28:39> PLE_Node1 Tx: message: 1,88,1760804919386.2356
# 12:28:39> PLE_Node1 Tx: message: 1,89,1760804919386.2368
# 12:28:39> PLE_Node1 Tx: message: 1,90,1760804919386.2385
# 12:28:39> PLE_Node1 Tx: message: 1,91,1760804919386.2397
# 12:28:39> PLE_Node1 Tx: message: 1,92,1760804919386.241
# 12:28:39> PLE_Node1 Tx: message: 1,93,1760804919386.2422
# 12:28:39> PLE_Node1 Tx: message: 1,94,1760804919386.244
# 12:28:39> PLE_Node1 PLE: packet loss (15%)
# 12:28:39> PLE_Node1 Tx: message: 1,95,1760804919386.2454
# 12:28:39> PLE_Node1 Tx: message: 1,96,1760804919386.2466
# 12:28:39> PLE_Node1 Tx: message: 1,97,1760804919386.2483
# 12:28:39> PLE_Node1 Tx: message: 1,98,1760804919386.2495
# 12:28:39> PLE_Node1 Tx: message: 1,99,1760804919386.2507
# 12:28:40> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,0,1760804919386.0908 (rx_delay=1.26s)
# 12:28:40> MLE_Node2 MLE Rx: message 1: 1,0,1760804919386.0908
# 12:28:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,1,1760804919386.108 (rx_delay=2.30s)
# 12:28:42> MLE_Node2 MLE Rx: message 2: 1,1,1760804919386.108
# 12:28:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,4,1760804919386.1143 (rx_delay=0.79s)
# 12:28:43> MLE_Node2 MLE Rx: message 3: 1,4,1760804919386.1143
# 12:28:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,6,1760804919386.1174 (rx_delay=2.57s)
# 12:28:46> MLE_Node2 MLE Rx: message 4: 1,6,1760804919386.1174
# 12:28:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,7,1760804919386.1187 (rx_delay=0.48s)
# 12:28:46> MLE_Node2 MLE Rx: message 5: 1,7,1760804919386.1187
# 12:28:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,8,1760804919386.12 (rx_delay=0.36s)
# 12:28:47> MLE_Node2 MLE Rx: message 6: 1,8,1760804919386.12
# 12:28:48> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,9,1760804919386.1218 (rx_delay=1.48s)
# 12:28:48> MLE_Node2 MLE Rx: message 7: 1,9,1760804919386.1218
# 12:28:50> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,10,1760804919386.1235 (rx_delay=1.92s)
# 12:28:50> MLE_Node2 MLE Rx: message 8: 1,10,1760804919386.1235
# 12:28:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,11,1760804919386.1248 (rx_delay=1.89s)
# 12:28:52> MLE_Node2 MLE Rx: message 9: 1,11,1760804919386.1248
# 12:28:53> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,11,1760804919386.1248 (rx_delay=1.36s)
# 12:28:53> MLE_Node2 MLE Rx: message 10: 1,11,1760804919386.1248
# 12:28:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,12,1760804919386.126 (rx_delay=2.86s)
# 12:28:56> MLE_Node2 MLE Rx: message 11: 1,12,1760804919386.126
# 12:28:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,13,1760804919386.1277 (rx_delay=0.52s)
# 12:28:57> MLE_Node2 MLE Rx: message 12: 1,13,1760804919386.1277
# 12:28:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,14,1760804919386.1292 (rx_delay=0.78s)
# 12:28:57> MLE_Node2 MLE Rx: message 13: 1,14,1760804919386.1292
# 12:28:59> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,15,1760804919386.1306 (rx_delay=1.29s)
# 12:28:59> MLE_Node2 MLE Rx: message 14: 1,15,1760804919386.1306
# 12:29:01> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,17,1760804919386.1335 (rx_delay=1.98s)
# 12:29:01> MLE_Node2 MLE Rx: message 15: 1,17,1760804919386.1335
# 12:29:01> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,19,1760804919386.1362 (rx_delay=0.68s)
# 12:29:01> MLE_Node2 MLE Rx: message 16: 1,19,1760804919386.1362
# 12:29:01> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,21,1760804919386.139 (rx_delay=0.06s)
# 12:29:01> MLE_Node2 MLE Rx: message 17: 1,21,1760804919386.139
# 12:29:04> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,22,1760804919386.1406 (rx_delay=2.12s)
# 12:29:04> MLE_Node2 MLE Rx: message 18: 1,22,1760804919386.1406
# 12:29:06> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,23,1760804919386.1426 (rx_delay=2.71s)
# 12:29:06> MLE_Node2 MLE Rx: message 19: 1,23,1760804919386.1426
# 12:29:06> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,24,1760804919386.1438 (rx_delay=0.01s)
# 12:29:06> MLE_Node2 MLE Rx: message 20: 1,24,1760804919386.1438
# 12:29:08> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,25,1760804919386.1453 (rx_delay=1.91s)
# 12:29:08> MLE_Node2 MLE Rx: message 21: 1,25,1760804919386.1453
# 12:29:09> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,26,1760804919386.1465 (rx_delay=1.01s)
# 12:29:09> MLE_Node2 MLE Rx: message 22: 1,26,1760804919386.1465
# 12:29:10> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,27,1760804919386.1482 (rx_delay=0.29s)
# 12:29:10> MLE_Node2 MLE Rx: message 23: 1,27,1760804919386.1482
# 12:29:10> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,28,1760804919386.1494 (rx_delay=0.70s)
# 12:29:10> MLE_Node2 MLE Rx: message 24: 1,28,1760804919386.1494
# 12:29:13> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,29,1760804919386.151 (rx_delay=2.32s)
# 12:29:13> MLE_Node2 MLE Rx: message 25: 1,29,1760804919386.151
# 12:29:14> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,30,1760804919386.1523 (rx_delay=1.46s)
# 12:29:14> MLE_Node2 MLE Rx: message 26: 1,30,1760804919386.1523
# 12:29:15> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,32,1760804919386.1553 (rx_delay=1.12s)
# 12:29:15> MLE_Node2 MLE Rx: message 27: 1,32,1760804919386.1553
# 12:29:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,33,1760804919386.1575 (rx_delay=0.49s)
# 12:29:16> MLE_Node2 MLE Rx: message 28: 1,33,1760804919386.1575
# 12:29:18> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,34,1760804919386.1592 (rx_delay=2.35s)
# 12:29:18> MLE_Node2 MLE Rx: message 29: 1,34,1760804919386.1592
# 12:29:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,35,1760804919386.1604 (rx_delay=2.71s)
# 12:29:21> MLE_Node2 MLE Rx: message 30: 1,35,1760804919386.1604
# 12:29:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,36,1760804919386.162 (rx_delay=0.41s)
# 12:29:21> MLE_Node2 MLE Rx: message 31: 1,36,1760804919386.162
# 12:29:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,37,1760804919386.1638 (rx_delay=1.94s)
# 12:29:23> MLE_Node2 MLE Rx: message 32: 1,37,1760804919386.1638
# 12:29:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,38,1760804919386.165 (rx_delay=2.53s)
# 12:29:26> MLE_Node2 MLE Rx: message 33: 1,38,1760804919386.165
# 12:29:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,39,1760804919386.1665 (rx_delay=0.90s)
# 12:29:26> MLE_Node2 MLE Rx: message 34: 1,39,1760804919386.1665
# 12:29:28> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,40,1760804919386.168 (rx_delay=1.64s)
# 12:29:28> MLE_Node2 MLE Rx: message 35: 1,40,1760804919386.168
# 12:29:29> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,42,1760804919386.171 (rx_delay=0.54s)
# 12:29:29> MLE_Node2 MLE Rx: message 36: 1,42,1760804919386.171
# 12:29:32> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,43,1760804919386.172 (rx_delay=2.92s)
# 12:29:32> MLE_Node2 MLE Rx: message 37: 1,43,1760804919386.172
# 12:29:32> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,44,1760804919386.1736 (rx_delay=0.36s)
# 12:29:32> MLE_Node2 MLE Rx: message 38: 1,44,1760804919386.1736
# 12:29:34> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,45,1760804919386.175 (rx_delay=1.96s)
# 12:29:34> MLE_Node2 MLE Rx: message 39: 1,45,1760804919386.175
# 12:29:36> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,46,1760804919386.1765 (rx_delay=2.25s)
# 12:29:36> MLE_Node2 MLE Rx: message 40: 1,46,1760804919386.1765
# 12:29:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,49,1760804919386.1812 (rx_delay=1.69s)
# 12:29:38> MLE_Node2 MLE Rx: message 41: 1,49,1760804919386.1812
# 12:29:39> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,50,1760804919386.1826 (rx_delay=1.56s)
# 12:29:39> MLE_Node2 MLE Rx: message 42: 1,50,1760804919386.1826
# 12:29:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,51,1760804919386.184 (rx_delay=2.84s)
# 12:29:42> MLE_Node2 MLE Rx: message 43: 1,51,1760804919386.184
# 12:29:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,52,1760804919386.1855 (rx_delay=0.48s)
# 12:29:43> MLE_Node2 MLE Rx: message 44: 1,52,1760804919386.1855
# 12:29:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,53,1760804919386.187 (rx_delay=1.08s)
# 12:29:44> MLE_Node2 MLE Rx: message 45: 1,53,1760804919386.187
# 12:29:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,54,1760804919386.1882 (rx_delay=1.71s)
# 12:29:46> MLE_Node2 MLE Rx: message 46: 1,54,1760804919386.1882
# 12:29:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,55,1760804919386.19 (rx_delay=0.83s)
# 12:29:46> MLE_Node2 MLE Rx: message 47: 1,55,1760804919386.19
# 12:29:47> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,56,1760804919386.1914 (rx_delay=0.33s)
# 12:29:47> MLE_Node2 MLE Rx: message 48: 1,56,1760804919386.1914
# 12:29:49> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,57,1760804919386.1929 (rx_delay=2.01s)
# 12:29:49> MLE_Node2 MLE Rx: message 49: 1,57,1760804919386.1929
# 12:29:49> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,58,1760804919386.194 (rx_delay=0.56s)
# 12:29:49> MLE_Node2 MLE Rx: message 50: 1,58,1760804919386.194
# 12:29:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,59,1760804919386.1958 (rx_delay=2.41s)
# 12:29:52> MLE_Node2 MLE Rx: message 51: 1,59,1760804919386.1958
# 12:29:53> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,60,1760804919386.197 (rx_delay=1.71s)
# 12:29:53> MLE_Node2 MLE Rx: message 52: 1,60,1760804919386.197
# 12:29:54> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,61,1760804919386.1985 (rx_delay=0.47s)
# 12:29:54> MLE_Node2 MLE Rx: message 53: 1,61,1760804919386.1985
# 12:29:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,62,1760804919386.1997 (rx_delay=2.03s)
# 12:29:56> MLE_Node2 MLE Rx: message 54: 1,62,1760804919386.1997
# 12:29:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,63,1760804919386.2012 (rx_delay=1.50s)
# 12:29:57> MLE_Node2 MLE Rx: message 55: 1,63,1760804919386.2012
# 12:30:00> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,64,1760804919386.2026 (rx_delay=2.48s)
# 12:30:00> MLE_Node2 MLE Rx: message 56: 1,64,1760804919386.2026
# 12:30:02> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,65,1760804919386.2043 (rx_delay=1.85s)
# 12:30:02> MLE_Node2 MLE Rx: message 57: 1,65,1760804919386.2043
# 12:30:02> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,66,1760804919386.2058 (rx_delay=0.26s)
# 12:30:02> MLE_Node2 MLE Rx: message 58: 1,66,1760804919386.2058
# 12:30:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,67,1760804919386.207 (rx_delay=0.68s)
# 12:30:03> MLE_Node2 MLE Rx: message 59: 1,67,1760804919386.207
# 12:30:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,68,1760804919386.2085 (rx_delay=0.70s)
# 12:30:03> MLE_Node2 MLE Rx: message 60: 1,68,1760804919386.2085
# 12:30:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,69,1760804919386.2097 (rx_delay=1.38s)
# 12:30:05> MLE_Node2 MLE Rx: message 61: 1,69,1760804919386.2097
# 12:30:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,70,1760804919386.2112 (rx_delay=0.41s)
# 12:30:05> MLE_Node2 MLE Rx: message 62: 1,70,1760804919386.2112
# 12:30:06> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,71,1760804919386.2126 (rx_delay=1.22s)
# 12:30:06> MLE_Node2 MLE Rx: message 63: 1,71,1760804919386.2126
# 12:30:09> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,71,1760804919386.2126 (rx_delay=2.32s)
# 12:30:09> MLE_Node2 MLE Rx: message 64: 1,71,1760804919386.2126
# 12:30:09> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,72,1760804919386.2139 (rx_delay=0.13s)
# 12:30:09> MLE_Node2 MLE Rx: message 65: 1,72,1760804919386.2139
# 12:30:12> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,74,1760804919386.2166 (rx_delay=2.99s)
# 12:30:12> MLE_Node2 MLE Rx: message 66: 1,74,1760804919386.2166
# 12:30:13> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,75,1760804919386.218 (rx_delay=0.76s)
# 12:30:13> MLE_Node2 MLE Rx: message 67: 1,75,1760804919386.218
# 12:30:15> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,76,1760804919386.2192 (rx_delay=2.34s)
# 12:30:15> MLE_Node2 MLE Rx: message 68: 1,76,1760804919386.2192
# 12:30:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,77,1760804919386.2207 (rx_delay=1.06s)
# 12:30:16> MLE_Node2 MLE Rx: message 69: 1,77,1760804919386.2207
# 12:30:17> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,78,1760804919386.2222 (rx_delay=0.64s)
# 12:30:17> MLE_Node2 MLE Rx: message 70: 1,78,1760804919386.2222
# 12:30:17> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,79,1760804919386.2236 (rx_delay=0.05s)
# 12:30:17> MLE_Node2 MLE Rx: message 71: 1,79,1760804919386.2236
# 12:30:18> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,80,1760804919386.2249 (rx_delay=0.89s)
# 12:30:18> MLE_Node2 MLE Rx: message 72: 1,80,1760804919386.2249
# 12:30:19> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,81,1760804919386.226 (rx_delay=1.38s)
# 12:30:19> MLE_Node2 MLE Rx: message 73: 1,81,1760804919386.226
# 12:30:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,82,1760804919386.2278 (rx_delay=2.13s)
# 12:30:21> MLE_Node2 MLE Rx: message 74: 1,82,1760804919386.2278
# 12:30:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,83,1760804919386.229 (rx_delay=0.43s)
# 12:30:21> MLE_Node2 MLE Rx: message 75: 1,83,1760804919386.229
# 12:30:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,84,1760804919386.2302 (rx_delay=1.46s)
# 12:30:23> MLE_Node2 MLE Rx: message 76: 1,84,1760804919386.2302
# 12:30:24> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,85,1760804919386.2314 (rx_delay=0.74s)
# 12:30:24> MLE_Node2 MLE Rx: message 77: 1,85,1760804919386.2314
# 12:30:27> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,85,1760804919386.2314 (rx_delay=2.87s)
# 12:30:27> MLE_Node2 MLE Rx: message 78: 1,85,1760804919386.2314
# 12:30:27> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,86,1760804919386.2332 (rx_delay=0.56s)
# 12:30:27> MLE_Node2 MLE Rx: message 79: 1,86,1760804919386.2332
# 12:30:28> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,87,1760804919386.2344 (rx_delay=1.37s)
# 12:30:28> MLE_Node2 MLE Rx: message 80: 1,87,1760804919386.2344
# 12:30:30> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,87,1760804919386.2344 (rx_delay=1.45s)
# 12:30:30> MLE_Node2 MLE Rx: message 81: 1,87,1760804919386.2344
# 12:30:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,88,1760804919386.2356 (rx_delay=0.73s)
# 12:30:31> MLE_Node2 MLE Rx: message 82: 1,88,1760804919386.2356
# 12:30:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,89,1760804919386.2368 (rx_delay=0.16s)
# 12:30:31> MLE_Node2 MLE Rx: message 83: 1,89,1760804919386.2368
# 12:30:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,90,1760804919386.2385 (rx_delay=0.43s)
# 12:30:31> MLE_Node2 MLE Rx: message 84: 1,90,1760804919386.2385
# 12:30:32> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,91,1760804919386.2397 (rx_delay=0.76s)
# 12:30:32> MLE_Node2 MLE Rx: message 85: 1,91,1760804919386.2397
# 12:30:33> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,92,1760804919386.241 (rx_delay=1.16s)
# 12:30:33> MLE_Node2 MLE Rx: message 86: 1,92,1760804919386.241
# 12:30:34> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,93,1760804919386.2422 (rx_delay=0.94s)
# 12:30:34> MLE_Node2 MLE Rx: message 87: 1,93,1760804919386.2422
# 12:30:37> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,95,1760804919386.2454 (rx_delay=2.51s)
# 12:30:37> MLE_Node2 MLE Rx: message 88: 1,95,1760804919386.2454
# 12:30:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,96,1760804919386.2466 (rx_delay=1.15s)
# 12:30:38> MLE_Node2 MLE Rx: message 89: 1,96,1760804919386.2466
# 12:30:39> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,97,1760804919386.2483 (rx_delay=1.47s)
# 12:30:39> MLE_Node2 MLE Rx: message 90: 1,97,1760804919386.2483
# 12:30:41> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,98,1760804919386.2495 (rx_delay=1.71s)
# 12:30:41> MLE_Node2 MLE Rx: message 91: 1,98,1760804919386.2495
# 12:30:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,99,1760804919386.2507 (rx_delay=2.87s)
# 12:30:44> MLE_Node2 MLE Rx: message 92: 1,99,1760804919386.2507
# 12:32:21> PLE_Node1 Tx: message: 1,0,1760805141377.5852
# 12:32:21> PLE_Node1 Tx: message: 1,1,1760805141377.5981
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,2,1760805141377.6
# 12:32:21> PLE_Node1 Tx: message: 1,3,1760805141377.601
# 12:32:21> PLE_Node1 Tx: message: 1,4,1760805141377.6023
# 12:32:21> PLE_Node1 Tx: message: 1,5,1760805141377.6033
# 12:32:21> PLE_Node1 Tx: message: 1,6,1760805141377.604
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,7,1760805141377.6052
# 12:32:21> PLE_Node1 Tx: message: 1,8,1760805141377.6062
# 12:32:21> PLE_Node1 Tx: message: 1,9,1760805141377.607
# 12:32:21> PLE_Node1 Tx: message: 1,10,1760805141377.6082
# 12:32:21> PLE_Node1 Tx: message: 1,11,1760805141377.609
# 12:32:21> PLE_Node1 Tx: message: 1,12,1760805141377.6096
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,13,1760805141377.6108
# 12:32:21> PLE_Node1 Tx: message: 1,14,1760805141377.6118
# 12:32:21> PLE_Node1 Tx: message: 1,15,1760805141377.6125
# 12:32:21> PLE_Node1 Tx: message: 1,16,1760805141377.6135
# 12:32:21> PLE_Node1 Tx: message: 1,17,1760805141377.6145
# 12:32:21> PLE_Node1 Tx: message: 1,18,1760805141377.6155
# 12:32:21> PLE_Node1 Tx: message: 1,19,1760805141377.6165
# 12:32:21> PLE_Node1 Tx: message: 1,20,1760805141377.6174
# 12:32:21> PLE_Node1 Tx: message: 1,21,1760805141377.6182
# 12:32:21> PLE_Node1 Tx: message: 1,22,1760805141377.6191
# 12:32:21> PLE_Node1 Tx: message: 1,23,1760805141377.62
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,24,1760805141377.621
# 12:32:21> PLE_Node1 Tx: message: 1,25,1760805141377.622
# 12:32:21> PLE_Node1 Tx: message: 1,26,1760805141377.6228
# 12:32:21> PLE_Node1 Tx: message: 1,27,1760805141377.6238
# 12:32:21> PLE_Node1 Tx: message: 1,28,1760805141377.6245
# 12:32:21> PLE_Node1 Tx: message: 1,29,1760805141377.6255
# 12:32:21> PLE_Node1 Tx: message: 1,30,1760805141377.6267
# 12:32:21> PLE_Node1 Tx: message: 1,31,1760805141377.6274
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,32,1760805141377.6284
# 12:32:21> PLE_Node1 Tx: message: 1,33,1760805141377.6292
# 12:32:21> PLE_Node1 Tx: message: 1,34,1760805141377.6301
# 12:32:21> PLE_Node1 Tx: message: 1,35,1760805141377.6309
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,36,1760805141377.6323
# 12:32:21> PLE_Node1 Tx: message: 1,37,1760805141377.633
# 12:32:21> PLE_Node1 Tx: message: 1,38,1760805141377.634
# 12:32:21> PLE_Node1 Tx: message: 1,39,1760805141377.635
# 12:32:21> PLE_Node1 Tx: message: 1,40,1760805141377.6357
# 12:32:21> PLE_Node1 Tx: message: 1,41,1760805141377.6367
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,42,1760805141377.6377
# 12:32:21> PLE_Node1 Tx: message: 1,43,1760805141377.6387
# 12:32:21> PLE_Node1 Tx: message: 1,44,1760805141377.6394
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,45,1760805141377.6404
# 12:32:21> PLE_Node1 Tx: message: 1,46,1760805141377.641
# 12:32:21> PLE_Node1 Tx: message: 1,47,1760805141377.6423
# 12:32:21> PLE_Node1 Tx: message: 1,48,1760805141377.643
# 12:32:21> PLE_Node1 Tx: message: 1,49,1760805141377.644
# 12:32:21> PLE_Node1 Tx: message: 1,50,1760805141377.6448
# 12:32:21> PLE_Node1 Tx: message: 1,51,1760805141377.6458
# 12:32:21> PLE_Node1 Tx: message: 1,52,1760805141377.6465
# 12:32:21> PLE_Node1 Tx: message: 1,53,1760805141377.6477
# 12:32:21> PLE_Node1 Tx: message: 1,54,1760805141377.6484
# 12:32:21> PLE_Node1 Tx: message: 1,55,1760805141377.6494
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,56,1760805141377.6501
# 12:32:21> PLE_Node1 Tx: message: 1,57,1760805141377.6511
# 12:32:21> PLE_Node1 Tx: message: 1,58,1760805141377.6523
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,59,1760805141377.653
# 12:32:21> PLE_Node1 Tx: message: 1,60,1760805141377.654
# 12:32:21> PLE_Node1 Tx: message: 1,61,1760805141377.655
# 12:32:21> PLE_Node1 Tx: message: 1,62,1760805141377.656
# 12:32:21> PLE_Node1 Tx: message: 1,63,1760805141377.6567
# 12:32:21> PLE_Node1 Tx: message: 1,64,1760805141377.6577
# 12:32:21> PLE_Node1 Tx: message: 1,65,1760805141377.6587
# 12:32:21> PLE_Node1 Tx: message: 1,66,1760805141377.6594
# 12:32:21> PLE_Node1 Tx: message: 1,67,1760805141377.6604
# 12:32:21> PLE_Node1 Tx: message: 1,68,1760805141377.6611
# 12:32:21> PLE_Node1 Tx: message: 1,69,1760805141377.662
# 12:32:21> PLE_Node1 PLE: duplicate transmission (5%)
# 12:32:21> PLE_Node1 Tx: message: 1,70,1760805141377.663
# 12:32:21> PLE_Node1 Tx: message: 1,71,1760805141377.664
# 12:32:21> PLE_Node1 Tx: message: 1,72,1760805141377.6648
# 12:32:21> PLE_Node1 Tx: message: 1,73,1760805141377.6658
# 12:32:21> PLE_Node1 Tx: message: 1,74,1760805141377.6665
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,75,1760805141377.6675
# 12:32:21> PLE_Node1 Tx: message: 1,76,1760805141377.6685
# 12:32:21> PLE_Node1 Tx: message: 1,77,1760805141377.6694
# 12:32:21> PLE_Node1 PLE: duplicate transmission (5%)
# 12:32:21> PLE_Node1 Tx: message: 1,78,1760805141377.6702
# 12:32:21> PLE_Node1 Tx: message: 1,79,1760805141377.6711
# 12:32:21> PLE_Node1 Tx: message: 1,80,1760805141377.6719
# 12:32:21> PLE_Node1 Tx: message: 1,81,1760805141377.673
# 12:32:21> PLE_Node1 Tx: message: 1,82,1760805141377.674
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,83,1760805141377.6748
# 12:32:21> PLE_Node1 Tx: message: 1,84,1760805141377.6758
# 12:32:21> PLE_Node1 Tx: message: 1,85,1760805141377.6765
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,86,1760805141377.6772
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,87,1760805141377.6782
# 12:32:21> PLE_Node1 Tx: message: 1,88,1760805141377.6792
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,89,1760805141377.68
# 12:32:21> PLE_Node1 Tx: message: 1,90,1760805141377.681
# 12:32:21> PLE_Node1 Tx: message: 1,91,1760805141377.682
# 12:32:21> PLE_Node1 Tx: message: 1,92,1760805141377.6826
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,93,1760805141377.6836
# 12:32:21> PLE_Node1 Tx: message: 1,94,1760805141377.6846
# 12:32:21> PLE_Node1 Tx: message: 1,95,1760805141377.6853
# 12:32:21> PLE_Node1 Tx: message: 1,96,1760805141377.6863
# 12:32:21> PLE_Node1 Tx: message: 1,97,1760805141377.6873
# 12:32:21> PLE_Node1 Tx: message: 1,98,1760805141377.688
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node1 Tx: message: 1,99,1760805141377.6887
# 12:32:21> PLE_Node1 PLE: packet loss (15%)
# 12:32:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,0,1760805141377.5852 (rx_delay=0.48s)
# 12:32:21> MLE_Node2 MLE Rx: message 93: 1,0,1760805141377.5852
# 12:32:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,2,1760805141377.6 (rx_delay=0.13s)
# 12:32:21> MLE_Node2 MLE Rx: message 94: 1,2,1760805141377.6
# 12:32:22> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,3,1760805141377.601 (rx_delay=0.18s)
# 12:32:22> MLE_Node2 MLE Rx: message 95: 1,3,1760805141377.601
# 12:32:22> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,4,1760805141377.6023 (rx_delay=0.20s)
# 12:32:22> MLE_Node2 MLE Rx: message 96: 1,4,1760805141377.6023
# 12:32:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,5,1760805141377.6033 (rx_delay=0.91s)
# 12:32:23> MLE_Node2 MLE Rx: message 97: 1,5,1760805141377.6033
# 12:32:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,7,1760805141377.6052 (rx_delay=0.32s)
# 12:32:23> MLE_Node2 MLE Rx: message 98: 1,7,1760805141377.6052
# 12:32:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,8,1760805141377.6062 (rx_delay=0.34s)
# 12:32:23> MLE_Node2 MLE Rx: message 99: 1,8,1760805141377.6062
# 12:32:24> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,9,1760805141377.607 (rx_delay=0.97s)
# 12:32:24> MLE_Node2 MLE Rx: message 100: 1,9,1760805141377.607
# 12:32:25> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,10,1760805141377.6082 (rx_delay=0.76s)
# 12:32:25> MLE_Node2 MLE Rx: message 101: 1,10,1760805141377.6082
# 12:32:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,11,1760805141377.609 (rx_delay=0.55s)
# 12:32:26> MLE_Node2 MLE Rx: message 102: 1,11,1760805141377.609
# 12:32:28> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,13,1760805141377.6108 (rx_delay=2.32s)
# 12:32:28> MLE_Node2 MLE Rx: message 103: 1,13,1760805141377.6108
# 12:32:29> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,14,1760805141377.6118 (rx_delay=0.49s)
# 12:32:29> MLE_Node2 MLE Rx: message 104: 1,14,1760805141377.6118
# 12:32:29> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,15,1760805141377.6125 (rx_delay=0.44s)
# 12:32:29> MLE_Node2 MLE Rx: message 105: 1,15,1760805141377.6125
# 12:32:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,16,1760805141377.6135 (rx_delay=1.72s)
# 12:32:31> MLE_Node2 MLE Rx: message 106: 1,16,1760805141377.6135
# 12:32:32> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,17,1760805141377.6145 (rx_delay=1.58s)
# 12:32:32> MLE_Node2 MLE Rx: message 107: 1,17,1760805141377.6145
# 12:32:35> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,18,1760805141377.6155 (rx_delay=2.39s)
# 12:32:35> MLE_Node2 MLE Rx: message 108: 1,18,1760805141377.6155
# 12:32:35> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,19,1760805141377.6165 (rx_delay=0.34s)
# 12:32:35> MLE_Node2 MLE Rx: message 109: 1,19,1760805141377.6165
# 12:32:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,20,1760805141377.6174 (rx_delay=2.92s)
# 12:32:38> MLE_Node2 MLE Rx: message 110: 1,20,1760805141377.6174
# 12:32:39> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,21,1760805141377.6182 (rx_delay=1.40s)
# 12:32:39> MLE_Node2 MLE Rx: message 111: 1,21,1760805141377.6182
# 12:32:40> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,22,1760805141377.6191 (rx_delay=0.97s)
# 12:32:40> MLE_Node2 MLE Rx: message 112: 1,22,1760805141377.6191
# 12:32:40> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,24,1760805141377.621 (rx_delay=0.07s)
# 12:32:40> MLE_Node2 MLE Rx: message 113: 1,24,1760805141377.621
# 12:32:42> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,25,1760805141377.622 (rx_delay=1.92s)
# 12:32:42> MLE_Node2 MLE Rx: message 114: 1,25,1760805141377.622
# 12:32:44> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,26,1760805141377.6228 (rx_delay=1.31s)
# 12:32:44> MLE_Node2 MLE Rx: message 115: 1,26,1760805141377.6228
# 12:32:46> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,27,1760805141377.6238 (rx_delay=2.53s)
# 12:32:46> MLE_Node2 MLE Rx: message 116: 1,27,1760805141377.6238
# 12:32:49> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,28,1760805141377.6245 (rx_delay=3.00s)
# 12:32:49> MLE_Node2 MLE Rx: message 117: 1,28,1760805141377.6245
# 12:32:50> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,29,1760805141377.6255 (rx_delay=1.34s)
# 12:32:50> MLE_Node2 MLE Rx: message 118: 1,29,1760805141377.6255
# 12:32:50> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,30,1760805141377.6267 (rx_delay=0.03s)
# 12:32:50> MLE_Node2 MLE Rx: message 119: 1,30,1760805141377.6267
# 12:32:53> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,32,1760805141377.6284 (rx_delay=2.80s)
# 12:32:53> MLE_Node2 MLE Rx: message 120: 1,32,1760805141377.6284
# 12:32:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,33,1760805141377.6292 (rx_delay=2.88s)
# 12:32:56> MLE_Node2 MLE Rx: message 121: 1,33,1760805141377.6292
# 12:32:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,34,1760805141377.6301 (rx_delay=0.14s)
# 12:32:56> MLE_Node2 MLE Rx: message 122: 1,34,1760805141377.6301
# 12:32:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,36,1760805141377.6323 (rx_delay=0.49s)
# 12:32:57> MLE_Node2 MLE Rx: message 123: 1,36,1760805141377.6323
# 12:32:57> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,37,1760805141377.633 (rx_delay=0.32s)
# 12:32:57> MLE_Node2 MLE Rx: message 124: 1,37,1760805141377.633
# 12:33:00> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,38,1760805141377.634 (rx_delay=2.99s)
# 12:33:00> MLE_Node2 MLE Rx: message 125: 1,38,1760805141377.634
# 12:33:02> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,39,1760805141377.635 (rx_delay=2.29s)
# 12:33:02> MLE_Node2 MLE Rx: message 126: 1,39,1760805141377.635
# 12:33:04> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,40,1760805141377.6357 (rx_delay=1.47s)
# 12:33:04> MLE_Node2 MLE Rx: message 127: 1,40,1760805141377.6357
# 12:33:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,42,1760805141377.6377 (rx_delay=0.76s)
# 12:33:05> MLE_Node2 MLE Rx: message 128: 1,42,1760805141377.6377
# 12:33:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,43,1760805141377.6387 (rx_delay=0.73s)
# 12:33:05> MLE_Node2 MLE Rx: message 129: 1,43,1760805141377.6387
# 12:33:08> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,45,1760805141377.6404 (rx_delay=2.89s)
# 12:33:08> MLE_Node2 MLE Rx: message 130: 1,45,1760805141377.6404
# 12:33:10> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,46,1760805141377.641 (rx_delay=1.53s)
# 12:33:10> MLE_Node2 MLE Rx: message 131: 1,46,1760805141377.641
# 12:33:12> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,47,1760805141377.6423 (rx_delay=2.61s)
# 12:33:12> MLE_Node2 MLE Rx: message 132: 1,47,1760805141377.6423
# 12:33:13> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,48,1760805141377.643 (rx_delay=0.37s)
# 12:33:13> MLE_Node2 MLE Rx: message 133: 1,48,1760805141377.643
# 12:33:15> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,49,1760805141377.644 (rx_delay=2.06s)
# 12:33:15> MLE_Node2 MLE Rx: message 134: 1,49,1760805141377.644
# 12:33:17> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,50,1760805141377.6448 (rx_delay=2.24s)
# 12:33:17> MLE_Node2 MLE Rx: message 135: 1,50,1760805141377.6448
# 12:33:20> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,51,1760805141377.6458 (rx_delay=2.66s)
# 12:33:20> MLE_Node2 MLE Rx: message 136: 1,51,1760805141377.6458
# 12:33:20> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,52,1760805141377.6465 (rx_delay=0.56s)
# 12:33:20> MLE_Node2 MLE Rx: message 137: 1,52,1760805141377.6465
# 12:33:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,53,1760805141377.6477 (rx_delay=2.98s)
# 12:33:23> MLE_Node2 MLE Rx: message 138: 1,53,1760805141377.6477
# 12:33:26> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,54,1760805141377.6484 (rx_delay=2.71s)
# 12:33:26> MLE_Node2 MLE Rx: message 139: 1,54,1760805141377.6484
# 12:33:27> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,56,1760805141377.6501 (rx_delay=1.20s)
# 12:33:27> MLE_Node2 MLE Rx: message 140: 1,56,1760805141377.6501
# 12:33:30> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,57,1760805141377.6511 (rx_delay=2.78s)
# 12:33:30> MLE_Node2 MLE Rx: message 141: 1,57,1760805141377.6511
# 12:33:30> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,59,1760805141377.653 (rx_delay=0.42s)
# 12:33:30> MLE_Node2 MLE Rx: message 142: 1,59,1760805141377.653
# 12:33:31> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,60,1760805141377.654 (rx_delay=0.38s)
# 12:33:31> MLE_Node2 MLE Rx: message 143: 1,60,1760805141377.654
# 12:33:33> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,61,1760805141377.655 (rx_delay=2.63s)
# 12:33:33> MLE_Node2 MLE Rx: message 144: 1,61,1760805141377.655
# 12:33:35> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,62,1760805141377.656 (rx_delay=1.98s)
# 12:33:35> MLE_Node2 MLE Rx: message 145: 1,62,1760805141377.656
# 12:33:38> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,63,1760805141377.6567 (rx_delay=2.52s)
# 12:33:38> MLE_Node2 MLE Rx: message 146: 1,63,1760805141377.6567
# 12:33:41> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,64,1760805141377.6577 (rx_delay=2.89s)
# 12:33:41> MLE_Node2 MLE Rx: message 147: 1,64,1760805141377.6577
# 12:33:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,65,1760805141377.6587 (rx_delay=2.57s)
# 12:33:43> MLE_Node2 MLE Rx: message 148: 1,65,1760805141377.6587
# 12:33:43> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,66,1760805141377.6594 (rx_delay=0.15s)
# 12:33:43> MLE_Node2 MLE Rx: message 149: 1,66,1760805141377.6594
# 12:33:45> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,67,1760805141377.6604 (rx_delay=2.01s)
# 12:33:45> MLE_Node2 MLE Rx: message 150: 1,67,1760805141377.6604
# 12:33:48> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,68,1760805141377.6611 (rx_delay=2.35s)
# 12:33:48> MLE_Node2 MLE Rx: message 151: 1,68,1760805141377.6611
# 12:33:49> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,69,1760805141377.662 (rx_delay=0.81s)
# 12:33:49> MLE_Node2 MLE Rx: message 152: 1,69,1760805141377.662
# 12:33:50> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,69,1760805141377.662 (rx_delay=1.48s)
# 12:33:50> MLE_Node2 MLE Rx: message 153: 1,69,1760805141377.662
# 12:33:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,70,1760805141377.663 (rx_delay=1.88s)
# 12:33:52> MLE_Node2 MLE Rx: message 154: 1,70,1760805141377.663
# 12:33:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,71,1760805141377.664 (rx_delay=0.14s)
# 12:33:52> MLE_Node2 MLE Rx: message 155: 1,71,1760805141377.664
# 12:33:52> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,72,1760805141377.6648 (rx_delay=0.23s)
# 12:33:52> MLE_Node2 MLE Rx: message 156: 1,72,1760805141377.6648
# 12:33:54> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,73,1760805141377.6658 (rx_delay=1.58s)
# 12:33:54> MLE_Node2 MLE Rx: message 157: 1,73,1760805141377.6658
# 12:33:56> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,75,1760805141377.6675 (rx_delay=2.25s)
# 12:33:56> MLE_Node2 MLE Rx: message 158: 1,75,1760805141377.6675
# 12:33:59> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,76,1760805141377.6685 (rx_delay=2.54s)
# 12:33:59> MLE_Node2 MLE Rx: message 159: 1,76,1760805141377.6685
# 12:34:00> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,77,1760805141377.6694 (rx_delay=1.75s)
# 12:34:00> MLE_Node2 MLE Rx: message 160: 1,77,1760805141377.6694
# 12:34:01> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,77,1760805141377.6694 (rx_delay=0.05s)
# 12:34:01> MLE_Node2 MLE Rx: message 161: 1,77,1760805141377.6694
# 12:34:03> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,78,1760805141377.6702 (rx_delay=2.55s)
# 12:34:03> MLE_Node2 MLE Rx: message 162: 1,78,1760805141377.6702
# 12:34:05> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,79,1760805141377.6711 (rx_delay=2.38s)
# 12:34:05> MLE_Node2 MLE Rx: message 163: 1,79,1760805141377.6711
# 12:34:06> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,80,1760805141377.6719 (rx_delay=0.95s)
# 12:34:06> MLE_Node2 MLE Rx: message 164: 1,80,1760805141377.6719
# 12:34:07> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,81,1760805141377.673 (rx_delay=0.82s)
# 12:34:07> MLE_Node2 MLE Rx: message 165: 1,81,1760805141377.673
# 12:34:08> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,83,1760805141377.6748 (rx_delay=0.42s)
# 12:34:08> MLE_Node2 MLE Rx: message 166: 1,83,1760805141377.6748
# 12:34:11> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,84,1760805141377.6758 (rx_delay=2.94s)
# 12:34:11> MLE_Node2 MLE Rx: message 167: 1,84,1760805141377.6758
# 12:34:13> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,87,1760805141377.6782 (rx_delay=2.09s)
# 12:34:13> MLE_Node2 MLE Rx: message 168: 1,87,1760805141377.6782
# 12:34:13> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,89,1760805141377.68 (rx_delay=0.71s)
# 12:34:13> MLE_Node2 MLE Rx: message 169: 1,89,1760805141377.68
# 12:34:15> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,90,1760805141377.681 (rx_delay=1.31s)
# 12:34:15> MLE_Node2 MLE Rx: message 170: 1,90,1760805141377.681
# 12:34:16> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,91,1760805141377.682 (rx_delay=0.82s)
# 12:34:16> MLE_Node2 MLE Rx: message 171: 1,91,1760805141377.682
# 12:34:18> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,93,1760805141377.6836 (rx_delay=2.82s)
# 12:34:18> MLE_Node2 MLE Rx: message 172: 1,93,1760805141377.6836
# 12:34:20> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,94,1760805141377.6846 (rx_delay=1.37s)
# 12:34:20> MLE_Node2 MLE Rx: message 173: 1,94,1760805141377.6846
# 12:34:21> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,95,1760805141377.6853 (rx_delay=1.58s)
# 12:34:21> MLE_Node2 MLE Rx: message 174: 1,95,1760805141377.6853
# 12:34:22> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,96,1760805141377.6863 (rx_delay=1.05s)
# 12:34:22> MLE_Node2 MLE Rx: message 175: 1,96,1760805141377.6863
# 12:34:23> PLE_Node2 Rx: from ('127.0.0.1', 32222): 1,97,1760805141377.6873 (rx_delay=0.55s)
# 12:34:23> MLE_Node2 MLE Rx: message 176: 1,97,1760805141377.6873

# %%
# Experiment 2: Two Nodes and Three Layers
# MLE_TR
# 
# DLE_TR
#
# PLE_TR

exp_out = EXP_Output()
# Node 1
AP_local_5 = ("127.0.0.1", 33333)
AP_remote_5 = ("127.0.0.1", 34000)

Socket_5 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_5 = PLE_TR("PLE_Node1", Socket_5, AP_remote_5, AP_local_5, exp_out)
DLE_3 = DLE_TR_FSM("DLE_Node1", PLE_5, exp_out)
MLE_3 = MLE_TR("MLE_Node1", 2, DLE_3, exp_out)

# Node 2
AP_local_6 = ("127.0.0.1", 34000)
AP_remote_6 = ("127.0.0.1", 33333)

Socket_6 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
PLE_6 = PLE_TR("PLE_Node2", Socket_6, AP_remote_6, AP_local_6, exp_out)
DLE_4 = DLE_TR_FSM("DLE_Node2", PLE_6, exp_out)
MLE_4 = MLE_TR("MLE_Node2", 2, DLE_4, exp_out)
# Out:
# Button(description='Send 100 messages from MLE_Node1.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# Button(description='Send 100 messages from MLE_Node2.', layout=Layout(width='500px'), style=ButtonStyle(), too…
# 12:28:36> PLE_Node1: loop_Rx starting
# 12:28:36> PLE_Node1: loop_Tx starting
# 12:28:36> DLE_Node1: loop_Rx starting
# 12:28:36> DLE_Node1: loop_Tx starting
# 12:28:36> DLE_Node1: loop_FSM starting
# 12:28:36> DLE_Node1: loop_Timer starting
# 12:28:36> MLE_Node1: MLE loop_Rx starting
# 12:28:36> PLE_Node2: loop_Rx starting
# 12:28:36> PLE_Node2: loop_Tx starting
# 12:28:36> DLE_Node2: loop_Rx starting
# 12:28:36> DLE_Node2: loop_Tx starting
# 12:28:36> DLE_Node2: loop_FSM starting
# 12:28:36> DLE_Node2: loop_Timer starting
# 12:28:36> MLE_Node2: MLE loop_Rx starting
# 12:38:08> DLE_Node1 Tx: message 1: 2,0,1760805488678.2913
# 12:38:08> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:08> DLE_Node1 FSM: to send: 2,0,1760805488678.2913
# 12:38:08> PLE_Node1 Tx: message: 002,0,1760805488678.2913
# 12:38:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,0,1760805488678.2913 (rx_delay=0.34s)
# 12:38:09> DLE_Node2 Rx: message 1: 002,0,1760805488678.2913
# 12:38:09> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:09> DLE_Node2 FSM: received: 2,0,1760805488678.2913
# 12:38:09> MLE_Node2 MLE Rx: message 1: 2,0,1760805488678.2913
# 12:38:09> PLE_Node2 Tx: message: 10
# 12:38:10> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.35s)
# 12:38:10> DLE_Node1 Rx: message 1: 10
# 12:38:10> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:10> DLE_Node1 Tx: message 2: 2,1,1760805488678.3062
# 12:38:10> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:10> DLE_Node1 FSM: to send: 2,1,1760805488678.3062
# 12:38:10> PLE_Node1 Tx: message: 012,1,1760805488678.3062
# 12:38:12> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,1,1760805488678.3062 (rx_delay=2.36s)
# 12:38:12> DLE_Node2 Rx: message 2: 012,1,1760805488678.3062
# 12:38:12> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:12> DLE_Node2 FSM: received: 2,1,1760805488678.3062
# 12:38:12> MLE_Node2 MLE Rx: message 2: 2,1,1760805488678.3062
# 12:38:12> PLE_Node2 Tx: message: 11
# 12:38:13> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.25s)
# 12:38:13> DLE_Node1 Rx: message 2: 11
# 12:38:13> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:13> DLE_Node1 Tx: message 3: 2,2,1760805488678.308
# 12:38:13> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:13> DLE_Node1 FSM: to send: 2,2,1760805488678.308
# 12:38:13> PLE_Node1 Tx: message: 022,2,1760805488678.308
# 12:38:16> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,2,1760805488678.308 (rx_delay=2.06s)
# 12:38:16> DLE_Node2 Rx: message 3: 022,2,1760805488678.308
# 12:38:16> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:16> DLE_Node2 FSM: received: 2,2,1760805488678.308
# 12:38:16> MLE_Node2 MLE Rx: message 3: 2,2,1760805488678.308
# 12:38:16> PLE_Node2 Tx: message: 12
# 12:38:16> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=0.34s)
# 12:38:16> DLE_Node1 Rx: message 3: 12
# 12:38:16> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:16> DLE_Node1 Tx: message 4: 2,3,1760805488678.3096
# 12:38:16> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:16> DLE_Node1 FSM: to send: 2,3,1760805488678.3096
# 12:38:16> PLE_Node1 Tx: message: 032,3,1760805488678.3096
# 12:38:17> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,3,1760805488678.3096 (rx_delay=0.70s)
# 12:38:17> DLE_Node2 Rx: message 4: 032,3,1760805488678.3096
# 12:38:17> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:17> DLE_Node2 FSM: received: 2,3,1760805488678.3096
# 12:38:17> PLE_Node2 Tx: message: 13
# 12:38:17> MLE_Node2 MLE Rx: message 4: 2,3,1760805488678.3096
# 12:38:19> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=2.07s)
# 12:38:19> DLE_Node1 Rx: message 4: 13
# 12:38:19> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:19> DLE_Node1 Tx: message 5: 2,4,1760805488678.3105
# 12:38:19> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:19> DLE_Node1 FSM: to send: 2,4,1760805488678.3105
# 12:38:19> PLE_Node1 Tx: message: 042,4,1760805488678.3105
# 12:38:20> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,4,1760805488678.3105 (rx_delay=1.45s)
# 12:38:20> DLE_Node2 Rx: message 5: 042,4,1760805488678.3105
# 12:38:20> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:20> DLE_Node2 FSM: received: 2,4,1760805488678.3105
# 12:38:20> MLE_Node2 MLE Rx: message 5: 2,4,1760805488678.3105
# 12:38:20> PLE_Node2 Tx: message: 14
# 12:38:20> PLE_Node2 PLE: packet loss (15%)
# 12:38:24> DLE_Node1 FSM: state: 1 event type: 3
# 12:38:24> DLE_Node1 FSM: to resend frame 4 2,4,1760805488678.3105
# 12:38:24> PLE_Node1 Tx: message: 042,4,1760805488678.3105
# 12:38:27> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,4,1760805488678.3105 (rx_delay=2.40s)
# 12:38:27> DLE_Node2 Rx: message 6: 042,4,1760805488678.3105
# 12:38:27> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:27> DLE_Node2 FSM: received: 2,4,1760805488678.3105
# 12:38:27> DLE_Node2 FSM: received received frame 4 but expected 5
# 12:38:27> PLE_Node2 Tx: message: 14
# 12:38:27> PLE_Node2 PLE: packet loss (15%)
# 12:38:30> DLE_Node1 FSM: state: 1 event type: 3
# 12:38:30> DLE_Node1 FSM: to resend frame 4 2,4,1760805488678.3105
# 12:38:30> PLE_Node1 Tx: message: 042,4,1760805488678.3105
# 12:38:31> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,4,1760805488678.3105 (rx_delay=1.56s)
# 12:38:31> DLE_Node2 Rx: message 7: 042,4,1760805488678.3105
# 12:38:31> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:31> DLE_Node2 FSM: received: 2,4,1760805488678.3105
# 12:38:31> DLE_Node2 FSM: received received frame 4 but expected 5
# 12:38:31> PLE_Node2 Tx: message: 14
# 12:38:31> PLE_Node2 PLE: packet loss (15%)
# 12:38:35> DLE_Node1 FSM: state: 1 event type: 3
# 12:38:35> DLE_Node1 FSM: to resend frame 4 2,4,1760805488678.3105
# 12:38:35> PLE_Node1 Tx: message: 042,4,1760805488678.3105
# 12:38:37> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,4,1760805488678.3105 (rx_delay=1.80s)
# 12:38:37> DLE_Node2 Rx: message 8: 042,4,1760805488678.3105
# 12:38:37> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:37> DLE_Node2 FSM: received: 2,4,1760805488678.3105
# 12:38:37> DLE_Node2 FSM: received received frame 4 but expected 5
# 12:38:37> PLE_Node2 Tx: message: 14
# 12:38:39> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=1.72s)
# 12:38:39> DLE_Node1 Rx: message 5: 14
# 12:38:39> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:39> DLE_Node1 Tx: message 6: 2,5,1760805488678.312
# 12:38:39> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:39> DLE_Node1 FSM: to send: 2,5,1760805488678.312
# 12:38:39> PLE_Node1 Tx: message: 052,5,1760805488678.312
# 12:38:41> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,5,1760805488678.312 (rx_delay=2.65s)
# 12:38:41> DLE_Node2 Rx: message 9: 052,5,1760805488678.312
# 12:38:41> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:41> DLE_Node2 FSM: received: 2,5,1760805488678.312
# 12:38:41> PLE_Node2 Tx: message: 15
# 12:38:41> MLE_Node2 MLE Rx: message 6: 2,5,1760805488678.312
# 12:38:43> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.73s)
# 12:38:43> DLE_Node1 Rx: message 6: 15
# 12:38:43> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:43> DLE_Node1 Tx: message 7: 2,6,1760805488678.313
# 12:38:43> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:43> DLE_Node1 FSM: to send: 2,6,1760805488678.313
# 12:38:43> PLE_Node1 Tx: message: 062,6,1760805488678.313
# 12:38:43> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,6,1760805488678.313 (rx_delay=0.13s)
# 12:38:43> DLE_Node2 Rx: message 10: 062,6,1760805488678.313
# 12:38:43> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:43> DLE_Node2 FSM: received: 2,6,1760805488678.313
# 12:38:43> MLE_Node2 MLE Rx: message 7: 2,6,1760805488678.313
# 12:38:43> PLE_Node2 Tx: message: 16
# 12:38:46> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=2.82s)
# 12:38:46> DLE_Node1 Rx: message 7: 16
# 12:38:46> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:46> DLE_Node1 Tx: message 8: 2,7,1760805488678.3137
# 12:38:46> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:46> DLE_Node1 FSM: to send: 2,7,1760805488678.3137
# 12:38:46> PLE_Node1 Tx: message: 072,7,1760805488678.3137
# 12:38:46> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,7,1760805488678.3137 (rx_delay=0.17s)
# 12:38:46> DLE_Node2 Rx: message 11: 072,7,1760805488678.3137
# 12:38:46> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:46> DLE_Node2 FSM: received: 2,7,1760805488678.3137
# 12:38:46> MLE_Node2 MLE Rx: message 8: 2,7,1760805488678.3137
# 12:38:46> PLE_Node2 Tx: message: 17
# 12:38:46> PLE_Node2 PLE: duplicate transmission (5%)
# 12:38:46> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.26s)
# 12:38:46> DLE_Node1 Rx: message 8: 17
# 12:38:46> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:46> DLE_Node1 Tx: message 9: 2,8,1760805488678.315
# 12:38:46> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:46> DLE_Node1 FSM: to send: 2,8,1760805488678.315
# 12:38:46> PLE_Node1 Tx: message: 082,8,1760805488678.315
# 12:38:46> PLE_Node1 PLE: duplicate transmission (5%)
# 12:38:48> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,8,1760805488678.315 (rx_delay=1.29s)
# 12:38:48> DLE_Node2 Rx: message 12: 082,8,1760805488678.315
# 12:38:48> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:48> DLE_Node2 FSM: received: 2,8,1760805488678.315
# 12:38:48> PLE_Node2 Tx: message: 18
# 12:38:48> MLE_Node2 MLE Rx: message 9: 2,8,1760805488678.315
# 12:38:49> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,8,1760805488678.315 (rx_delay=0.81s)
# 12:38:49> DLE_Node2 Rx: message 13: 082,8,1760805488678.315
# 12:38:49> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:49> DLE_Node2 FSM: received: 2,8,1760805488678.315
# 12:38:49> DLE_Node2 FSM: received received frame 8 but expected 9
# 12:38:49> PLE_Node2 Tx: message: 18
# 12:38:49> PLE_Node2 PLE: packet loss (15%)
# 12:38:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.46s)
# 12:38:49> DLE_Node1 Rx: message 9: 17
# 12:38:49> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:49> ACK # 7 does not match local seq # 8
# 12:38:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=0.25s)
# 12:38:49> DLE_Node1 Rx: message 10: 18
# 12:38:49> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:49> DLE_Node1 Tx: message 10: 2,9,1760805488678.3157
# 12:38:49> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:49> DLE_Node1 FSM: to send: 2,9,1760805488678.3157
# 12:38:49> PLE_Node1 Tx: message: 092,9,1760805488678.3157
# 12:38:49> PLE_Node1 PLE: duplicate transmission (5%)
# 12:38:51> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,9,1760805488678.3157 (rx_delay=1.52s)
# 12:38:51> DLE_Node2 Rx: message 14: 092,9,1760805488678.3157
# 12:38:51> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:51> DLE_Node2 FSM: received: 2,9,1760805488678.3157
# 12:38:51> MLE_Node2 MLE Rx: message 10: 2,9,1760805488678.3157
# 12:38:51> PLE_Node2 Tx: message: 19
# 12:38:51> PLE_Node2 PLE: packet loss (15%)
# 12:38:51> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,9,1760805488678.3157 (rx_delay=0.30s)
# 12:38:51> DLE_Node2 Rx: message 15: 092,9,1760805488678.3157
# 12:38:51> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:51> DLE_Node2 FSM: received: 2,9,1760805488678.3157
# 12:38:51> DLE_Node2 FSM: received received frame 9 but expected 0
# 12:38:51> PLE_Node2 Tx: message: 19
# 12:38:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.91s)
# 12:38:52> DLE_Node1 Rx: message 11: 19
# 12:38:52> DLE_Node1 FSM: state: 1 event type: 2
# 12:38:52> DLE_Node1 Tx: message 11: 2,10,1760805488678.3171
# 12:38:52> DLE_Node1 FSM: state: 0 event type: 0
# 12:38:52> DLE_Node1 FSM: to send: 2,10,1760805488678.3171
# 12:38:52> PLE_Node1 Tx: message: 002,10,1760805488678.3171
# 12:38:53> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,10,1760805488678.3171 (rx_delay=0.60s)
# 12:38:53> DLE_Node2 Rx: message 16: 002,10,1760805488678.3171
# 12:38:53> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:53> DLE_Node2 FSM: received: 2,10,1760805488678.3171
# 12:38:53> MLE_Node2 MLE Rx: message 11: 2,10,1760805488678.3171
# 12:38:53> PLE_Node2 Tx: message: 10
# 12:38:53> PLE_Node2 PLE: packet loss (15%)
# 12:38:58> DLE_Node1 FSM: state: 1 event type: 3
# 12:38:58> DLE_Node1 FSM: to resend frame 0 2,10,1760805488678.3171
# 12:38:58> PLE_Node1 Tx: message: 002,10,1760805488678.3171
# 12:38:59> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,10,1760805488678.3171 (rx_delay=0.93s)
# 12:38:59> DLE_Node2 Rx: message 17: 002,10,1760805488678.3171
# 12:38:59> DLE_Node2 FSM: state: 0 event type: 1
# 12:38:59> DLE_Node2 FSM: received: 2,10,1760805488678.3171
# 12:38:59> DLE_Node2 FSM: received received frame 0 but expected 1
# 12:38:59> PLE_Node2 Tx: message: 10
# 12:39:01> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=2.57s)
# 12:39:01> DLE_Node1 Rx: message 12: 10
# 12:39:01> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:01> DLE_Node1 Tx: message 12: 2,11,1760805488678.3179
# 12:39:01> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:01> DLE_Node1 FSM: to send: 2,11,1760805488678.3179
# 12:39:01> PLE_Node1 Tx: message: 012,11,1760805488678.3179
# 12:39:01> PLE_Node1 PLE: packet loss (15%)
# 12:39:07> DLE_Node1 FSM: state: 1 event type: 3
# 12:39:07> DLE_Node1 FSM: to resend frame 1 2,11,1760805488678.3179
# 12:39:07> PLE_Node1 Tx: message: 012,11,1760805488678.3179
# 12:39:08> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,11,1760805488678.3179 (rx_delay=1.52s)
# 12:39:08> DLE_Node2 Rx: message 18: 012,11,1760805488678.3179
# 12:39:08> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:08> DLE_Node2 FSM: received: 2,11,1760805488678.3179
# 12:39:08> MLE_Node2 MLE Rx: message 12: 2,11,1760805488678.3179
# 12:39:08> PLE_Node2 Tx: message: 11
# 12:39:10> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=1.27s)
# 12:39:10> DLE_Node1 Rx: message 13: 11
# 12:39:10> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:10> DLE_Node1 Tx: message 13: 2,12,1760805488678.3188
# 12:39:10> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:10> DLE_Node1 FSM: to send: 2,12,1760805488678.3188
# 12:39:10> PLE_Node1 Tx: message: 022,12,1760805488678.3188
# 12:39:12> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,12,1760805488678.3188 (rx_delay=2.06s)
# 12:39:12> DLE_Node2 Rx: message 19: 022,12,1760805488678.3188
# 12:39:12> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:12> DLE_Node2 FSM: received: 2,12,1760805488678.3188
# 12:39:12> MLE_Node2 MLE Rx: message 13: 2,12,1760805488678.3188
# 12:39:12> PLE_Node2 Tx: message: 12
# 12:39:14> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=2.39s)
# 12:39:14> DLE_Node1 Rx: message 14: 12
# 12:39:14> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:14> DLE_Node1 Tx: message 14: 2,13,1760805488678.3196
# 12:39:14> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:14> DLE_Node1 FSM: to send: 2,13,1760805488678.3196
# 12:39:14> PLE_Node1 Tx: message: 032,13,1760805488678.3196
# 12:39:16> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,13,1760805488678.3196 (rx_delay=1.99s)
# 12:39:16> DLE_Node2 Rx: message 20: 032,13,1760805488678.3196
# 12:39:16> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:16> DLE_Node2 FSM: received: 2,13,1760805488678.3196
# 12:39:16> MLE_Node2 MLE Rx: message 14: 2,13,1760805488678.3196
# 12:39:16> PLE_Node2 Tx: message: 13
# 12:39:16> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.34s)
# 12:39:16> DLE_Node1 Rx: message 15: 13
# 12:39:16> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:16> DLE_Node1 Tx: message 15: 2,14,1760805488678.3206
# 12:39:16> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:16> DLE_Node1 FSM: to send: 2,14,1760805488678.3206
# 12:39:16> PLE_Node1 Tx: message: 042,14,1760805488678.3206
# 12:39:16> PLE_Node1 PLE: duplicate transmission (5%)
# 12:39:18> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,14,1760805488678.3206 (rx_delay=1.79s)
# 12:39:18> DLE_Node2 Rx: message 21: 042,14,1760805488678.3206
# 12:39:18> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:18> DLE_Node2 FSM: received: 2,14,1760805488678.3206
# 12:39:18> PLE_Node2 Tx: message: 14
# 12:39:18> MLE_Node2 MLE Rx: message 15: 2,14,1760805488678.3206
# 12:39:19> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.64s)
# 12:39:19> DLE_Node1 Rx: message 16: 14
# 12:39:19> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:19> DLE_Node1 Tx: message 16: 2,15,1760805488678.3218
# 12:39:19> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:19> DLE_Node1 FSM: to send: 2,15,1760805488678.3218
# 12:39:19> PLE_Node1 Tx: message: 052,15,1760805488678.3218
# 12:39:19> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,14,1760805488678.3206 (rx_delay=0.69s)
# 12:39:19> DLE_Node2 Rx: message 22: 042,14,1760805488678.3206
# 12:39:19> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:19> DLE_Node2 FSM: received: 2,14,1760805488678.3206
# 12:39:19> DLE_Node2 FSM: received received frame 4 but expected 5
# 12:39:19> PLE_Node2 Tx: message: 14
# 12:39:21> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,15,1760805488678.3218 (rx_delay=2.03s)
# 12:39:21> DLE_Node2 Rx: message 23: 052,15,1760805488678.3218
# 12:39:21> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:21> DLE_Node2 FSM: received: 2,15,1760805488678.3218
# 12:39:21> MLE_Node2 MLE Rx: message 16: 2,15,1760805488678.3218
# 12:39:21> PLE_Node2 Tx: message: 15
# 12:39:21> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.05s)
# 12:39:21> DLE_Node1 Rx: message 17: 14
# 12:39:21> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:21> ACK # 4 does not match local seq # 5
# 12:39:22> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.02s)
# 12:39:22> DLE_Node1 Rx: message 18: 15
# 12:39:22> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:22> DLE_Node1 Tx: message 17: 2,16,1760805488678.3228
# 12:39:22> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:22> DLE_Node1 FSM: to send: 2,16,1760805488678.3228
# 12:39:22> PLE_Node1 Tx: message: 062,16,1760805488678.3228
# 12:39:22> PLE_Node1 PLE: packet loss (15%)
# 12:39:28> DLE_Node1 FSM: state: 1 event type: 3
# 12:39:28> DLE_Node1 FSM: to resend frame 6 2,16,1760805488678.3228
# 12:39:28> PLE_Node1 Tx: message: 062,16,1760805488678.3228
# 12:39:29> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,16,1760805488678.3228 (rx_delay=1.57s)
# 12:39:29> DLE_Node2 Rx: message 24: 062,16,1760805488678.3228
# 12:39:29> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:29> DLE_Node2 FSM: received: 2,16,1760805488678.3228
# 12:39:29> MLE_Node2 MLE Rx: message 17: 2,16,1760805488678.3228
# 12:39:29> PLE_Node2 Tx: message: 16
# 12:39:29> PLE_Node2 PLE: duplicate transmission (5%)
# 12:39:29> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=0.19s)
# 12:39:29> DLE_Node1 Rx: message 19: 16
# 12:39:29> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:29> DLE_Node1 Tx: message 18: 2,17,1760805488678.3237
# 12:39:29> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:29> DLE_Node1 FSM: to send: 2,17,1760805488678.3237
# 12:39:29> PLE_Node1 Tx: message: 072,17,1760805488678.3237
# 12:39:29> PLE_Node1 PLE: duplicate transmission (5%)
# 12:39:32> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,17,1760805488678.3237 (rx_delay=2.36s)
# 12:39:32> DLE_Node2 Rx: message 25: 072,17,1760805488678.3237
# 12:39:32> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:32> DLE_Node2 FSM: received: 2,17,1760805488678.3237
# 12:39:32> MLE_Node2 MLE Rx: message 18: 2,17,1760805488678.3237
# 12:39:32> PLE_Node2 Tx: message: 17
# 12:39:32> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=2.62s)
# 12:39:32> DLE_Node1 Rx: message 20: 16
# 12:39:32> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:32> ACK # 6 does not match local seq # 7
# 12:39:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,17,1760805488678.3237 (rx_delay=1.32s)
# 12:39:33> DLE_Node2 Rx: message 26: 072,17,1760805488678.3237
# 12:39:33> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:33> DLE_Node2 FSM: received: 2,17,1760805488678.3237
# 12:39:33> DLE_Node2 FSM: received received frame 7 but expected 8
# 12:39:33> PLE_Node2 Tx: message: 17
# 12:39:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=1.10s)
# 12:39:33> DLE_Node1 Rx: message 21: 17
# 12:39:33> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:33> DLE_Node1 Tx: message 19: 2,18,1760805488678.3245
# 12:39:33> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:33> DLE_Node1 FSM: to send: 2,18,1760805488678.3245
# 12:39:33> PLE_Node1 Tx: message: 082,18,1760805488678.3245
# 12:39:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,18,1760805488678.3245 (rx_delay=0.02s)
# 12:39:33> DLE_Node2 Rx: message 27: 082,18,1760805488678.3245
# 12:39:33> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:33> DLE_Node2 FSM: received: 2,18,1760805488678.3245
# 12:39:33> PLE_Node2 Tx: message: 18
# 12:39:33> MLE_Node2 MLE Rx: message 19: 2,18,1760805488678.3245
# 12:39:35> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.11s)
# 12:39:35> DLE_Node1 Rx: message 22: 17
# 12:39:35> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:35> ACK # 7 does not match local seq # 8
# 12:39:38> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=2.58s)
# 12:39:38> DLE_Node1 Rx: message 23: 18
# 12:39:38> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:38> DLE_Node1 Tx: message 20: 2,19,1760805488678.3254
# 12:39:38> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:38> DLE_Node1 FSM: to send: 2,19,1760805488678.3254
# 12:39:38> PLE_Node1 Tx: message: 092,19,1760805488678.3254
# 12:39:39> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,19,1760805488678.3254 (rx_delay=0.81s)
# 12:39:39> DLE_Node2 Rx: message 28: 092,19,1760805488678.3254
# 12:39:39> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:39> DLE_Node2 FSM: received: 2,19,1760805488678.3254
# 12:39:39> PLE_Node2 Tx: message: 19
# 12:39:39> MLE_Node2 MLE Rx: message 20: 2,19,1760805488678.3254
# 12:39:40> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=1.57s)
# 12:39:40> DLE_Node1 Rx: message 24: 19
# 12:39:40> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:40> DLE_Node1 Tx: message 21: 2,20,1760805488678.3264
# 12:39:40> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:40> DLE_Node1 FSM: to send: 2,20,1760805488678.3264
# 12:39:40> PLE_Node1 Tx: message: 002,20,1760805488678.3264
# 12:39:41> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,20,1760805488678.3264 (rx_delay=0.45s)
# 12:39:41> DLE_Node2 Rx: message 29: 002,20,1760805488678.3264
# 12:39:41> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:41> DLE_Node2 FSM: received: 2,20,1760805488678.3264
# 12:39:41> PLE_Node2 Tx: message: 10
# 12:39:41> MLE_Node2 MLE Rx: message 21: 2,20,1760805488678.3264
# 12:39:42> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.29s)
# 12:39:42> DLE_Node1 Rx: message 25: 10
# 12:39:42> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:42> DLE_Node1 Tx: message 22: 2,21,1760805488678.3274
# 12:39:42> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:42> DLE_Node1 FSM: to send: 2,21,1760805488678.3274
# 12:39:42> PLE_Node1 Tx: message: 012,21,1760805488678.3274
# 12:39:43> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,21,1760805488678.3274 (rx_delay=1.15s)
# 12:39:43> DLE_Node2 Rx: message 30: 012,21,1760805488678.3274
# 12:39:43> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:43> DLE_Node2 FSM: received: 2,21,1760805488678.3274
# 12:39:43> MLE_Node2 MLE Rx: message 22: 2,21,1760805488678.3274
# 12:39:43> PLE_Node2 Tx: message: 11
# 12:39:44> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.91s)
# 12:39:44> DLE_Node1 Rx: message 26: 11
# 12:39:44> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:44> DLE_Node1 Tx: message 23: 2,22,1760805488678.3284
# 12:39:44> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:44> DLE_Node1 FSM: to send: 2,22,1760805488678.3284
# 12:39:44> PLE_Node1 Tx: message: 022,22,1760805488678.3284
# 12:39:46> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,22,1760805488678.3284 (rx_delay=2.07s)
# 12:39:46> DLE_Node2 Rx: message 31: 022,22,1760805488678.3284
# 12:39:46> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:46> DLE_Node2 FSM: received: 2,22,1760805488678.3284
# 12:39:46> MLE_Node2 MLE Rx: message 23: 2,22,1760805488678.3284
# 12:39:46> PLE_Node2 Tx: message: 12
# 12:39:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=2.95s)
# 12:39:49> DLE_Node1 Rx: message 27: 12
# 12:39:49> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:49> DLE_Node1 Tx: message 24: 2,23,1760805488678.329
# 12:39:49> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:49> DLE_Node1 FSM: to send: 2,23,1760805488678.329
# 12:39:49> PLE_Node1 Tx: message: 032,23,1760805488678.329
# 12:39:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,23,1760805488678.329 (rx_delay=2.80s)
# 12:39:52> DLE_Node2 Rx: message 32: 032,23,1760805488678.329
# 12:39:52> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:52> DLE_Node2 FSM: received: 2,23,1760805488678.329
# 12:39:52> MLE_Node2 MLE Rx: message 24: 2,23,1760805488678.329
# 12:39:52> PLE_Node2 Tx: message: 13
# 12:39:52> PLE_Node2 PLE: duplicate transmission (5%)
# 12:39:53> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.26s)
# 12:39:53> DLE_Node1 Rx: message 28: 13
# 12:39:53> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:53> DLE_Node1 Tx: message 25: 2,24,1760805488678.33
# 12:39:53> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:53> DLE_Node1 FSM: to send: 2,24,1760805488678.33
# 12:39:53> PLE_Node1 Tx: message: 042,24,1760805488678.33
# 12:39:55> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,24,1760805488678.33 (rx_delay=1.42s)
# 12:39:55> DLE_Node2 Rx: message 33: 042,24,1760805488678.33
# 12:39:55> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:55> DLE_Node2 FSM: received: 2,24,1760805488678.33
# 12:39:55> MLE_Node2 MLE Rx: message 25: 2,24,1760805488678.33
# 12:39:55> PLE_Node2 Tx: message: 14
# 12:39:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.83s)
# 12:39:55> DLE_Node1 Rx: message 29: 13
# 12:39:55> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:55> ACK # 3 does not match local seq # 4
# 12:39:56> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=1.46s)
# 12:39:56> DLE_Node1 Rx: message 30: 14
# 12:39:56> DLE_Node1 FSM: state: 1 event type: 2
# 12:39:56> DLE_Node1 Tx: message 26: 2,25,1760805488678.3308
# 12:39:56> DLE_Node1 FSM: state: 0 event type: 0
# 12:39:56> DLE_Node1 FSM: to send: 2,25,1760805488678.3308
# 12:39:56> PLE_Node1 Tx: message: 052,25,1760805488678.3308
# 12:39:59> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,25,1760805488678.3308 (rx_delay=2.56s)
# 12:39:59> DLE_Node2 Rx: message 34: 052,25,1760805488678.3308
# 12:39:59> DLE_Node2 FSM: state: 0 event type: 1
# 12:39:59> DLE_Node2 FSM: received: 2,25,1760805488678.3308
# 12:39:59> MLE_Node2 MLE Rx: message 26: 2,25,1760805488678.3308
# 12:39:59> PLE_Node2 Tx: message: 15
# 12:40:01> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=2.22s)
# 12:40:01> DLE_Node1 Rx: message 31: 15
# 12:40:01> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:01> DLE_Node1 Tx: message 27: 2,26,1760805488678.3318
# 12:40:01> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:01> DLE_Node1 FSM: to send: 2,26,1760805488678.3318
# 12:40:01> PLE_Node1 Tx: message: 062,26,1760805488678.3318
# 12:40:02> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,26,1760805488678.3318 (rx_delay=0.60s)
# 12:40:02> DLE_Node2 Rx: message 35: 062,26,1760805488678.3318
# 12:40:02> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:02> DLE_Node2 FSM: received: 2,26,1760805488678.3318
# 12:40:02> MLE_Node2 MLE Rx: message 27: 2,26,1760805488678.3318
# 12:40:02> PLE_Node2 Tx: message: 16
# 12:40:02> PLE_Node2 PLE: duplicate transmission (5%)
# 12:40:03> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.29s)
# 12:40:03> DLE_Node1 Rx: message 32: 16
# 12:40:03> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:03> DLE_Node1 Tx: message 28: 2,27,1760805488678.333
# 12:40:03> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:03> DLE_Node1 FSM: to send: 2,27,1760805488678.333
# 12:40:03> PLE_Node1 Tx: message: 072,27,1760805488678.333
# 12:40:06> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,27,1760805488678.333 (rx_delay=2.77s)
# 12:40:06> DLE_Node2 Rx: message 36: 072,27,1760805488678.333
# 12:40:06> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:06> DLE_Node2 FSM: received: 2,27,1760805488678.333
# 12:40:06> MLE_Node2 MLE Rx: message 28: 2,27,1760805488678.333
# 12:40:06> PLE_Node2 Tx: message: 17
# 12:40:06> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=2.80s)
# 12:40:06> DLE_Node1 Rx: message 33: 16
# 12:40:06> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:06> ACK # 6 does not match local seq # 7
# 12:40:08> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=1.81s)
# 12:40:08> DLE_Node1 Rx: message 34: 17
# 12:40:08> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:08> DLE_Node1 Tx: message 29: 2,28,1760805488678.3337
# 12:40:08> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:08> DLE_Node1 FSM: to send: 2,28,1760805488678.3337
# 12:40:08> PLE_Node1 Tx: message: 082,28,1760805488678.3337
# 12:40:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,28,1760805488678.3337 (rx_delay=1.19s)
# 12:40:09> DLE_Node2 Rx: message 37: 082,28,1760805488678.3337
# 12:40:09> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:09> DLE_Node2 FSM: received: 2,28,1760805488678.3337
# 12:40:09> MLE_Node2 MLE Rx: message 29: 2,28,1760805488678.3337
# 12:40:09> PLE_Node2 Tx: message: 18
# 12:40:09> PLE_Node2 PLE: packet loss (15%)
# 12:40:14> DLE_Node1 FSM: state: 1 event type: 3
# 12:40:14> DLE_Node1 FSM: to resend frame 8 2,28,1760805488678.3337
# 12:40:14> PLE_Node1 Tx: message: 082,28,1760805488678.3337
# 12:40:16> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,28,1760805488678.3337 (rx_delay=1.80s)
# 12:40:16> DLE_Node2 Rx: message 38: 082,28,1760805488678.3337
# 12:40:16> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:16> DLE_Node2 FSM: received: 2,28,1760805488678.3337
# 12:40:16> DLE_Node2 FSM: received received frame 8 but expected 9
# 12:40:16> PLE_Node2 Tx: message: 18
# 12:40:17> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.29s)
# 12:40:17> DLE_Node1 Rx: message 35: 18
# 12:40:17> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:17> DLE_Node1 Tx: message 30: 2,29,1760805488678.3347
# 12:40:17> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:17> DLE_Node1 FSM: to send: 2,29,1760805488678.3347
# 12:40:17> PLE_Node1 Tx: message: 092,29,1760805488678.3347
# 12:40:19> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,29,1760805488678.3347 (rx_delay=1.89s)
# 12:40:19> DLE_Node2 Rx: message 39: 092,29,1760805488678.3347
# 12:40:19> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:19> DLE_Node2 FSM: received: 2,29,1760805488678.3347
# 12:40:19> MLE_Node2 MLE Rx: message 30: 2,29,1760805488678.3347
# 12:40:19> PLE_Node2 Tx: message: 19
# 12:40:19> PLE_Node2 PLE: packet loss (15%)
# 12:40:23> DLE_Node1 FSM: state: 1 event type: 3
# 12:40:23> DLE_Node1 FSM: to resend frame 9 2,29,1760805488678.3347
# 12:40:23> PLE_Node1 Tx: message: 092,29,1760805488678.3347
# 12:40:25> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,29,1760805488678.3347 (rx_delay=1.79s)
# 12:40:25> DLE_Node2 Rx: message 40: 092,29,1760805488678.3347
# 12:40:25> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:25> DLE_Node2 FSM: received: 2,29,1760805488678.3347
# 12:40:25> DLE_Node2 FSM: received received frame 9 but expected 0
# 12:40:25> PLE_Node2 Tx: message: 19
# 12:40:26> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=1.91s)
# 12:40:26> DLE_Node1 Rx: message 36: 19
# 12:40:26> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:26> DLE_Node1 Tx: message 31: 2,30,1760805488678.3357
# 12:40:26> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:26> DLE_Node1 FSM: to send: 2,30,1760805488678.3357
# 12:40:26> PLE_Node1 Tx: message: 002,30,1760805488678.3357
# 12:40:29> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,30,1760805488678.3357 (rx_delay=2.09s)
# 12:40:29> DLE_Node2 Rx: message 41: 002,30,1760805488678.3357
# 12:40:29> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:29> DLE_Node2 FSM: received: 2,30,1760805488678.3357
# 12:40:29> MLE_Node2 MLE Rx: message 31: 2,30,1760805488678.3357
# 12:40:29> PLE_Node2 Tx: message: 10
# 12:40:30> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=1.80s)
# 12:40:30> DLE_Node1 Rx: message 37: 10
# 12:40:30> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:30> DLE_Node1 Tx: message 32: 2,31,1760805488678.3364
# 12:40:30> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:30> DLE_Node1 FSM: to send: 2,31,1760805488678.3364
# 12:40:30> PLE_Node1 Tx: message: 012,31,1760805488678.3364
# 12:40:30> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,31,1760805488678.3364 (rx_delay=0.13s)
# 12:40:30> DLE_Node2 Rx: message 42: 012,31,1760805488678.3364
# 12:40:30> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:30> DLE_Node2 FSM: received: 2,31,1760805488678.3364
# 12:40:30> PLE_Node2 Tx: message: 11
# 12:40:30> MLE_Node2 MLE Rx: message 32: 2,31,1760805488678.3364
# 12:40:33> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=2.28s)
# 12:40:33> DLE_Node1 Rx: message 38: 11
# 12:40:33> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:33> DLE_Node1 Tx: message 33: 2,32,1760805488678.5022
# 12:40:33> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:33> DLE_Node1 FSM: to send: 2,32,1760805488678.5022
# 12:40:33> PLE_Node1 Tx: message: 022,32,1760805488678.5022
# 12:40:33> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,32,1760805488678.5022 (rx_delay=0.05s)
# 12:40:33> DLE_Node2 Rx: message 43: 022,32,1760805488678.5022
# 12:40:33> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:33> DLE_Node2 FSM: received: 2,32,1760805488678.5022
# 12:40:33> PLE_Node2 Tx: message: 12
# 12:40:33> MLE_Node2 MLE Rx: message 33: 2,32,1760805488678.5022
# 12:40:34> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=1.67s)
# 12:40:34> DLE_Node1 Rx: message 39: 12
# 12:40:34> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:34> DLE_Node1 Tx: message 34: 2,33,1760805488678.5042
# 12:40:34> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:34> DLE_Node1 FSM: to send: 2,33,1760805488678.5042
# 12:40:34> PLE_Node1 Tx: message: 032,33,1760805488678.5042
# 12:40:35> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,33,1760805488678.5042 (rx_delay=0.34s)
# 12:40:35> DLE_Node2 Rx: message 44: 032,33,1760805488678.5042
# 12:40:35> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:35> DLE_Node2 FSM: received: 2,33,1760805488678.5042
# 12:40:35> MLE_Node2 MLE Rx: message 34: 2,33,1760805488678.5042
# 12:40:35> PLE_Node2 Tx: message: 13
# 12:40:37> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=2.63s)
# 12:40:37> DLE_Node1 Rx: message 40: 13
# 12:40:37> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:37> DLE_Node1 Tx: message 35: 2,34,1760805488678.5051
# 12:40:37> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:37> DLE_Node1 FSM: to send: 2,34,1760805488678.5051
# 12:40:37> PLE_Node1 Tx: message: 042,34,1760805488678.5051
# 12:40:38> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,34,1760805488678.5051 (rx_delay=0.90s)
# 12:40:38> DLE_Node2 Rx: message 45: 042,34,1760805488678.5051
# 12:40:38> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:38> DLE_Node2 FSM: received: 2,34,1760805488678.5051
# 12:40:38> PLE_Node2 Tx: message: 14
# 12:40:38> MLE_Node2 MLE Rx: message 35: 2,34,1760805488678.5051
# 12:40:41> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.66s)
# 12:40:41> DLE_Node1 Rx: message 41: 14
# 12:40:41> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:41> DLE_Node1 Tx: message 36: 2,35,1760805488678.5066
# 12:40:41> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:41> DLE_Node1 FSM: to send: 2,35,1760805488678.5066
# 12:40:41> PLE_Node1 Tx: message: 052,35,1760805488678.5066
# 12:40:42> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,35,1760805488678.5066 (rx_delay=0.57s)
# 12:40:42> DLE_Node2 Rx: message 46: 052,35,1760805488678.5066
# 12:40:42> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:42> DLE_Node2 FSM: received: 2,35,1760805488678.5066
# 12:40:42> PLE_Node2 Tx: message: 15
# 12:40:42> MLE_Node2 MLE Rx: message 36: 2,35,1760805488678.5066
# 12:40:44> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=2.24s)
# 12:40:44> DLE_Node1 Rx: message 42: 15
# 12:40:44> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:44> DLE_Node1 Tx: message 37: 2,36,1760805488678.5076
# 12:40:44> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:44> DLE_Node1 FSM: to send: 2,36,1760805488678.5076
# 12:40:44> PLE_Node1 Tx: message: 062,36,1760805488678.5076
# 12:40:44> PLE_Node1 PLE: packet loss (15%)
# 12:40:50> DLE_Node1 FSM: state: 1 event type: 3
# 12:40:50> DLE_Node1 FSM: to resend frame 6 2,36,1760805488678.5076
# 12:40:50> PLE_Node1 Tx: message: 062,36,1760805488678.5076
# 12:40:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,36,1760805488678.5076 (rx_delay=2.22s)
# 12:40:52> DLE_Node2 Rx: message 47: 062,36,1760805488678.5076
# 12:40:52> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:52> DLE_Node2 FSM: received: 2,36,1760805488678.5076
# 12:40:52> PLE_Node2 Tx: message: 16
# 12:40:52> MLE_Node2 MLE Rx: message 37: 2,36,1760805488678.5076
# 12:40:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=0.30s)
# 12:40:52> DLE_Node1 Rx: message 43: 16
# 12:40:52> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:52> DLE_Node1 Tx: message 38: 2,37,1760805488678.5083
# 12:40:52> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:52> DLE_Node1 FSM: to send: 2,37,1760805488678.5083
# 12:40:52> PLE_Node1 Tx: message: 072,37,1760805488678.5083
# 12:40:53> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,37,1760805488678.5083 (rx_delay=0.33s)
# 12:40:53> DLE_Node2 Rx: message 48: 072,37,1760805488678.5083
# 12:40:53> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:53> DLE_Node2 FSM: received: 2,37,1760805488678.5083
# 12:40:53> MLE_Node2 MLE Rx: message 38: 2,37,1760805488678.5083
# 12:40:53> PLE_Node2 Tx: message: 17
# 12:40:54> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.87s)
# 12:40:54> DLE_Node1 Rx: message 44: 17
# 12:40:54> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:54> DLE_Node1 Tx: message 39: 2,38,1760805488678.5095
# 12:40:54> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:54> DLE_Node1 FSM: to send: 2,38,1760805488678.5095
# 12:40:54> PLE_Node1 Tx: message: 082,38,1760805488678.5095
# 12:40:54> PLE_Node1 PLE: duplicate transmission (5%)
# 12:40:54> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,38,1760805488678.5095 (rx_delay=0.46s)
# 12:40:54> DLE_Node2 Rx: message 49: 082,38,1760805488678.5095
# 12:40:54> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:54> DLE_Node2 FSM: received: 2,38,1760805488678.5095
# 12:40:54> PLE_Node2 Tx: message: 18
# 12:40:54> MLE_Node2 MLE Rx: message 39: 2,38,1760805488678.5095
# 12:40:54> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,38,1760805488678.5095 (rx_delay=0.26s)
# 12:40:54> DLE_Node2 Rx: message 50: 082,38,1760805488678.5095
# 12:40:54> DLE_Node2 FSM: state: 0 event type: 1
# 12:40:54> DLE_Node2 FSM: received: 2,38,1760805488678.5095
# 12:40:54> DLE_Node2 FSM: received received frame 8 but expected 9
# 12:40:54> PLE_Node2 Tx: message: 18
# 12:40:54> PLE_Node2 PLE: packet loss (15%)
# 12:40:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=1.24s)
# 12:40:55> DLE_Node1 Rx: message 45: 18
# 12:40:55> DLE_Node1 FSM: state: 1 event type: 2
# 12:40:55> DLE_Node1 Tx: message 40: 2,39,1760805488678.5105
# 12:40:55> DLE_Node1 FSM: state: 0 event type: 0
# 12:40:55> DLE_Node1 FSM: to send: 2,39,1760805488678.5105
# 12:40:55> PLE_Node1 Tx: message: 092,39,1760805488678.5105
# 12:40:55> PLE_Node1 PLE: packet loss (15%)
# 12:41:01> DLE_Node1 FSM: state: 1 event type: 3
# 12:41:01> DLE_Node1 FSM: to resend frame 9 2,39,1760805488678.5105
# 12:41:01> PLE_Node1 Tx: message: 092,39,1760805488678.5105
# 12:41:03> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,39,1760805488678.5105 (rx_delay=1.86s)
# 12:41:03> DLE_Node2 Rx: message 51: 092,39,1760805488678.5105
# 12:41:03> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:03> DLE_Node2 FSM: received: 2,39,1760805488678.5105
# 12:41:03> MLE_Node2 MLE Rx: message 40: 2,39,1760805488678.5105
# 12:41:03> PLE_Node2 Tx: message: 19
# 12:41:04> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=1.56s)
# 12:41:04> DLE_Node1 Rx: message 46: 19
# 12:41:04> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:04> DLE_Node1 Tx: message 41: 2,40,1760805488678.5117
# 12:41:04> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:04> DLE_Node1 FSM: to send: 2,40,1760805488678.5117
# 12:41:04> PLE_Node1 Tx: message: 002,40,1760805488678.5117
# 12:41:04> PLE_Node1 PLE: packet loss (15%)
# 12:41:10> DLE_Node1 FSM: state: 1 event type: 3
# 12:41:10> DLE_Node1 FSM: to resend frame 0 2,40,1760805488678.5117
# 12:41:10> PLE_Node1 Tx: message: 002,40,1760805488678.5117
# 12:41:10> PLE_Node1 PLE: packet loss (15%)
# 12:41:15> DLE_Node1 FSM: state: 1 event type: 3
# 12:41:15> DLE_Node1 FSM: to resend frame 0 2,40,1760805488678.5117
# 12:41:15> PLE_Node1 Tx: message: 002,40,1760805488678.5117
# 12:41:18> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,40,1760805488678.5117 (rx_delay=2.44s)
# 12:41:18> DLE_Node2 Rx: message 52: 002,40,1760805488678.5117
# 12:41:18> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:18> DLE_Node2 FSM: received: 2,40,1760805488678.5117
# 12:41:18> MLE_Node2 MLE Rx: message 41: 2,40,1760805488678.5117
# 12:41:18> PLE_Node2 Tx: message: 10
# 12:41:18> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=0.52s)
# 12:41:18> DLE_Node1 Rx: message 47: 10
# 12:41:18> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:18> DLE_Node1 Tx: message 42: 2,41,1760805488678.5127
# 12:41:18> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:18> DLE_Node1 FSM: to send: 2,41,1760805488678.5127
# 12:41:18> PLE_Node1 Tx: message: 012,41,1760805488678.5127
# 12:41:18> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,41,1760805488678.5127 (rx_delay=0.09s)
# 12:41:18> DLE_Node2 Rx: message 53: 012,41,1760805488678.5127
# 12:41:18> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:18> DLE_Node2 FSM: received: 2,41,1760805488678.5127
# 12:41:18> PLE_Node2 Tx: message: 11
# 12:41:18> PLE_Node2 PLE: packet loss (15%)
# 12:41:18> MLE_Node2 MLE Rx: message 42: 2,41,1760805488678.5127
# 12:41:24> DLE_Node1 FSM: state: 1 event type: 3
# 12:41:24> DLE_Node1 FSM: to resend frame 1 2,41,1760805488678.5127
# 12:41:24> PLE_Node1 Tx: message: 012,41,1760805488678.5127
# 12:41:25> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,41,1760805488678.5127 (rx_delay=0.93s)
# 12:41:25> DLE_Node2 Rx: message 54: 012,41,1760805488678.5127
# 12:41:25> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:25> DLE_Node2 FSM: received: 2,41,1760805488678.5127
# 12:41:25> DLE_Node2 FSM: received received frame 1 but expected 2
# 12:41:25> PLE_Node2 Tx: message: 11
# 12:41:25> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.73s)
# 12:41:25> DLE_Node1 Rx: message 48: 11
# 12:41:25> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:25> DLE_Node1 Tx: message 43: 2,42,1760805488678.514
# 12:41:25> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:25> DLE_Node1 FSM: to send: 2,42,1760805488678.514
# 12:41:25> PLE_Node1 Tx: message: 022,42,1760805488678.514
# 12:41:26> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,42,1760805488678.514 (rx_delay=0.45s)
# 12:41:26> DLE_Node2 Rx: message 55: 022,42,1760805488678.514
# 12:41:26> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:26> DLE_Node2 FSM: received: 2,42,1760805488678.514
# 12:41:26> MLE_Node2 MLE Rx: message 43: 2,42,1760805488678.514
# 12:41:26> PLE_Node2 Tx: message: 12
# 12:41:26> PLE_Node2 PLE: packet loss (15%)
# 12:41:31> DLE_Node1 FSM: state: 1 event type: 3
# 12:41:31> DLE_Node1 FSM: to resend frame 2 2,42,1760805488678.514
# 12:41:31> PLE_Node1 Tx: message: 022,42,1760805488678.514
# 12:41:32> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,42,1760805488678.514 (rx_delay=0.50s)
# 12:41:32> DLE_Node2 Rx: message 56: 022,42,1760805488678.514
# 12:41:32> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:32> DLE_Node2 FSM: received: 2,42,1760805488678.514
# 12:41:32> DLE_Node2 FSM: received received frame 2 but expected 3
# 12:41:32> PLE_Node2 Tx: message: 12
# 12:41:34> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=2.09s)
# 12:41:34> DLE_Node1 Rx: message 49: 12
# 12:41:34> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:34> DLE_Node1 Tx: message 44: 2,43,1760805488678.515
# 12:41:34> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:34> DLE_Node1 FSM: to send: 2,43,1760805488678.515
# 12:41:34> PLE_Node1 Tx: message: 032,43,1760805488678.515
# 12:41:37> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,43,1760805488678.515 (rx_delay=2.75s)
# 12:41:37> DLE_Node2 Rx: message 57: 032,43,1760805488678.515
# 12:41:37> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:37> DLE_Node2 FSM: received: 2,43,1760805488678.515
# 12:41:37> MLE_Node2 MLE Rx: message 44: 2,43,1760805488678.515
# 12:41:37> PLE_Node2 Tx: message: 13
# 12:41:38> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.53s)
# 12:41:38> DLE_Node1 Rx: message 50: 13
# 12:41:38> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:38> DLE_Node1 Tx: message 45: 2,44,1760805488678.5159
# 12:41:38> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:38> DLE_Node1 FSM: to send: 2,44,1760805488678.5159
# 12:41:38> PLE_Node1 Tx: message: 042,44,1760805488678.5159
# 12:41:40> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,44,1760805488678.5159 (rx_delay=1.72s)
# 12:41:40> DLE_Node2 Rx: message 58: 042,44,1760805488678.5159
# 12:41:40> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:40> DLE_Node2 FSM: received: 2,44,1760805488678.5159
# 12:41:40> MLE_Node2 MLE Rx: message 45: 2,44,1760805488678.5159
# 12:41:40> PLE_Node2 Tx: message: 14
# 12:41:43> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.63s)
# 12:41:43> DLE_Node1 Rx: message 51: 14
# 12:41:43> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:43> DLE_Node1 Tx: message 46: 2,45,1760805488678.517
# 12:41:43> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:43> DLE_Node1 FSM: to send: 2,45,1760805488678.517
# 12:41:43> PLE_Node1 Tx: message: 052,45,1760805488678.517
# 12:41:44> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,45,1760805488678.517 (rx_delay=1.47s)
# 12:41:44> DLE_Node2 Rx: message 59: 052,45,1760805488678.517
# 12:41:44> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:44> DLE_Node2 FSM: received: 2,45,1760805488678.517
# 12:41:44> PLE_Node2 Tx: message: 15
# 12:41:44> MLE_Node2 MLE Rx: message 46: 2,45,1760805488678.517
# 12:41:45> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.01s)
# 12:41:45> DLE_Node1 Rx: message 52: 15
# 12:41:45> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:45> DLE_Node1 Tx: message 47: 2,46,1760805488678.518
# 12:41:45> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:45> DLE_Node1 FSM: to send: 2,46,1760805488678.518
# 12:41:45> PLE_Node1 Tx: message: 062,46,1760805488678.518
# 12:41:47> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,46,1760805488678.518 (rx_delay=2.27s)
# 12:41:47> DLE_Node2 Rx: message 60: 062,46,1760805488678.518
# 12:41:47> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:47> DLE_Node2 FSM: received: 2,46,1760805488678.518
# 12:41:47> MLE_Node2 MLE Rx: message 47: 2,46,1760805488678.518
# 12:41:47> PLE_Node2 Tx: message: 16
# 12:41:48> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.10s)
# 12:41:48> DLE_Node1 Rx: message 53: 16
# 12:41:48> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:48> DLE_Node1 Tx: message 48: 2,47,1760805488678.5188
# 12:41:48> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:48> DLE_Node1 FSM: to send: 2,47,1760805488678.5188
# 12:41:48> PLE_Node1 Tx: message: 072,47,1760805488678.5188
# 12:41:48> PLE_Node1 PLE: duplicate transmission (5%)
# 12:41:49> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,47,1760805488678.5188 (rx_delay=1.11s)
# 12:41:49> DLE_Node2 Rx: message 61: 072,47,1760805488678.5188
# 12:41:49> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:49> DLE_Node2 FSM: received: 2,47,1760805488678.5188
# 12:41:49> PLE_Node2 Tx: message: 17
# 12:41:49> MLE_Node2 MLE Rx: message 48: 2,47,1760805488678.5188
# 12:41:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,47,1760805488678.5188 (rx_delay=0.93s)
# 12:41:50> DLE_Node2 Rx: message 62: 072,47,1760805488678.5188
# 12:41:50> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:50> DLE_Node2 FSM: received: 2,47,1760805488678.5188
# 12:41:50> DLE_Node2 FSM: received received frame 7 but expected 8
# 12:41:50> PLE_Node2 Tx: message: 17
# 12:41:51> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=1.53s)
# 12:41:51> DLE_Node1 Rx: message 54: 17
# 12:41:51> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:51> DLE_Node1 Tx: message 49: 2,48,1760805488678.52
# 12:41:51> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:51> DLE_Node1 FSM: to send: 2,48,1760805488678.52
# 12:41:51> PLE_Node1 Tx: message: 082,48,1760805488678.52
# 12:41:51> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=0.13s)
# 12:41:51> DLE_Node1 Rx: message 55: 17
# 12:41:51> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:51> ACK # 7 does not match local seq # 8
# 12:41:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,48,1760805488678.52 (rx_delay=1.37s)
# 12:41:52> DLE_Node2 Rx: message 63: 082,48,1760805488678.52
# 12:41:52> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:52> DLE_Node2 FSM: received: 2,48,1760805488678.52
# 12:41:52> PLE_Node2 Tx: message: 18
# 12:41:52> MLE_Node2 MLE Rx: message 49: 2,48,1760805488678.52
# 12:41:53> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=0.51s)
# 12:41:53> DLE_Node1 Rx: message 56: 18
# 12:41:53> DLE_Node1 FSM: state: 1 event type: 2
# 12:41:53> DLE_Node1 Tx: message 50: 2,49,1760805488678.521
# 12:41:53> DLE_Node1 FSM: state: 0 event type: 0
# 12:41:53> DLE_Node1 FSM: to send: 2,49,1760805488678.521
# 12:41:53> PLE_Node1 Tx: message: 092,49,1760805488678.521
# 12:41:54> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,49,1760805488678.521 (rx_delay=1.43s)
# 12:41:54> DLE_Node2 Rx: message 64: 092,49,1760805488678.521
# 12:41:54> DLE_Node2 FSM: state: 0 event type: 1
# 12:41:54> DLE_Node2 FSM: received: 2,49,1760805488678.521
# 12:41:54> MLE_Node2 MLE Rx: message 50: 2,49,1760805488678.521
# 12:41:54> PLE_Node2 Tx: message: 19
# 12:41:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.80s)
# ...
# 12:45:48> DLE_Node2 FSM: received: 2,82,1760805488678.5732
# 12:45:48> PLE_Node2 Tx: message: 12
# 12:45:48> MLE_Node2 MLE Rx: message 83: 2,82,1760805488678.5732
# 12:45:48> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=0.65s)
# 12:45:48> DLE_Node1 Rx: message 95: 12
# 12:45:48> DLE_Node1 FSM: state: 1 event type: 2
# 12:45:48> DLE_Node1 Tx: message 84: 2,83,1760805488678.574
# 12:45:48> DLE_Node1 FSM: state: 0 event type: 0
# 12:45:48> DLE_Node1 FSM: to send: 2,83,1760805488678.574
# 12:45:48> PLE_Node1 Tx: message: 032,83,1760805488678.574
# 12:45:50> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,83,1760805488678.574 (rx_delay=1.63s)
# 12:45:50> DLE_Node2 Rx: message 113: 032,83,1760805488678.574
# 12:45:50> DLE_Node2 FSM: state: 0 event type: 1
# 12:45:50> DLE_Node2 FSM: received: 2,83,1760805488678.574
# 12:45:50> MLE_Node2 MLE Rx: message 84: 2,83,1760805488678.574
# 12:45:50> PLE_Node2 Tx: message: 13
# 12:45:50> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=0.34s)
# 12:45:50> DLE_Node1 Rx: message 96: 13
# 12:45:50> DLE_Node1 FSM: state: 1 event type: 2
# 12:45:50> DLE_Node1 Tx: message 85: 2,84,1760805488678.575
# 12:45:50> DLE_Node1 FSM: state: 0 event type: 0
# 12:45:50> DLE_Node1 FSM: to send: 2,84,1760805488678.575
# 12:45:50> PLE_Node1 Tx: message: 042,84,1760805488678.575
# 12:45:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,84,1760805488678.575 (rx_delay=1.34s)
# 12:45:52> DLE_Node2 Rx: message 114: 042,84,1760805488678.575
# 12:45:52> DLE_Node2 FSM: state: 0 event type: 1
# 12:45:52> DLE_Node2 FSM: received: 2,84,1760805488678.575
# 12:45:52> PLE_Node2 Tx: message: 14
# 12:45:52> MLE_Node2 MLE Rx: message 85: 2,84,1760805488678.575
# 12:45:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=0.03s)
# 12:45:52> DLE_Node1 Rx: message 97: 14
# 12:45:52> DLE_Node1 FSM: state: 1 event type: 2
# 12:45:52> DLE_Node1 Tx: message 86: 2,85,1760805488678.576
# 12:45:52> DLE_Node1 FSM: state: 0 event type: 0
# 12:45:52> DLE_Node1 FSM: to send: 2,85,1760805488678.576
# 12:45:52> PLE_Node1 Tx: message: 052,85,1760805488678.576
# 12:45:53> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,85,1760805488678.576 (rx_delay=0.73s)
# 12:45:53> DLE_Node2 Rx: message 115: 052,85,1760805488678.576
# 12:45:53> DLE_Node2 FSM: state: 0 event type: 1
# 12:45:53> DLE_Node2 FSM: received: 2,85,1760805488678.576
# 12:45:53> MLE_Node2 MLE Rx: message 86: 2,85,1760805488678.576
# 12:45:53> PLE_Node2 Tx: message: 15
# 12:45:54> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=1.79s)
# 12:45:54> DLE_Node1 Rx: message 98: 15
# 12:45:54> DLE_Node1 FSM: state: 1 event type: 2
# 12:45:54> DLE_Node1 Tx: message 87: 2,86,1760805488678.5767
# 12:45:54> DLE_Node1 FSM: state: 0 event type: 0
# 12:45:54> DLE_Node1 FSM: to send: 2,86,1760805488678.5767
# 12:45:54> PLE_Node1 Tx: message: 062,86,1760805488678.5767
# 12:45:57> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,86,1760805488678.5767 (rx_delay=2.43s)
# 12:45:57> DLE_Node2 Rx: message 116: 062,86,1760805488678.5767
# 12:45:57> DLE_Node2 FSM: state: 0 event type: 1
# 12:45:57> DLE_Node2 FSM: received: 2,86,1760805488678.5767
# 12:45:57> PLE_Node2 Tx: message: 16
# 12:45:57> MLE_Node2 MLE Rx: message 87: 2,86,1760805488678.5767
# 12:45:58> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.21s)
# 12:45:58> DLE_Node1 Rx: message 99: 16
# 12:45:58> DLE_Node1 FSM: state: 1 event type: 2
# 12:45:58> DLE_Node1 Tx: message 88: 2,87,1760805488678.5774
# 12:45:58> DLE_Node1 FSM: state: 0 event type: 0
# 12:45:58> DLE_Node1 FSM: to send: 2,87,1760805488678.5774
# 12:45:58> PLE_Node1 Tx: message: 072,87,1760805488678.5774
# 12:46:00> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,87,1760805488678.5774 (rx_delay=2.42s)
# 12:46:00> DLE_Node2 Rx: message 117: 072,87,1760805488678.5774
# 12:46:00> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:00> DLE_Node2 FSM: received: 2,87,1760805488678.5774
# 12:46:00> MLE_Node2 MLE Rx: message 88: 2,87,1760805488678.5774
# 12:46:00> PLE_Node2 Tx: message: 17
# 12:46:00> PLE_Node2 PLE: packet loss (15%)
# 12:46:03> DLE_Node1 FSM: state: 1 event type: 3
# 12:46:03> DLE_Node1 FSM: to resend frame 7 2,87,1760805488678.5774
# 12:46:03> PLE_Node1 Tx: message: 072,87,1760805488678.5774
# 12:46:04> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,87,1760805488678.5774 (rx_delay=0.69s)
# 12:46:04> DLE_Node2 Rx: message 118: 072,87,1760805488678.5774
# 12:46:04> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:04> DLE_Node2 FSM: received: 2,87,1760805488678.5774
# 12:46:04> DLE_Node2 FSM: received received frame 7 but expected 8
# 12:46:04> PLE_Node2 Tx: message: 17
# 12:46:07> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.79s)
# 12:46:07> DLE_Node1 Rx: message 100: 17
# 12:46:07> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:07> DLE_Node1 Tx: message 89: 2,88,1760805488678.5781
# 12:46:07> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:07> DLE_Node1 FSM: to send: 2,88,1760805488678.5781
# 12:46:07> PLE_Node1 Tx: message: 082,88,1760805488678.5781
# 12:46:09> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,88,1760805488678.5781 (rx_delay=2.38s)
# 12:46:09> DLE_Node2 Rx: message 119: 082,88,1760805488678.5781
# 12:46:09> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:09> DLE_Node2 FSM: received: 2,88,1760805488678.5781
# 12:46:09> MLE_Node2 MLE Rx: message 89: 2,88,1760805488678.5781
# 12:46:09> PLE_Node2 Tx: message: 18
# 12:46:10> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=0.99s)
# 12:46:10> DLE_Node1 Rx: message 101: 18
# 12:46:10> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:10> DLE_Node1 Tx: message 90: 2,89,1760805488678.579
# 12:46:10> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:10> DLE_Node1 FSM: to send: 2,89,1760805488678.579
# 12:46:10> PLE_Node1 Tx: message: 092,89,1760805488678.579
# 12:46:11> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,89,1760805488678.579 (rx_delay=0.52s)
# 12:46:11> DLE_Node2 Rx: message 120: 092,89,1760805488678.579
# 12:46:11> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:11> DLE_Node2 FSM: received: 2,89,1760805488678.579
# 12:46:11> MLE_Node2 MLE Rx: message 90: 2,89,1760805488678.579
# 12:46:11> PLE_Node2 Tx: message: 19
# 12:46:11> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=0.64s)
# 12:46:11> DLE_Node1 Rx: message 102: 19
# 12:46:11> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:11> DLE_Node1 Tx: message 91: 2,90,1760805488678.5803
# 12:46:11> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:11> DLE_Node1 FSM: to send: 2,90,1760805488678.5803
# 12:46:11> PLE_Node1 Tx: message: 002,90,1760805488678.5803
# 12:46:13> PLE_Node2 Rx: from ('127.0.0.1', 33333): 002,90,1760805488678.5803 (rx_delay=1.36s)
# 12:46:13> DLE_Node2 Rx: message 121: 002,90,1760805488678.5803
# 12:46:13> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:13> DLE_Node2 FSM: received: 2,90,1760805488678.5803
# 12:46:13> MLE_Node2 MLE Rx: message 91: 2,90,1760805488678.5803
# 12:46:13> PLE_Node2 Tx: message: 10
# 12:46:15> PLE_Node1 Rx: from ('127.0.0.1', 34000): 10 (rx_delay=2.54s)
# 12:46:15> DLE_Node1 Rx: message 103: 10
# 12:46:15> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:15> DLE_Node1 Tx: message 92: 2,91,1760805488678.581
# 12:46:15> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:15> DLE_Node1 FSM: to send: 2,91,1760805488678.581
# 12:46:15> PLE_Node1 Tx: message: 012,91,1760805488678.581
# 12:46:17> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,91,1760805488678.581 (rx_delay=1.93s)
# 12:46:17> DLE_Node2 Rx: message 122: 012,91,1760805488678.581
# 12:46:17> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:17> DLE_Node2 FSM: received: 2,91,1760805488678.581
# 12:46:17> MLE_Node2 MLE Rx: message 92: 2,91,1760805488678.581
# 12:46:17> PLE_Node2 Tx: message: 11
# 12:46:17> PLE_Node2 PLE: packet loss (15%)
# 12:46:21> DLE_Node1 FSM: state: 1 event type: 3
# 12:46:21> DLE_Node1 FSM: to resend frame 1 2,91,1760805488678.581
# 12:46:21> PLE_Node1 Tx: message: 012,91,1760805488678.581
# 12:46:21> PLE_Node2 Rx: from ('127.0.0.1', 33333): 012,91,1760805488678.581 (rx_delay=0.43s)
# 12:46:21> DLE_Node2 Rx: message 123: 012,91,1760805488678.581
# 12:46:21> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:21> DLE_Node2 FSM: received: 2,91,1760805488678.581
# 12:46:21> DLE_Node2 FSM: received received frame 1 but expected 2
# 12:46:21> PLE_Node2 Tx: message: 11
# 12:46:22> PLE_Node1 Rx: from ('127.0.0.1', 34000): 11 (rx_delay=0.68s)
# 12:46:22> DLE_Node1 Rx: message 104: 11
# 12:46:22> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:22> DLE_Node1 Tx: message 93: 2,92,1760805488678.582
# 12:46:22> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:22> DLE_Node1 FSM: to send: 2,92,1760805488678.582
# 12:46:22> PLE_Node1 Tx: message: 022,92,1760805488678.582
# 12:46:24> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,92,1760805488678.582 (rx_delay=2.07s)
# 12:46:24> DLE_Node2 Rx: message 124: 022,92,1760805488678.582
# 12:46:24> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:24> DLE_Node2 FSM: received: 2,92,1760805488678.582
# 12:46:24> PLE_Node2 Tx: message: 12
# 12:46:24> PLE_Node2 PLE: packet loss (15%)
# 12:46:24> MLE_Node2 MLE Rx: message 93: 2,92,1760805488678.582
# 12:46:28> DLE_Node1 FSM: state: 1 event type: 3
# 12:46:28> DLE_Node1 FSM: to resend frame 2 2,92,1760805488678.582
# 12:46:28> PLE_Node1 Tx: message: 022,92,1760805488678.582
# 12:46:28> PLE_Node1 PLE: packet loss (15%)
# 12:46:33> DLE_Node1 FSM: state: 1 event type: 3
# 12:46:33> DLE_Node1 FSM: to resend frame 2 2,92,1760805488678.582
# 12:46:33> PLE_Node1 Tx: message: 022,92,1760805488678.582
# 12:46:35> PLE_Node2 Rx: from ('127.0.0.1', 33333): 022,92,1760805488678.582 (rx_delay=1.16s)
# 12:46:35> DLE_Node2 Rx: message 125: 022,92,1760805488678.582
# 12:46:35> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:35> DLE_Node2 FSM: received: 2,92,1760805488678.582
# 12:46:35> DLE_Node2 FSM: received received frame 2 but expected 3
# 12:46:35> PLE_Node2 Tx: message: 12
# 12:46:36> PLE_Node1 Rx: from ('127.0.0.1', 34000): 12 (rx_delay=1.06s)
# 12:46:36> DLE_Node1 Rx: message 105: 12
# 12:46:36> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:36> DLE_Node1 Tx: message 94: 2,93,1760805488678.583
# 12:46:36> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:36> DLE_Node1 FSM: to send: 2,93,1760805488678.583
# 12:46:36> PLE_Node1 Tx: message: 032,93,1760805488678.583
# 12:46:38> PLE_Node2 Rx: from ('127.0.0.1', 33333): 032,93,1760805488678.583 (rx_delay=2.40s)
# 12:46:38> DLE_Node2 Rx: message 126: 032,93,1760805488678.583
# 12:46:38> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:38> DLE_Node2 FSM: received: 2,93,1760805488678.583
# 12:46:38> MLE_Node2 MLE Rx: message 94: 2,93,1760805488678.583
# 12:46:38> PLE_Node2 Tx: message: 13
# 12:46:40> PLE_Node1 Rx: from ('127.0.0.1', 34000): 13 (rx_delay=1.50s)
# 12:46:40> DLE_Node1 Rx: message 106: 13
# 12:46:40> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:40> DLE_Node1 Tx: message 95: 2,94,1760805488678.5837
# 12:46:40> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:40> DLE_Node1 FSM: to send: 2,94,1760805488678.5837
# 12:46:40> PLE_Node1 Tx: message: 042,94,1760805488678.5837
# 12:46:42> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,94,1760805488678.5837 (rx_delay=2.00s)
# 12:46:42> DLE_Node2 Rx: message 127: 042,94,1760805488678.5837
# 12:46:42> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:42> DLE_Node2 FSM: received: 2,94,1760805488678.5837
# 12:46:42> MLE_Node2 MLE Rx: message 95: 2,94,1760805488678.5837
# 12:46:42> PLE_Node2 Tx: message: 14
# 12:46:42> PLE_Node2 PLE: packet loss (15%)
# 12:46:45> DLE_Node1 FSM: state: 1 event type: 3
# 12:46:45> DLE_Node1 FSM: to resend frame 4 2,94,1760805488678.5837
# 12:46:45> PLE_Node1 Tx: message: 042,94,1760805488678.5837
# 12:46:47> PLE_Node2 Rx: from ('127.0.0.1', 33333): 042,94,1760805488678.5837 (rx_delay=1.84s)
# 12:46:47> DLE_Node2 Rx: message 128: 042,94,1760805488678.5837
# 12:46:47> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:47> DLE_Node2 FSM: received: 2,94,1760805488678.5837
# 12:46:47> DLE_Node2 FSM: received received frame 4 but expected 5
# 12:46:47> PLE_Node2 Tx: message: 14
# 12:46:49> PLE_Node1 Rx: from ('127.0.0.1', 34000): 14 (rx_delay=2.15s)
# 12:46:49> DLE_Node1 Rx: message 107: 14
# 12:46:49> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:49> DLE_Node1 Tx: message 96: 2,95,1760805488678.5845
# 12:46:49> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:49> DLE_Node1 FSM: to send: 2,95,1760805488678.5845
# 12:46:49> PLE_Node1 Tx: message: 052,95,1760805488678.5845
# 12:46:52> PLE_Node2 Rx: from ('127.0.0.1', 33333): 052,95,1760805488678.5845 (rx_delay=2.06s)
# 12:46:52> DLE_Node2 Rx: message 129: 052,95,1760805488678.5845
# 12:46:52> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:52> DLE_Node2 FSM: received: 2,95,1760805488678.5845
# 12:46:52> MLE_Node2 MLE Rx: message 96: 2,95,1760805488678.5845
# 12:46:52> PLE_Node2 Tx: message: 15
# 12:46:52> PLE_Node1 Rx: from ('127.0.0.1', 34000): 15 (rx_delay=0.82s)
# 12:46:52> DLE_Node1 Rx: message 108: 15
# 12:46:52> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:52> DLE_Node1 Tx: message 97: 2,96,1760805488678.5857
# 12:46:52> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:52> DLE_Node1 FSM: to send: 2,96,1760805488678.5857
# 12:46:52> PLE_Node1 Tx: message: 062,96,1760805488678.5857
# 12:46:53> PLE_Node2 Rx: from ('127.0.0.1', 33333): 062,96,1760805488678.5857 (rx_delay=1.08s)
# 12:46:53> DLE_Node2 Rx: message 130: 062,96,1760805488678.5857
# 12:46:53> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:53> DLE_Node2 FSM: received: 2,96,1760805488678.5857
# 12:46:53> MLE_Node2 MLE Rx: message 97: 2,96,1760805488678.5857
# 12:46:53> PLE_Node2 Tx: message: 16
# 12:46:55> PLE_Node1 Rx: from ('127.0.0.1', 34000): 16 (rx_delay=1.25s)
# 12:46:55> DLE_Node1 Rx: message 109: 16
# 12:46:55> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:55> DLE_Node1 Tx: message 98: 2,97,1760805488678.5867
# 12:46:55> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:55> DLE_Node1 FSM: to send: 2,97,1760805488678.5867
# 12:46:55> PLE_Node1 Tx: message: 072,97,1760805488678.5867
# 12:46:57> PLE_Node2 Rx: from ('127.0.0.1', 33333): 072,97,1760805488678.5867 (rx_delay=2.22s)
# 12:46:57> DLE_Node2 Rx: message 131: 072,97,1760805488678.5867
# 12:46:57> DLE_Node2 FSM: state: 0 event type: 1
# 12:46:57> DLE_Node2 FSM: received: 2,97,1760805488678.5867
# 12:46:57> MLE_Node2 MLE Rx: message 98: 2,97,1760805488678.5867
# 12:46:57> PLE_Node2 Tx: message: 17
# 12:46:59> PLE_Node1 Rx: from ('127.0.0.1', 34000): 17 (rx_delay=2.55s)
# 12:46:59> DLE_Node1 Rx: message 110: 17
# 12:46:59> DLE_Node1 FSM: state: 1 event type: 2
# 12:46:59> DLE_Node1 Tx: message 99: 2,98,1760805488678.5874
# 12:46:59> DLE_Node1 FSM: state: 0 event type: 0
# 12:46:59> DLE_Node1 FSM: to send: 2,98,1760805488678.5874
# 12:46:59> PLE_Node1 Tx: message: 082,98,1760805488678.5874
# 12:47:02> PLE_Node2 Rx: from ('127.0.0.1', 33333): 082,98,1760805488678.5874 (rx_delay=2.85s)
# 12:47:02> DLE_Node2 Rx: message 132: 082,98,1760805488678.5874
# 12:47:02> DLE_Node2 FSM: state: 0 event type: 1
# 12:47:02> DLE_Node2 FSM: received: 2,98,1760805488678.5874
# 12:47:02> PLE_Node2 Tx: message: 18
# 12:47:02> MLE_Node2 MLE Rx: message 99: 2,98,1760805488678.5874
# 12:47:05> DLE_Node1 FSM: state: 1 event type: 3
# 12:47:05> DLE_Node1 FSM: to resend frame 8 2,98,1760805488678.5874
# 12:47:05> PLE_Node1 Tx: message: 082,98,1760805488678.5874
# 12:47:05> PLE_Node1 PLE: packet loss (15%)
# 12:47:05> PLE_Node1 Rx: from ('127.0.0.1', 34000): 18 (rx_delay=2.96s)
# 12:47:05> DLE_Node1 Rx: message 111: 18
# 12:47:05> DLE_Node1 FSM: state: 1 event type: 2
# 12:47:05> DLE_Node1 Tx: message 100: 2,99,1760805488678.5884
# 12:47:05> DLE_Node1 FSM: state: 0 event type: 0
# 12:47:05> DLE_Node1 FSM: to send: 2,99,1760805488678.5884
# 12:47:05> PLE_Node1 Tx: message: 092,99,1760805488678.5884
# 12:47:05> PLE_Node1 PLE: packet loss (15%)
# 12:47:11> DLE_Node1 FSM: state: 1 event type: 3
# 12:47:11> DLE_Node1 FSM: to resend frame 9 2,99,1760805488678.5884
# 12:47:11> PLE_Node1 Tx: message: 092,99,1760805488678.5884
# 12:47:13> PLE_Node2 Rx: from ('127.0.0.1', 33333): 092,99,1760805488678.5884 (rx_delay=1.93s)
# 12:47:13> DLE_Node2 Rx: message 133: 092,99,1760805488678.5884
# 12:47:13> DLE_Node2 FSM: state: 0 event type: 1
# 12:47:13> DLE_Node2 FSM: received: 2,99,1760805488678.5884
# 12:47:13> MLE_Node2 MLE Rx: message 100: 2,99,1760805488678.5884
# 12:47:13> PLE_Node2 Tx: message: 19
# 12:47:15> PLE_Node1 Rx: from ('127.0.0.1', 34000): 19 (rx_delay=2.22s)
# 12:47:15> DLE_Node1 Rx: message 112: 19
# 12:47:15> DLE_Node1 FSM: state: 1 event type: 2

# %%
# Run the loop functions on threads
x1_1 = Thread(target = PLE_3.loop_Tx, args = ()) 
x1_2 = Thread(target = PLE_3.loop_Rx, args = ()) 
x1_3 = Thread(target = MLE_1.loop_Rx, args=())
x2_1 = Thread(target = PLE_4.loop_Tx, args = ()) 
x2_2 = Thread(target = PLE_4.loop_Rx, args = ()) 
x2_3 = Thread(target = MLE_2.loop_Rx, args=())

x3_1 = Thread(target = PLE_5.loop_Rx, args = ())
x3_2 = Thread(target = PLE_5.loop_Tx, args = ())
x3_3 = Thread(target = DLE_3.loop_Rx, args = ())
x3_4 = Thread(target = DLE_3.loop_Tx, args = ())
x3_5 = Thread(target = DLE_3.loop_FSM, args = ())
x3_6 = Thread(target = DLE_3.loop_timer, args = ())
x3_7 = Thread(target = MLE_3.loop_Rx, args = ())
x4_1 = Thread(target = PLE_6.loop_Rx, args = ())
x4_2 = Thread(target = PLE_6.loop_Tx, args = ())
x4_3 = Thread(target = DLE_4.loop_Rx, args = ())
x4_4 = Thread(target = DLE_4.loop_Tx, args = ())
x4_5 = Thread(target = DLE_4.loop_FSM, args = ())
x4_6 = Thread(target = DLE_4.loop_timer, args = ())
x4_7 = Thread(target = MLE_4.loop_Rx, args = ())

thread_running = True

x1_1.start()
x1_2.start()
x1_3.start()
x2_1.start()
x2_2.start()
x2_3.start()
x3_1.start()
x3_2.start()
x3_3.start()
x3_4.start()
x3_5.start()
x3_6.start()
x3_7.start()
x4_1.start()
x4_2.start()
x4_3.start()
x4_4.start()
x4_5.start()
x4_6.start()
x4_7.start()
